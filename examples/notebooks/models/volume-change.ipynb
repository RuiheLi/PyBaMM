# %%
import pybamm
import numpy as np
import matplotlib.pyplot as plt

# %%
def graphite_volume_change_Ai2020(sto, c_s_max):
    p1 = 145.907
    p2 = -681.229
    p3 = 1334.442
    p4 = -1415.710
    p5 = 873.906
    p6 = -312.528
    p7 = 60.641
    p8 = -5.706
    p9 = 0.386
    p10 = -4.966e-05
    t_change = (
        p1 * sto**9
        + p2 * sto**8
        + p3 * sto**7
        + p4 * sto**6
        + p5 * sto**5
        + p6 * sto**4
        + p7 * sto**3
        + p8 * sto**2
        + p9 * sto
        + p10
    )
    return t_change

# %%
sto = []
t_change = []
for i in range(101):
    sto.append(0.01*i)
    t_change.append(graphite_volume_change_Ai2020(0.01*i,32544))
plt.figure()
plt.plot(sto,t_change)
plt.show()
