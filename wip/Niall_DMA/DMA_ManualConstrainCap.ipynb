# %% [markdown]
# # <a id='toc1_'></a>[Add constrains on identified capacity](#toc0_)

# %%
# Load modules
# Mark Ruihe change 
import sys  ; import pybamm; import os
str_path_0 = os.path.abspath(os.path.join(pybamm.__path__[0],'..'))
str_path_1 = os.path.abspath(os.path.join(str_path_0,"wip\\Niall_DMA\\Data Analysis Functions"))
sys.path.append(str_path_1) 

import warnings
warnings.simplefilter('ignore', FutureWarning)

# Standard python libraries required for this to work
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider, Button
from matplotlib.lines import Line2D
import numpy as np
from scipy import optimize

# Some modules I wrote which contain functions used for data processing/analysis
import NDK_functions_Biologic_loading as bl
import NDK_functions_Degradation_Modes as dm
import NDK_functions_Degradation_Modes_composites as dmc

# To graph the results within the Notebook
# %matplotlib notebook
import matplotlib as mpl; fs=17; 
font = {'family' : 'DejaVu Sans',
        #'weight' : 'bold',
        'size'   : fs}
mpl.rc('font', **font)
from random import seed,random

# %%
# Load reference 1/2 cell datasets for each electrode/component (1 for PE, 2 for NE)
PE_OCV = pd.read_csv(
    'Example Data/Reference half-cell data/LGM50_NMC_PE_lithiation_OCV_v2.csv', 
    index_col=0)
NE_LGM50_OCV = pd.read_csv(
    'Example Data/Reference half-cell data/LGM50_SiGr_NE_delithiation_OCV.csv', 
    index_col=0)
NE_Gr_OCV = pd.read_csv(
    'Example Data/Reference half-cell data/Gr_NE_OCV_delithiation.csv', 
    index_col=0)
NE_Si_OCV = pd.read_csv(
    'Example Data/Reference half-cell data/Si_NE_OCV_delithiation_NEW(pure-Si(100mV)cycle2).csv', 
    index_col=0)

# %%
# Load full cell datasets to be analysed (a BoL dataset and some aged cell datasets)
AgeDataPath = "D:/OneDrive - Imperial College London/Degradation Tests/"
Path_Exp   = "Expt 3 - Cathode Degradation and Li-Plating/Performance Checks/"
SavePath = "D:/OneDrive - Imperial College London/SimDataSave/DMA_Niall_Ruihe/Exp3/"
import traceback
Rig_Exp3 = {
    "A":"1","B":"1","C":"1",
    "D":"3","E":"3","F":"3",
    "G":"6","H":"6","I":"6",}
Temp_Exp3 = {
    "A":"10","B":"10","C":"10",
    "D":"25","E":"25","F":"25",
    "G":"40","H":"40","I":"40",}
def Read_Path(AgeDataPath,Path_Exp,Exp_num,Rig_Exp3,NumRPT,str_cell):
    Cell_i_1RPT = bl.combo_function_fast(
        AgeDataPath+Path_Exp+  "BoL/Slow/" +   #  "RPT1/"
        f"NDK - LG M50 deg - exp {Exp_num} - rig {Rig_Exp3[str_cell]} - {Temp_Exp3[str_cell]}degC - cell {str_cell} - BoL (slow)_01_MB_CD6.mpt"
        )
    cellData = []
    cellData.append(Cell_i_1RPT)
    for i in range(1,NumRPT+1):
        try:
            cell_RPT_i = bl.combo_function_fast(
                AgeDataPath+Path_Exp+    f"RPT{i}/" +
                f'NDK - LG M50 deg - exp {Exp_num} - rig {Rig_Exp3[str_cell]} - {Temp_Exp3[str_cell]}degC - cell {str_cell} - RPT{i}_01_MB_CB6.mpt'
                )
        except Exception as e:
            # traceback.print_exc()
            print(f"Cell {str_cell} does not have RPT-{i}")
        else:
            cellData.append(cell_RPT_i)
    return cellData
# Mark Ruihe: define some new functions here:
# 1-Define a function to generate random numbers based on given values:
def Guess_0_Random(Num_try,guess_values_0,Min_guess_0,Max_guess_0):
    Min_guess = []; Max_guess =[]
    Guess_Values =[]
    for i in range(5):
        Min_guess.append( max(guess_values_0[i]*0.98,Min_guess_0[i])  )
        Max_guess.append( min(guess_values_0[i]*1.05,Max_guess_0[i])   ) 
    seed(1) # seed random number generator
    # generate random numbers between 0-1
    for k in range(Num_try):
        guess_values_i =[];
        for i in range(5):
            value = random()
            value_i =  Min_guess[i] + (value * (Max_guess[i] - Min_guess[i]))
            guess_values_i.append(value_i)
        Guess_Values.append(guess_values_i)
    return Guess_Values
# 2-Define a function to find the 8 min fits
# print(Err_1Cell1RPT_Alltries*1e3)
def Find_min(Err_1Cell1RPT_Alltries,Min_num):
    import copy
    Err_temp = copy.deepcopy(Err_1Cell1RPT_Alltries.tolist())
    min_number = []
    Min_index = []
    for _ in range(Min_num):
        number = min(Err_temp)
        i_temp = Err_temp.index(number)
        Err_temp[i_temp] = 1e6
        min_number.append(number)
        Min_index.append(i_temp)
        # print(number*1e3,i_temp)
    Err_temp = []
    return Min_index
# 3- Define a function to wrap OCV and plot 8 best fits,  but not yet decide on which one
def Wrap_OCV_Fit(Input_pack):  
    
    # Unpack input parameters:
    [Cell_i_Dis_1RPT, str_cell, RPT_num, Num_try,
        guess_values_0, Min_guess_0, Max_guess_0,
        NE_Gr_OCV, NE_Si_OCV, PE_OCV,Path, Save,fs,lw,ms,dpi] = Input_pack

    

    Cell_i_Dis_1RPT = Cell_i_Dis_1RPT[
        Cell_i_Dis_1RPT[
        'Current (mA)']<0].loc[
        :, ['Charge (mA.h)', 'Voltage (V)']]
    Cell_i_Dis_1RPT.reset_index(inplace=True, drop=True)
    Cell_i_Dis_1RPT['SOC (%)'] =(
        1 - 
        Cell_i_Dis_1RPT['Charge (mA.h)']
        /Cell_i_Dis_1RPT['Charge (mA.h)'].max()   )

    z_1Cell1RPT_Alltries = [];   Err_1Cell1RPT_Alltries=[]; 
    Fit_1Cell1RPT_Alltries = []; Cap_1Cell1RPT_Alltries=[]; 
    Guess_Values = Guess_0_Random(Num_try,guess_values_0,Min_guess_0,Max_guess_0)
    for guess_values in Guess_Values:
        z_out, _, Cap_out = dmc.stoich_OCV_fit_multi_comp(
            NE_Gr_OCV, NE_Si_OCV, PE_OCV, Cell_i_Dis_1RPT,
            z_guess=guess_values)
        Fit_1Cell1RPT, _, _, _ = dmc.calc_full_cell_OCV_multi_standalone(
            NE_Gr_OCV, NE_Si_OCV, PE_OCV, Cell_i_Dis_1RPT['SOC (%)'], 
            *z_out)
        fitted_Gr_fract = z_out[4].round(4)
        fitted_Si_fract = 1-fitted_Gr_fract
        err_BoL = dmc.DM_error_check(
            NE_Gr_OCV, NE_Si_OCV, PE_OCV, Cell_i_Dis_1RPT, 
            z_out)
        # print(f"RMSE for {guess_values} is {(err_BoL*1e3).round(2)} mV")
        # Append
        z_1Cell1RPT_Alltries.append(z_out);          Err_1Cell1RPT_Alltries.append(err_BoL) 
        Fit_1Cell1RPT_Alltries.append(Fit_1Cell1RPT);Cap_1Cell1RPT_Alltries.append(Cap_out)

    Err_1Cell1RPT_Alltries = np.array(Err_1Cell1RPT_Alltries)    
    Min_index = Find_min(Err_1Cell1RPT_Alltries,8)
    
    # History: for 20 rounds of optimization, 64s is needed. 
    import matplotlib as mpl; import copy; 
    font = {'family' : 'DejaVu Sans','size': fs}
    mpl.rc('font', **font)
    Index_Plot = {
        "0":[0,1],"1":[0,2],"2":[1,0],"3":[1,1],
        "4":[1,2],"5":[2,0],"6":[2,1],"7":[2,2] }

    # Start a plot
    Fig_DMA_1cell1RPT, ax = plt.subplots(3,3,  figsize=(16,12))
    Err_1Cell1RPT_Alltries_temp = copy.deepcopy(Err_1Cell1RPT_Alltries)
    Err_1Cell1RPT_Alltries_temp = abs( np.sort(-Err_1Cell1RPT_Alltries_temp)); 
    Temp_List = np.arange(1,len(Err_1Cell1RPT_Alltries_temp)+1)
    ax[0,0].plot(Temp_List,  Err_1Cell1RPT_Alltries_temp*1e3,  
        color='grey',linewidth=lw,  linestyle='-',marker = 'o',markersize = ms)
    ax[0,0].plot(Temp_List[-8:] ,  Err_1Cell1RPT_Alltries_temp[-8:]*1e3,  
        color='b',linewidth=lw,  linestyle='none',marker = 'o',markersize = ms+2)
    # ax[0,0].set_ylim([3 , 15])
    ax[0,0].set_ylabel('RMSE (mV)')
    ax[0,0].set_xlabel('Try number (sort)')
    # plot things:
    for min_index,i in zip(Min_index,range(len(Min_index))):
        SOC_OCV_Temp = Fit_1Cell1RPT_Alltries[min_index].to_numpy()
        SOC_OCV_Exp  = Cell_i_Dis_1RPT.to_numpy()
        m,n = Index_Plot[str(i)]
        ax[m,n].plot(SOC_OCV_Exp[:,2]*100,SOC_OCV_Exp[:,1],linewidth=lw, ls='-',color='k',label='Exp', ) 
        ax[m,n].plot(SOC_OCV_Temp[:,0]*100,SOC_OCV_Temp[:,1],linewidth=lw, ls='--',color='b',label='Fit', ) 
        ax[m,n].set_xlabel('SOC %')
        ax[m,n].invert_xaxis()
        ax[m,n].set_ylabel('Voltage (V)')
        ax[m,n].text(75,2.7,
            f'Try Num: {min_index}\nRMSE: {format(Err_1Cell1RPT_Alltries[min_index]*1e3,".2f")} mV',
            horizontalalignment='left',
            verticalalignment='bottom', fontsize=fs)
    ax[0,1].legend(frameon=False,)

    Fig_DMA_1cell1RPT.suptitle(
        f'Fit result of Cell {str_cell}, RPT-{RPT_num}', 
        fontsize=fs+4)
    Fig_DMA_1cell1RPT.tight_layout()
    if Save == True:
        Fig_DMA_1cell1RPT.savefig(
            Path + f"Cell_{str_cell}_RPT_{RPT_num}_8bestFits.png", dpi=dpi)
    
    Out_1Cell1RPT = [
        z_1Cell1RPT_Alltries, Err_1Cell1RPT_Alltries, Fit_1Cell1RPT_Alltries, Cell_i_Dis_1RPT, 
        Cap_1Cell1RPT_Alltries,Min_index ]

    return Out_1Cell1RPT

# %%
cellData_A = Read_Path(AgeDataPath,Path_Exp,3,Rig_Exp3,12,"A")
# Plot of the discharge voltage curves for the 3 datasets being analysed
fig_V_curves, ax = plt.subplots()
for cell in cellData_A:
    data_to_plot = cell[cell['Current (mA)'] < 0]
    data_to_plot.plot('Charge (mA.h)', 'Voltage (V)', ax=ax, )
ax.set_ylabel('Voltage (V)')
fig_V_curves.tight_layout()
# Out:
# Cell A does not have RPT-11
# Cell A does not have RPT-12

# %%
# Do the actual OCV fit!

# Global settings: initial guess range - should be the same in at least one Exp set. 
#   PE_lo	NE_lo	PE_hi	NE_hi	Gr_frac
Min_guess_0 = [0.01, 0.001, 0.90, 0.80 , 0.70 ]; 
Max_guess_0 = [0.23, 0.05, 0.99, 0.95, 0.87]; 
str_cell = 'A'; Num_try = 200;  
dpi = 300; fs=17; lw=2; ms=6; Save = True; 
guess_values_0 = [0.1, 0.002, 0.95, 0.85, 0.84] # The guess value for BoL
# Results for One cell all RPTs:
z_1CellAllRPTs=[];    Err_1CellAllRPTs=[];     Fit_1CellAllRPTs=[]; Exp_1CellAllRPTs=[];
Cap_1CellAllRPTs=[];  Index_1CellAllRPTs = []; Guess_values_0_1CellAllRPTs =[guess_values_0,]


########################## start from BoL:  ######################### 
#####################################################################
RPT_num =  0
Cell_i_Dis_1RPT = eval("cellData_{}".format(str_cell))[RPT_num].copy() # This is where choose the cell and RPT
 # input values: 
# Fit!!!
[
    z_1Cell1RPT_Alltries, Err_1Cell1RPT_Alltries, Fit_1Cell1RPT_Alltries, Cell_i_Dis_1RPT, 
    Cap_1Cell1RPT_Alltries,Min_index ] =  Wrap_OCV_Fit([
        Cell_i_Dis_1RPT, str_cell, RPT_num, Num_try,
        Guess_values_0_1CellAllRPTs[-1], Min_guess_0, Max_guess_0,
        NE_Gr_OCV, NE_Si_OCV, PE_OCV,SavePath, Save,fs,lw,ms,dpi ])
# Make decision now: after visual inspection:
Index_1CellAllRPTs.append(Min_index[0] )  # start from always pick the lowest RMSE ones
# in the future, maybe consider to compare Cap_1CellAllRPTs
# Append others:
Exp_1CellAllRPTs.append(Cell_i_Dis_1RPT)
Guess_values_0_1CellAllRPTs.append(z_1Cell1RPT_Alltries[Index_1CellAllRPTs[-1]])
z_1CellAllRPTs  .append(z_1Cell1RPT_Alltries[Index_1CellAllRPTs[-1]])
Err_1CellAllRPTs.append(Err_1Cell1RPT_Alltries[Index_1CellAllRPTs[-1]])
Fit_1CellAllRPTs.append(Fit_1Cell1RPT_Alltries[Index_1CellAllRPTs[-1]])
Cap_1CellAllRPTs.append(Cap_1Cell1RPT_Alltries[Index_1CellAllRPTs[-1]])

# %%
########################## start from BoL:  ######################### 
#####################################################################
Cap_NESi_1Cell1RPT_Alltries = []; Cap_NEto_1Cell1RPT_Alltries=[];
for i in range(200):
    Cap_NESi_1Cell1RPT_Alltries.append( Cap_1Cell1RPT_Alltries[i][4] )
    Cap_NEto_1Cell1RPT_Alltries.append( Cap_1Cell1RPT_Alltries[i][2] )
######################### For BoL  ######################### 
######################### Step-2: Plot #########################    
df_RMSE_Cap_NEto_NESi = pd.DataFrame(
    data={
    "RMSE (mV)":np.array(Err_1Cell1RPT_Alltries)*1e3,
    "Cap_NESi (Ah)":(np.array(Cap_NESi_1Cell1RPT_Alltries)/1e3),
    "Cap_NEtot (Ah)":(np.array(Cap_NEto_1Cell1RPT_Alltries)/1e3),
})
df_RMSE_Cap_NEto_NESi = df_RMSE_Cap_NEto_NESi.sort_values(by=["RMSE (mV)"], ignore_index=True)
fig,ax = plt.subplots(3,1,figsize=(12,12))
ax[0].plot(df_RMSE_Cap_NEto_NESi["RMSE (mV)"],linestyle='-',marker = 'o',markersize = ms+2)
# ax[0].plot(df_select["RMSE (mV)"],linestyle='none',color='r',marker = '^',markersize = ms+4)
ax[0].plot(np.arange(1,Num_try+1),np.full([Num_try,1],10) ,linestyle='-',)
ax[0].set_ylabel('RMSE (mV)')
ax[1].plot(df_RMSE_Cap_NEto_NESi["Cap_NESi (Ah)"],linestyle='-',marker = 'o',markersize = ms+2 )
# ax[1].plot(df_select["Cap_NESi (Ah)"],linestyle='none',color='r',marker = '^',markersize = ms+4)

ax[1].set_ylabel('NE_Si (Ah)')
ax[2].plot(df_RMSE_Cap_NEto_NESi["Cap_NEtot (Ah)"],linestyle='-',marker = 'o',markersize = ms+2 )
# ax[2].plot(df_select["Cap_NEtot (Ah)"],linestyle='none',color='r',marker = '^',markersize = ms+4)

ax[2].set_ylabel('NE_tot (Ah)')

for i in range(3):
    ax[i].set_xlabel('Try number')
    ax[i].grid()
# 105 and 108 
fig.tight_layout()

# %%
######################### For 1st RPT  ######################### 
######################### Step-1: Fit  #########################           
RPT_num = 1
Cap_NESi_estimated = Cap_1CellAllRPTs[-1][4]
Cap_NEto_estimated = Cap_1CellAllRPTs[-1][2]
print(Cap_NESi_estimated, Cap_NEto_estimated)

Cell_i_Dis_1RPT = eval("cellData_{}".format(str_cell))[RPT_num].copy() # This is where choose the cell and RPT
Path = SavePath
Input_pack = [Cell_i_Dis_1RPT, str_cell, RPT_num, Num_try,
        guess_values_0, Min_guess_0, Max_guess_0,
        Cap_NESi_estimated, Cap_NEto_estimated,
        NE_Gr_OCV, NE_Si_OCV, PE_OCV,Path, Save,fs,lw,ms,dpi,
        ]
Cell_i_Dis_1RPT = Cell_i_Dis_1RPT[
        Cell_i_Dis_1RPT[
        'Current (mA)']<0].loc[:, ['Charge (mA.h)', 'Voltage (V)']]
Cell_i_Dis_1RPT.reset_index(inplace=True, drop=True)
Cell_i_Dis_1RPT['SOC (%)'] =(
        1 - 
        Cell_i_Dis_1RPT['Charge (mA.h)']
        /Cell_i_Dis_1RPT['Charge (mA.h)'].max()   )

z_1Cell1RPT_Alltries = [];   Err_1Cell1RPT_Alltries=[]; 
Fit_1Cell1RPT_Alltries = []; Cap_1Cell1RPT_Alltries=[]; 
Cap_NESi_1Cell1RPT_Alltries=[];  Cap_NEto_1Cell1RPT_Alltries=[];
Guess_Values = Guess_0_Random(Num_try,guess_values_0,Min_guess_0,Max_guess_0)
for guess_values in Guess_Values:
        z_out, _, Cap_out = dmc.stoich_OCV_fit_multi_comp(
                NE_Gr_OCV, NE_Si_OCV, PE_OCV, Cell_i_Dis_1RPT,
                z_guess=guess_values)
        Cap_NESi_1Cell1RPT_Alltries.append(Cap_out[4])
        Cap_NEto_1Cell1RPT_Alltries.append(Cap_out[2])
        Fit_1Cell1RPT, _, _, _ = dmc.calc_full_cell_OCV_multi_standalone(
                NE_Gr_OCV, NE_Si_OCV, PE_OCV, Cell_i_Dis_1RPT['SOC (%)'], 
                *z_out)
        fitted_Gr_fract = z_out[4].round(4)
        fitted_Si_fract = 1-fitted_Gr_fract
        err_BoL = dmc.DM_error_check(
                NE_Gr_OCV, NE_Si_OCV, PE_OCV, Cell_i_Dis_1RPT, 
                z_out)
        # print(f"RMSE for {guess_values} is {(err_BoL*1e3).round(2)} mV")
        # Append
        z_1Cell1RPT_Alltries.append(z_out);          Err_1Cell1RPT_Alltries.append(err_BoL) 
        Fit_1Cell1RPT_Alltries.append(Fit_1Cell1RPT);Cap_1Cell1RPT_Alltries.append(Cap_out)
# Out:
# 777.7439281149599 5435.40744264856

# %%
######################### For 1st RPT  ######################### 
######################### Step-2: Plot #########################    
df_RMSE_Cap_NEto_NESi = pd.DataFrame(
    data={
    "RMSE (mV)":np.array(Err_1Cell1RPT_Alltries)*1e3,
    "Cap_NESi (Ah)":(np.array(Cap_NESi_1Cell1RPT_Alltries)/1e3),
    "Cap_NEtot (Ah)":(np.array(Cap_NEto_1Cell1RPT_Alltries)/1e3),
})
df_RMSE_Cap_NEto_NESi = df_RMSE_Cap_NEto_NESi.sort_values(by=["RMSE (mV)"], ignore_index=True)
fig,ax = plt.subplots(3,1,figsize=(12,12))
ax[0].plot(df_RMSE_Cap_NEto_NESi["RMSE (mV)"],linestyle='-',marker = 'o',markersize = ms+2)
# ax[0].plot(df_select["RMSE (mV)"],linestyle='none',color='r',marker = '^',markersize = ms+4)
ax[0].plot(np.arange(1,Num_try+1),np.full([Num_try,1],10) ,linestyle='-',)
ax[0].set_ylabel('RMSE (mV)')
ax[1].plot(df_RMSE_Cap_NEto_NESi["Cap_NESi (Ah)"],linestyle='-',marker = 'o',markersize = ms+2 )
# ax[1].plot(df_select["Cap_NESi (Ah)"],linestyle='none',color='r',marker = '^',markersize = ms+4)
ax[1].plot(
    np.arange(1,Num_try+1),
    np.full([Num_try,1],Cap_NESi_estimated/1e3),
    color='r',linestyle='-' )
ax[1].set_ylabel('NE_Si (Ah)')
ax[2].plot(df_RMSE_Cap_NEto_NESi["Cap_NEtot (Ah)"],linestyle='-',marker = 'o',markersize = ms+2 )
# ax[2].plot(df_select["Cap_NEtot (Ah)"],linestyle='none',color='r',marker = '^',markersize = ms+4)
ax[2].plot(
    np.arange(1,Num_try+1),
    np.full([Num_try,1],Cap_NEto_estimated/1e3) ,
    color='r',linestyle='-' )
ax[2].set_ylabel('NE_tot (Ah)')

for i in range(3):
    ax[i].set_xlabel('Try number')
    ax[i].grid()
# 105 and 108 
fig.tight_layout()

# %%
######################### For 1st RPT    ######################### 
######################### Step-3: Select #########################    
# print, and manully decide 108
df_select= df_RMSE_Cap_NEto_NESi.loc[
    (df_RMSE_Cap_NEto_NESi["RMSE (mV)"] <10 ) 
    & 
    (df_RMSE_Cap_NEto_NESi["Cap_NEtot (Ah)"] <= 5.8)
    ]
print(df_select)
# Out:
#      RMSE (mV)  Cap_NESi (Ah)  Cap_NEtot (Ah)
# 105   7.186275       0.789887        5.708445
# 108   7.224657       0.782936        5.669684
# 138   8.920585       0.719768        5.754635

# %%
######################### For 1st RPT    ######################### 
######################### Step-3: Select #########################   
# manually select
Array_Err_1Cell1RPT_Alltries = np.array(Err_1Cell1RPT_Alltries)*1e3
index =np.where(Array_Err_1Cell1RPT_Alltries==df_select["RMSE (mV)"][108]) 
print(f"Select index is: {index[0][0]}")
print(
    Err_1Cell1RPT_Alltries[index[0][0]]*1e3,
    Cap_NESi_1Cell1RPT_Alltries[index[0][0]]/1e3,
    Cap_NEto_1Cell1RPT_Alltries[index[0][0]]/1e3)
# Out:
# Select index is: 120
# 7.224657192542458 0.7829363757326505 5.669683669922933

# %%
#########################     For 1st RPT      ######################### 
######################### Step-4: Double check #########################  
fig,ax = plt.subplots(3,1,figsize=(16,16))
ax[0].plot(df_RMSE_Cap_NEto_NESi["RMSE (mV)"],linestyle='-',marker = 'o',markersize = ms+2)
ax[0].plot(df_select["RMSE (mV)"],linestyle='none',color='r',marker = '^',markersize = ms+4)
ax[0].plot(np.arange(1,Num_try+1),np.full([Num_try,1],10) ,linestyle='-',)
ax[0].set_ylabel('RMSE (mV)')
ax[1].plot(df_RMSE_Cap_NEto_NESi["Cap_NESi (Ah)"],linestyle='-',marker = 'o',markersize = ms+2 )
ax[1].plot(df_select["Cap_NESi (Ah)"],linestyle='none',color='r',marker = '^',markersize = ms+4)
ax[1].plot(
    np.arange(1,Num_try+1),
    np.full([Num_try,1],Cap_NESi_estimated/1e3),
    color='r',linestyle='-' )
ax[1].set_ylabel('NE_Si (Ah)')
ax[2].plot(df_RMSE_Cap_NEto_NESi["Cap_NEtot (Ah)"],linestyle='-',marker = 'o',markersize = ms+2 )
ax[2].plot(df_select["Cap_NEtot (Ah)"],linestyle='none',color='r',marker = '^',markersize = ms+4)
ax[2].plot(
    np.arange(1,Num_try+1),
    np.full([Num_try,1],Cap_NEto_estimated/1e3) ,
    color='r',linestyle='-' )
ax[2].set_ylabel('NE_tot (Ah)')

for i in range(3):
    ax[i].set_xlabel('Try number')
    ax[i].grid()
# 105 and 108 
fig.tight_layout()

# %%
#########################     For 1st RPT         ######################### 
######################### Step-6: Append for next #########################  
# Make decision now: after visual inspection:
Index_1CellAllRPTs.append(120 )  # start from always pick the lowest RMSE ones
# in the future, maybe consider to compare Cap_1CellAllRPTs
# Append others:
Exp_1CellAllRPTs.append(Cell_i_Dis_1RPT)
Guess_values_0_1CellAllRPTs.append(z_1Cell1RPT_Alltries[Index_1CellAllRPTs[-1]])
z_1CellAllRPTs  .append(z_1Cell1RPT_Alltries[Index_1CellAllRPTs[-1]])
Err_1CellAllRPTs.append(Err_1Cell1RPT_Alltries[Index_1CellAllRPTs[-1]])
Fit_1CellAllRPTs.append(Fit_1Cell1RPT_Alltries[Index_1CellAllRPTs[-1]])
Cap_1CellAllRPTs.append(Cap_1Cell1RPT_Alltries[Index_1CellAllRPTs[-1]])

# %%
######################### For 2nd RPT  ######################### 
################################################################
######################### Step-1: Fit  #########################           
RPT_num = 2
Cap_NESi_estimated = Cap_1CellAllRPTs[-1][4]
Cap_NEto_estimated = Cap_1CellAllRPTs[-1][2]
print(Cap_NESi_estimated, Cap_NEto_estimated)

Cell_i_Dis_1RPT = eval("cellData_{}".format(str_cell))[RPT_num].copy() # This is where choose the cell and RPT
Path = SavePath
Input_pack = [Cell_i_Dis_1RPT, str_cell, RPT_num, Num_try,
        guess_values_0, Min_guess_0, Max_guess_0,
        Cap_NESi_estimated, Cap_NEto_estimated,
        NE_Gr_OCV, NE_Si_OCV, PE_OCV,Path, Save,fs,lw,ms,dpi,
        ]
Cell_i_Dis_1RPT = Cell_i_Dis_1RPT[
        Cell_i_Dis_1RPT[
        'Current (mA)']<0].loc[:, ['Charge (mA.h)', 'Voltage (V)']]
Cell_i_Dis_1RPT.reset_index(inplace=True, drop=True)
Cell_i_Dis_1RPT['SOC (%)'] =(
        1 - 
        Cell_i_Dis_1RPT['Charge (mA.h)']
        /Cell_i_Dis_1RPT['Charge (mA.h)'].max()   )

z_1Cell1RPT_Alltries = [];   Err_1Cell1RPT_Alltries=[]; 
Fit_1Cell1RPT_Alltries = []; Cap_1Cell1RPT_Alltries=[]; 
Cap_NESi_1Cell1RPT_Alltries=[];  Cap_NEto_1Cell1RPT_Alltries=[];
Guess_Values = Guess_0_Random(Num_try,guess_values_0,Min_guess_0,Max_guess_0)
for guess_values in Guess_Values:
        z_out, _, Cap_out = dmc.stoich_OCV_fit_multi_comp(
                NE_Gr_OCV, NE_Si_OCV, PE_OCV, Cell_i_Dis_1RPT,
                z_guess=guess_values)
        Cap_NESi_1Cell1RPT_Alltries.append(Cap_out[4])
        Cap_NEto_1Cell1RPT_Alltries.append(Cap_out[2])
        Fit_1Cell1RPT, _, _, _ = dmc.calc_full_cell_OCV_multi_standalone(
                NE_Gr_OCV, NE_Si_OCV, PE_OCV, Cell_i_Dis_1RPT['SOC (%)'], 
                *z_out)
        fitted_Gr_fract = z_out[4].round(4)
        fitted_Si_fract = 1-fitted_Gr_fract
        err_BoL = dmc.DM_error_check(
                NE_Gr_OCV, NE_Si_OCV, PE_OCV, Cell_i_Dis_1RPT, 
                z_out)
        # print(f"RMSE for {guess_values} is {(err_BoL*1e3).round(2)} mV")
        # Append
        z_1Cell1RPT_Alltries.append(z_out);          Err_1Cell1RPT_Alltries.append(err_BoL) 
        Fit_1Cell1RPT_Alltries.append(Fit_1Cell1RPT);Cap_1Cell1RPT_Alltries.append(Cap_out)
# Out:
# 782.9363757326505 5669.683669922933

# %%
######################### For 2nd RPT  ######################### 
######################### Step-2: Plot #########################    
df_RMSE_Cap_NEto_NESi = pd.DataFrame(
    data={
    "RMSE (mV)":np.array(Err_1Cell1RPT_Alltries)*1e3,
    "Cap_NESi (Ah)":(np.array(Cap_NESi_1Cell1RPT_Alltries)/1e3),
    "Cap_NEtot (Ah)":(np.array(Cap_NEto_1Cell1RPT_Alltries)/1e3),
})
df_RMSE_Cap_NEto_NESi = df_RMSE_Cap_NEto_NESi.sort_values(by=["RMSE (mV)"], ignore_index=True)
fig,ax = plt.subplots(3,1,figsize=(12,12))
ax[0].plot(df_RMSE_Cap_NEto_NESi["RMSE (mV)"],linestyle='-',marker = 'o',markersize = ms+2)
# ax[0].plot(df_select["RMSE (mV)"],linestyle='none',color='r',marker = '^',markersize = ms+4)
ax[0].plot(np.arange(1,Num_try+1),np.full([Num_try,1],10) ,linestyle='-',)
ax[0].set_ylabel('RMSE (mV)')
ax[1].plot(df_RMSE_Cap_NEto_NESi["Cap_NESi (Ah)"],linestyle='-',marker = 'o',markersize = ms+2 )
# ax[1].plot(df_select["Cap_NESi (Ah)"],linestyle='none',color='r',marker = '^',markersize = ms+4)
ax[1].plot(
    np.arange(1,Num_try+1),
    np.full([Num_try,1],Cap_NESi_estimated/1e3),
    color='r',linestyle='-' )
ax[1].set_ylabel('NE_Si (Ah)')
ax[2].plot(df_RMSE_Cap_NEto_NESi["Cap_NEtot (Ah)"],linestyle='-',marker = 'o',markersize = ms+2 )
# ax[2].plot(df_select["Cap_NEtot (Ah)"],linestyle='none',color='r',marker = '^',markersize = ms+4)
ax[2].plot(
    np.arange(1,Num_try+1),
    np.full([Num_try,1],Cap_NEto_estimated/1e3) ,
    color='r',linestyle='-' )
ax[2].set_ylabel('NE_tot (Ah)')

for i in range(3):
    ax[i].set_xlabel('Try number')
    ax[i].grid()
# 105 and 108 
fig.tight_layout()

# %%
######################### For 2nd RPT    ######################### 
######################### Step-3: Select #########################    
# print, and manully decide 108
df_select= df_RMSE_Cap_NEto_NESi.loc[
    (df_RMSE_Cap_NEto_NESi["RMSE (mV)"] <10 ) 
    & 
    (df_RMSE_Cap_NEto_NESi["Cap_NEtot (Ah)"] <= 5.8)
    ]
print(df_select)
# Out:
#      RMSE (mV)  Cap_NESi (Ah)  Cap_NEtot (Ah)
# 150   6.789994       0.754148        5.577237
# 151   7.043027       0.800312        5.356820

# %%
######################### For 2nd RPT    ######################### 
######################### Step-3: Select #########################   
# manually select
Array_Err_1Cell1RPT_Alltries = np.array(Err_1Cell1RPT_Alltries)*1e3
index =np.where(Array_Err_1Cell1RPT_Alltries==df_select["RMSE (mV)"][150]) 
print(f"Select index is: {index[0][0]}")
print(
    Err_1Cell1RPT_Alltries[index[0][0]]*1e3,
    Cap_NESi_1Cell1RPT_Alltries[index[0][0]]/1e3,
    Cap_NEto_1Cell1RPT_Alltries[index[0][0]]/1e3)
# Out:
# Select index is: 93
# 6.7899944010985065 0.7541476780983544 5.57723710766646

# %%
#########################     For 2nd RPT      ######################### 
######################### Step-4: Double check #########################  
fig,ax = plt.subplots(3,1,figsize=(16,16))
ax[0].plot(df_RMSE_Cap_NEto_NESi["RMSE (mV)"],linestyle='-',marker = 'o',markersize = ms+2)
ax[0].plot(df_select["RMSE (mV)"],linestyle='none',color='r',marker = '^',markersize = ms+4)
ax[0].plot(np.arange(1,Num_try+1),np.full([Num_try,1],10) ,linestyle='-',)
ax[0].set_ylabel('RMSE (mV)')
ax[1].plot(df_RMSE_Cap_NEto_NESi["Cap_NESi (Ah)"],linestyle='-',marker = 'o',markersize = ms+2 )
ax[1].plot(df_select["Cap_NESi (Ah)"],linestyle='none',color='r',marker = '^',markersize = ms+4)
ax[1].plot(
    np.arange(1,Num_try+1),
    np.full([Num_try,1],Cap_NESi_estimated/1e3),
    color='r',linestyle='-' )
ax[1].set_ylabel('NE_Si (Ah)')
ax[2].plot(df_RMSE_Cap_NEto_NESi["Cap_NEtot (Ah)"],linestyle='-',marker = 'o',markersize = ms+2 )
ax[2].plot(df_select["Cap_NEtot (Ah)"],linestyle='none',color='r',marker = '^',markersize = ms+4)
ax[2].plot(
    np.arange(1,Num_try+1),
    np.full([Num_try,1],Cap_NEto_estimated/1e3) ,
    color='r',linestyle='-' )
ax[2].set_ylabel('NE_tot (Ah)')

for i in range(3):
    ax[i].set_xlabel('Try number')
    ax[i].grid()
# 105 and 108 
fig.tight_layout()

# %%
#########################     For 2nd RPT         ######################### 
######################### Step-5: Append for next #########################  
# Make decision now: after visual inspection:
Index_1CellAllRPTs.append(93 )  # start from always pick the lowest RMSE ones
# in the future, maybe consider to compare Cap_1CellAllRPTs
# Append others:
Exp_1CellAllRPTs.append(Cell_i_Dis_1RPT)
Guess_values_0_1CellAllRPTs.append(z_1Cell1RPT_Alltries[Index_1CellAllRPTs[-1]])
z_1CellAllRPTs  .append(z_1Cell1RPT_Alltries[Index_1CellAllRPTs[-1]])
Err_1CellAllRPTs.append(Err_1Cell1RPT_Alltries[Index_1CellAllRPTs[-1]])
Fit_1CellAllRPTs.append(Fit_1Cell1RPT_Alltries[Index_1CellAllRPTs[-1]])
Cap_1CellAllRPTs.append(Cap_1Cell1RPT_Alltries[Index_1CellAllRPTs[-1]])

# %%
######################### For 3rd RPT  ######################### 
######################### Step-1: Fit  #########################           
RPT_num = 3
Cap_NESi_estimated = Cap_1CellAllRPTs[-1][4]
Cap_NEto_estimated = Cap_1CellAllRPTs[-1][2]
print(Cap_NESi_estimated, Cap_NEto_estimated)

Cell_i_Dis_1RPT = eval("cellData_{}".format(str_cell))[RPT_num].copy() # This is where choose the cell and RPT
Path = SavePath
Input_pack = [Cell_i_Dis_1RPT, str_cell, RPT_num, Num_try,
        guess_values_0, Min_guess_0, Max_guess_0,
        Cap_NESi_estimated, Cap_NEto_estimated,
        NE_Gr_OCV, NE_Si_OCV, PE_OCV,Path, Save,fs,lw,ms,dpi,
        ]
Cell_i_Dis_1RPT = Cell_i_Dis_1RPT[
        Cell_i_Dis_1RPT[
        'Current (mA)']<0].loc[:, ['Charge (mA.h)', 'Voltage (V)']]
Cell_i_Dis_1RPT.reset_index(inplace=True, drop=True)
Cell_i_Dis_1RPT['SOC (%)'] =(
        1 - 
        Cell_i_Dis_1RPT['Charge (mA.h)']
        /Cell_i_Dis_1RPT['Charge (mA.h)'].max()   )

z_1Cell1RPT_Alltries = [];   Err_1Cell1RPT_Alltries=[]; 
Fit_1Cell1RPT_Alltries = []; Cap_1Cell1RPT_Alltries=[]; 
Cap_NESi_1Cell1RPT_Alltries=[];  Cap_NEto_1Cell1RPT_Alltries=[];
Guess_Values = Guess_0_Random(Num_try,guess_values_0,Min_guess_0,Max_guess_0)
for guess_values in Guess_Values:
        z_out, _, Cap_out = dmc.stoich_OCV_fit_multi_comp(
                NE_Gr_OCV, NE_Si_OCV, PE_OCV, Cell_i_Dis_1RPT,
                z_guess=guess_values)
        Cap_NESi_1Cell1RPT_Alltries.append(Cap_out[4])
        Cap_NEto_1Cell1RPT_Alltries.append(Cap_out[2])
        Fit_1Cell1RPT, _, _, _ = dmc.calc_full_cell_OCV_multi_standalone(
                NE_Gr_OCV, NE_Si_OCV, PE_OCV, Cell_i_Dis_1RPT['SOC (%)'], 
                *z_out)
        fitted_Gr_fract = z_out[4].round(4)
        fitted_Si_fract = 1-fitted_Gr_fract
        err_BoL = dmc.DM_error_check(
                NE_Gr_OCV, NE_Si_OCV, PE_OCV, Cell_i_Dis_1RPT, 
                z_out)
        # print(f"RMSE for {guess_values} is {(err_BoL*1e3).round(2)} mV")
        # Append
        z_1Cell1RPT_Alltries.append(z_out);          Err_1Cell1RPT_Alltries.append(err_BoL) 
        Fit_1Cell1RPT_Alltries.append(Fit_1Cell1RPT);Cap_1Cell1RPT_Alltries.append(Cap_out)
# Out:
# 754.1476780983544 5577.23710766646

# %%
######################### For 3rd RPT  ######################### 
######################### Step-2: Plot #########################    
df_RMSE_Cap_NEto_NESi = pd.DataFrame(
    data={
    "RMSE (mV)":np.array(Err_1Cell1RPT_Alltries)*1e3,
    "Cap_NESi (Ah)":(np.array(Cap_NESi_1Cell1RPT_Alltries)/1e3),
    "Cap_NEtot (Ah)":(np.array(Cap_NEto_1Cell1RPT_Alltries)/1e3),
})
df_RMSE_Cap_NEto_NESi = df_RMSE_Cap_NEto_NESi.sort_values(by=["RMSE (mV)"], ignore_index=True)
fig,ax = plt.subplots(3,1,figsize=(12,12))
ax[0].plot(df_RMSE_Cap_NEto_NESi["RMSE (mV)"],linestyle='-',marker = 'o',markersize = ms+2)
# ax[0].plot(df_select["RMSE (mV)"],linestyle='none',color='r',marker = '^',markersize = ms+4)
ax[0].plot(np.arange(1,Num_try+1),np.full([Num_try,1],10) ,linestyle='-',)
ax[0].set_ylabel('RMSE (mV)')
ax[1].plot(df_RMSE_Cap_NEto_NESi["Cap_NESi (Ah)"],linestyle='-',marker = 'o',markersize = ms+2 )
# ax[1].plot(df_select["Cap_NESi (Ah)"],linestyle='none',color='r',marker = '^',markersize = ms+4)
ax[1].plot(
    np.arange(1,Num_try+1),
    np.full([Num_try,1],Cap_NESi_estimated/1e3),
    color='r',linestyle='-' )
ax[1].set_ylabel('NE_Si (Ah)')
ax[2].plot(df_RMSE_Cap_NEto_NESi["Cap_NEtot (Ah)"],linestyle='-',marker = 'o',markersize = ms+2 )
# ax[2].plot(df_select["Cap_NEtot (Ah)"],linestyle='none',color='r',marker = '^',markersize = ms+4)
ax[2].plot(
    np.arange(1,Num_try+1),
    np.full([Num_try,1],Cap_NEto_estimated/1e3) ,
    color='r',linestyle='-' )
ax[2].set_ylabel('NE_tot (Ah)')

for i in range(3):
    ax[i].set_xlabel('Try number')
    ax[i].grid()
# 105 and 108 
fig.tight_layout()

# %%
######################### For 3rd RPT    ######################### 
######################### Step-3: Select #########################    
# print, and manully decide 108
df_select= df_RMSE_Cap_NEto_NESi.loc[
    (df_RMSE_Cap_NEto_NESi["RMSE (mV)"] <10 ) 
    & 
    (df_RMSE_Cap_NEto_NESi["Cap_NEtot (Ah)"] <= 5.57)
    ]
print(df_select)
# Out:
#      RMSE (mV)  Cap_NESi (Ah)  Cap_NEtot (Ah)
# 173   8.377283       0.825203        5.426845
# 174   8.457783       0.710978        5.546391

# %%
######################### For 3rd RPT    ######################### 
######################### Step-3: Select #########################   
# manually select
Array_Err_1Cell1RPT_Alltries = np.array(Err_1Cell1RPT_Alltries)*1e3
index =np.where(Array_Err_1Cell1RPT_Alltries==df_select["RMSE (mV)"][173]) 
print(f"Select index is: {index[0][0]}")
print(
    Err_1Cell1RPT_Alltries[index[0][0]]*1e3,
    Cap_NESi_1Cell1RPT_Alltries[index[0][0]]/1e3,
    Cap_NEto_1Cell1RPT_Alltries[index[0][0]]/1e3)
# Out:
# Select index is: 14
# 8.377282601507257 0.8252028672649778 5.426844600416819

# %%
#########################     For 3rd RPT      ######################### 
######################### Step-4: Double check #########################  
fig,ax = plt.subplots(3,1,figsize=(16,16))
ax[0].plot(df_RMSE_Cap_NEto_NESi["RMSE (mV)"],linestyle='-',marker = 'o',markersize = ms+2)
ax[0].plot(df_select["RMSE (mV)"],linestyle='none',color='r',marker = '^',markersize = ms+4)
ax[0].plot(np.arange(1,Num_try+1),np.full([Num_try,1],10) ,linestyle='-',)
ax[0].set_ylabel('RMSE (mV)')
ax[1].plot(df_RMSE_Cap_NEto_NESi["Cap_NESi (Ah)"],linestyle='-',marker = 'o',markersize = ms+2 )
ax[1].plot(df_select["Cap_NESi (Ah)"],linestyle='none',color='r',marker = '^',markersize = ms+4)
ax[1].plot(
    np.arange(1,Num_try+1),
    np.full([Num_try,1],Cap_NESi_estimated/1e3),
    color='r',linestyle='-' )
ax[1].set_ylabel('NE_Si (Ah)')
ax[2].plot(df_RMSE_Cap_NEto_NESi["Cap_NEtot (Ah)"],linestyle='-',marker = 'o',markersize = ms+2 )
ax[2].plot(df_select["Cap_NEtot (Ah)"],linestyle='none',color='r',marker = '^',markersize = ms+4)
ax[2].plot(
    np.arange(1,Num_try+1),
    np.full([Num_try,1],Cap_NEto_estimated/1e3) ,
    color='r',linestyle='-' )
ax[2].set_ylabel('NE_tot (Ah)')

for i in range(3):
    ax[i].set_xlabel('Try number')
    ax[i].grid()
# 105 and 108 
fig.tight_layout()

# %%
#########################     For 3rd RPT         ######################### 
######################### Step-5: Append for next #########################  
# Make decision now: after visual inspection:
Index_1CellAllRPTs.append(120 )  # start from always pick the lowest RMSE ones
# in the future, maybe consider to compare Cap_1CellAllRPTs
# Append others:
Exp_1CellAllRPTs.append(Cell_i_Dis_1RPT)
Guess_values_0_1CellAllRPTs.append(z_1Cell1RPT_Alltries[Index_1CellAllRPTs[-1]])
z_1CellAllRPTs  .append(z_1Cell1RPT_Alltries[Index_1CellAllRPTs[-1]])
Err_1CellAllRPTs.append(Err_1Cell1RPT_Alltries[Index_1CellAllRPTs[-1]])
Fit_1CellAllRPTs.append(Fit_1Cell1RPT_Alltries[Index_1CellAllRPTs[-1]])
Cap_1CellAllRPTs.append(Cap_1Cell1RPT_Alltries[Index_1CellAllRPTs[-1]])

# %%
for RPT_num in np.arange(1,11):
    Cell_i_Dis_1RPT = eval("cellData_{}".format(str_cell))[RPT_num].copy() # This is where choose the cell and RPT
    # input values: 
    # Fit!!!
    [
        z_1Cell1RPT_Alltries, Err_1Cell1RPT_Alltries, Fit_1Cell1RPT_Alltries,Cell_i_Dis_1RPT, 
        Cap_1Cell1RPT_Alltries,Min_index ] =  Wrap_OCV_Fit([
            Cell_i_Dis_1RPT, str_cell, RPT_num, Num_try,
            Guess_values_0_1CellAllRPTs[-1], Min_guess_0, Max_guess_0,
            NE_Gr_OCV, NE_Si_OCV, PE_OCV,SavePath, Save,fs,lw,ms,dpi] )
    # Make decision now: after visual inspection:
    Index_1CellAllRPTs.append(Min_index[0] )  # start from always pick the lowest RMSE ones
    # in the future, maybe consider to compare Cap_1CellAllRPTs
    # Append others:
    Exp_1CellAllRPTs.append(Cell_i_Dis_1RPT)
    Guess_values_0_1CellAllRPTs.append(z_1Cell1RPT_Alltries[Index_1CellAllRPTs[-1]])
    z_1CellAllRPTs  .append(z_1Cell1RPT_Alltries[Index_1CellAllRPTs[-1]])  # identified electrode sto / SOC  
    Err_1CellAllRPTs.append(Err_1Cell1RPT_Alltries[Index_1CellAllRPTs[-1]])# RMSE
    Fit_1CellAllRPTs.append(Fit_1Cell1RPT_Alltries[Index_1CellAllRPTs[-1]])# Fitted voltage 
    Cap_1CellAllRPTs.append(Cap_1Cell1RPT_Alltries[Index_1CellAllRPTs[-1]])# identified electrode cap
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\GitPyBaMM\LRH_409\LRH_409\envSolCon\PyBaMM-GEM\wip\Niall_DMA\DMA_Ruihe_ConstrainCap.ipynb Cell 27 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/d%3A/GitPyBaMM/LRH_409/LRH_409/envSolCon/PyBaMM-GEM/wip/Niall_DMA/DMA_Ruihe_ConstrainCap.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> Cell_i_Dis_1RPT = eval("cellData_{}".format(str_cell))[RPT_num].copy() # This is where choose the cell and RPT
#       <a href='vscode-notebook-cell:/d%3A/GitPyBaMM/LRH_409/LRH_409/envSolCon/PyBaMM-GEM/wip/Niall_DMA/DMA_Ruihe_ConstrainCap.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a> # input values:
#       <a href='vscode-notebook-cell:/d%3A/GitPyBaMM/LRH_409/LRH_409/envSolCon/PyBaMM-GEM/wip/Niall_DMA/DMA_Ruihe_ConstrainCap.ipynb#X12sZmlsZQ%3D%3D?line=3'>4</a> # Fit!!!
#       <a href='vscode-notebook-cell:/d%3A/GitPyBaMM/LRH_409/LRH_409/envSolCon/PyBaMM-GEM/wip/Niall_DMA/DMA_Ruihe_ConstrainCap.ipynb#X12sZmlsZQ%3D%3D?line=4'>5</a> [
#       <a href='vscode-notebook-cell:/d%3A/GitPyBaMM/LRH_409/LRH_409/envSolCon/PyBaMM-GEM/wip/Niall_DMA/DMA_Ruihe_ConstrainCap.ipynb#X12sZmlsZQ%3D%3D?line=5'>6</a>     z_1Cell1RPT_Alltries, Err_1Cell1RPT_Alltries, Fit_1Cell1RPT_Alltries,Cell_i_Dis_1RPT,
# ----> <a href='vscode-notebook-cell:/d%3A/GitPyBaMM/LRH_409/LRH_409/envSolCon/PyBaMM-GEM/wip/Niall_DMA/DMA_Ruihe_ConstrainCap.ipynb#X12sZmlsZQ%3D%3D?line=6'>7</a>     Cap_1Cell1RPT_Alltries,Min_index ] =  Wrap_OCV_Fit([
#       <a href='vscode-notebook-cell:/d%3A/GitPyBaMM/LRH_409/LRH_409/envSolCon/PyBaMM-GEM/wip/Niall_DMA/DMA_Ruihe_ConstrainCap.ipynb#X12sZmlsZQ%3D%3D?line=7'>8</a>         Cell_i_Dis_1RPT, str_cell, RPT_num, Num_try,
#       <a href='vscode-notebook-cell:/d%3A/GitPyBaMM/LRH_409/LRH_409/envSolCon/PyBaMM-GEM/wip/Niall_DMA/DMA_Ruihe_ConstrainCap.ipynb#X12sZmlsZQ%3D%3D?line=8'>9</a>         Guess_values_0_1CellAllRPTs[-1], Min_guess_0, Max_guess_0,
#      <a href='vscode-notebook-cell:/d%3A/GitPyBaMM/LRH_409/LRH_409/envSolCon/PyBaMM-GEM/wip/Niall_DMA/DMA_Ruihe_ConstrainCap.ipynb#X12sZmlsZQ%3D%3D?line=9'>10</a>         NE_Gr_OCV, NE_Si_OCV, PE_OCV,SavePath, Save,fs,lw,ms,dpi] )
#      <a href='vscode-notebook-cell:/d%3A/GitPyBaMM/LRH_409/LRH_409/envSolCon/PyBaMM-GEM/wip/Niall_DMA/DMA_Ruihe_ConstrainCap.ipynb#X12sZmlsZQ%3D%3D?line=10'>11</a> # Make decision now: after visual inspection:
#      <a href='vscode-notebook-cell:/d%3A/GitPyBaMM/LRH_409/LRH_409/envSolCon/PyBaMM-GEM/wip/Niall_DMA/DMA_Ruihe_ConstrainCap.ipynb#X12sZmlsZQ%3D%3D?line=11'>12</a> Index_1CellAllRPTs.append(Min_index[0] )  # start from always pick the lowest RMSE ones
#
# d:\GitPyBaMM\LRH_409\LRH_409\envSolCon\PyBaMM-GEM\wip\Niall_DMA\DMA_Ruihe_ConstrainCap.ipynb Cell 27 in Wrap_OCV_Fit(Input_pack)
#      <a href='vscode-notebook-cell:/d%3A/GitPyBaMM/LRH_409/LRH_409/envSolCon/PyBaMM-GEM/wip/Niall_DMA/DMA_Ruihe_ConstrainCap.ipynb#X12sZmlsZQ%3D%3D?line=88'>89</a> Guess_Values = Guess_0_Random(Num_try,guess_values_0,Min_guess_0,Max_guess_0)
#      <a href='vscode-notebook-cell:/d%3A/GitPyBaMM/LRH_409/LRH_409/envSolCon/PyBaMM-GEM/wip/Niall_DMA/DMA_Ruihe_ConstrainCap.ipynb#X12sZmlsZQ%3D%3D?line=89'>90</a> for guess_values in Guess_Values:
# ---> <a href='vscode-notebook-cell:/d%3A/GitPyBaMM/LRH_409/LRH_409/envSolCon/PyBaMM-GEM/wip/Niall_DMA/DMA_Ruihe_ConstrainCap.ipynb#X12sZmlsZQ%3D%3D?line=90'>91</a>     z_out, _, Cap_out = dmc.stoich_OCV_fit_multi_comp(
#      <a href='vscode-notebook-cell:/d%3A/GitPyBaMM/LRH_409/LRH_409/envSolCon/PyBaMM-GEM/wip/Niall_DMA/DMA_Ruihe_ConstrainCap.ipynb#X12sZmlsZQ%3D%3D?line=91'>92</a>         NE_Gr_OCV, NE_Si_OCV, PE_OCV, Cell_i_Dis_1RPT,
#      <a href='vscode-notebook-cell:/d%3A/GitPyBaMM/LRH_409/LRH_409/envSolCon/PyBaMM-GEM/wip/Niall_DMA/DMA_Ruihe_ConstrainCap.ipynb#X12sZmlsZQ%3D%3D?line=92'>93</a>         z_guess=guess_values)
#      <a href='vscode-notebook-cell:/d%3A/GitPyBaMM/LRH_409/LRH_409/envSolCon/PyBaMM-GEM/wip/Niall_DMA/DMA_Ruihe_ConstrainCap.ipynb#X12sZmlsZQ%3D%3D?line=93'>94</a>     Fit_1Cell1RPT, _, _, _ = dmc.calc_full_cell_OCV_multi_standalone(
#      <a href='vscode-notebook-cell:/d%3A/GitPyBaMM/LRH_409/LRH_409/envSolCon/PyBaMM-GEM/wip/Niall_DMA/DMA_Ruihe_ConstrainCap.ipynb#X12sZmlsZQ%3D%3D?line=94'>95</a>         NE_Gr_OCV, NE_Si_OCV, PE_OCV, Cell_i_Dis_1RPT['SOC (%)'],
#      <a href='vscode-notebook-cell:/d%3A/GitPyBaMM/LRH_409/LRH_409/envSolCon/PyBaMM-GEM/wip/Niall_DMA/DMA_Ruihe_ConstrainCap.ipynb#X12sZmlsZQ%3D%3D?line=95'>96</a>         *z_out)
#      <a href='vscode-notebook-cell:/d%3A/GitPyBaMM/LRH_409/LRH_409/envSolCon/PyBaMM-GEM/wip/Niall_DMA/DMA_Ruihe_ConstrainCap.ipynb#X12sZmlsZQ%3D%3D?line=96'>97</a>     fitted_Gr_fract = z_out[4].round(4)
#
# File d:\gitpybamm\lrh_409\lrh_409\envsolcon\pybamm-gem\wip\Niall_DMA\Data Analysis Functions\NDK_functions_Degradation_Modes_composites.py:373, in stoich_OCV_fit_multi_comp(anode_comp1_data, anode_comp2_data, cathode_data, full_cell, z_guess, diff_step_size)
#     367     return output
#     369 # This is the actual optimisation
#     370 # It takes the above function, x- and y-values from the full_cell dataset,
#     371 # and the initial_guess of the z_values provided in z_guess
#     372 # It returns the fitted z_values (lithiation fractions), and a covariance matrix
# --> 373 z_out, z_cov = optimize.curve_fit(
#     374     calc_full_cell_OCV_multi, xdata=cell_SOC, ydata=cell_V,
#     375     p0=z_guess, bounds=([0.,0.,0.,0.,0.5], [1.,1.,1.,1.,1.]), # Mark Ruihe add: constrain Gr_frac to 0.5~1 as we know
#     376     diff_step=diff_step_size)
#     378 # The fitted z_values are then used for calculating the capacities of the full and 1/2 cells, and the offset
#     379 PE_lo, NE_lo, PE_hi, NE_hi, comp1_frac = z_out
#
# File d:\GitPyBaMM\LRH_409\LRH_409\envSolCon\lib\site-packages\scipy\optimize\_minpack_py.py:800, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, **kwargs)
#     797 if 'max_nfev' not in kwargs:
#     798     kwargs['max_nfev'] = kwargs.pop('maxfev', None)
# --> 800 res = least_squares(func, p0, jac=jac, bounds=bounds, method=method,
#     801                     **kwargs)
#     803 if not res.success:
#     804     raise RuntimeError("Optimal parameters not found: " + res.message)
#
# File d:\GitPyBaMM\LRH_409\LRH_409\envSolCon\lib\site-packages\scipy\optimize\_lsq\least_squares.py:928, in least_squares(fun, x0, jac, bounds, method, ftol, xtol, gtol, x_scale, loss, f_scale, diff_step, tr_solver, tr_options, jac_sparsity, max_nfev, verbose, args, kwargs)
#     924     result = call_minpack(fun_wrapped, x0, jac_wrapped, ftol, xtol, gtol,
#     925                           max_nfev, x_scale, diff_step)
#     927 elif method == 'trf':
# --> 928     result = trf(fun_wrapped, jac_wrapped, x0, f0, J0, lb, ub, ftol, xtol,
#     929                  gtol, max_nfev, x_scale, loss_function, tr_solver,
#     930                  tr_options.copy(), verbose)
#     932 elif method == 'dogbox':
#     933     if tr_solver == 'lsmr' and 'regularize' in tr_options:
#
# File d:\GitPyBaMM\LRH_409\LRH_409\envSolCon\lib\site-packages\scipy\optimize\_lsq\trf.py:123, in trf(fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale, loss_function, tr_solver, tr_options, verbose)
#     119     return trf_no_bounds(
#     120         fun, jac, x0, f0, J0, ftol, xtol, gtol, max_nfev, x_scale,
#     121         loss_function, tr_solver, tr_options, verbose)
#     122 else:
# --> 123     return trf_bounds(
#     124         fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale,
#     125         loss_function, tr_solver, tr_options, verbose)
#
# File d:\GitPyBaMM\LRH_409\LRH_409\envSolCon\lib\site-packages\scipy\optimize\_lsq\trf.py:338, in trf_bounds(fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale, loss_function, tr_solver, tr_options, verbose)
#     334 step, step_h, predicted_reduction = select_step(
#     335     x, J_h, diag_h, g_h, p, p_h, d, Delta, lb, ub, theta)
#     337 x_new = make_strictly_feasible(x + step, lb, ub, rstep=0)
# --> 338 f_new = fun(x_new)
#     339 nfev += 1
#     341 step_h_norm = norm(step_h)
#
# File d:\GitPyBaMM\LRH_409\LRH_409\envSolCon\lib\site-packages\scipy\optimize\_lsq\least_squares.py:815, in least_squares.<locals>.fun_wrapped(x)
#     814 def fun_wrapped(x):
# --> 815     return np.atleast_1d(fun(x, *args, **kwargs))
#
# File d:\GitPyBaMM\LRH_409\LRH_409\envSolCon\lib\site-packages\scipy\optimize\_minpack_py.py:485, in _wrap_func.<locals>.func_wrapped(params)
#     484 def func_wrapped(params):
# --> 485     return func(xdata, *params) - ydata
#
# File d:\gitpybamm\lrh_409\lrh_409\envsolcon\pybamm-gem\wip\Niall_DMA\Data Analysis Functions\NDK_functions_Degradation_Modes_composites.py:362, in stoich_OCV_fit_multi_comp.<locals>.calc_full_cell_OCV_multi(SOC_points, z_pe_lo, z_ne_lo, z_pe_hi, z_ne_hi, comp1_frac)
#     360 cell_out = pd.DataFrame(data=None, index=SOC_points.round(5)) # Make a new DF, using the SOC of the input (measured) full cell data as the index
#     361 cell_out['OCV'] = cell_ocv['OCV'] # Get 'OCV' values from the calculated full cell data based on the SOC (index) of the input data
# --> 362 cell_out.interpolate(inplace=True) # Interpolate over all SOC values from input data (index)
#     364 # For the scipy.optimize.curve_fit function, the output needs to be in the form of a numpy array for some reason
#     365 output = np.array(cell_out['OCV'])
#
# File d:\GitPyBaMM\LRH_409\LRH_409\envSolCon\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File d:\GitPyBaMM\LRH_409\LRH_409\envSolCon\lib\site-packages\pandas\core\frame.py:10937, in DataFrame.interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#   10925 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "method"])
#   10926 def interpolate(
#   10927     self: DataFrame,
#    (...)
#   10935     **kwargs,
#   10936 ) -> DataFrame | None:
# > 10937     return super().interpolate(
#   10938         method,
#   10939         axis,
#   10940         limit,
#   10941         inplace,
#   10942         limit_direction,
#   10943         limit_area,
#   10944         downcast,
#   10945         **kwargs,
#   10946     )
#
# File d:\GitPyBaMM\LRH_409\LRH_409\envSolCon\lib\site-packages\pandas\core\generic.py:7036, in NDFrame.interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    7030 if isna(index).any():
#    7031     raise NotImplementedError(
#    7032         "Interpolation with NaNs in the index "
#    7033         "has not been implemented. Try filling "
#    7034         "those NaNs before interpolating."
#    7035     )
# -> 7036 new_data = obj._mgr.interpolate(
#    7037     method=method,
#    7038     axis=axis,
#    7039     index=index,
#    7040     limit=limit,
#    7041     limit_direction=limit_direction,
#    7042     limit_area=limit_area,
#    7043     inplace=inplace,
#    7044     downcast=downcast,
#    7045     **kwargs,
#    7046 )
#    7048 result = self._constructor(new_data)
#    7049 if should_transpose:
#
# File d:\GitPyBaMM\LRH_409\LRH_409\envSolCon\lib\site-packages\pandas\core\internals\managers.py:359, in BaseBlockManager.interpolate(self, **kwargs)
#     358 def interpolate(self: T, **kwargs) -> T:
# --> 359     return self.apply("interpolate", **kwargs)
#
# File d:\GitPyBaMM\LRH_409\LRH_409\envSolCon\lib\site-packages\pandas\core\internals\managers.py:304, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     302         applied = b.apply(f, **kwargs)
#     303     else:
# --> 304         applied = getattr(b, f)(**kwargs)
#     305 except (TypeError, NotImplementedError):
#     306     if not ignore_failures:
#
# File d:\GitPyBaMM\LRH_409\LRH_409\envSolCon\lib\site-packages\pandas\core\internals\blocks.py:1101, in Block.interpolate(self, method, axis, index, inplace, limit, limit_direction, limit_area, fill_value, coerce, downcast, **kwargs)
#    1098 data = self.values if inplace else self.values.copy()
#    1099 data = cast(np.ndarray, data)  # bc overridden by ExtensionBlock
# -> 1101 missing.interpolate_array_2d(
#    1102     data,
#    1103     method=method,
#    1104     axis=axis,
#    1105     index=index,
#    1106     limit=limit,
#    1107     limit_direction=limit_direction,
#    1108     limit_area=limit_area,
#    1109     fill_value=fill_value,
#    1110     **kwargs,
#    1111 )
#    1113 nb = self.make_block_same_class(data)
#    1114 return nb._maybe_downcast([nb], downcast)
#
# File d:\GitPyBaMM\LRH_409\LRH_409\envSolCon\lib\site-packages\pandas\core\missing.py:249, in interpolate_array_2d(data, method, axis, index, limit, limit_direction, limit_area, fill_value, coerce, downcast, **kwargs)
#     246 else:
#     247     assert index is not None  # for mypy
# --> 249     _interpolate_2d_with_fill(
#     250         data=data,
#     251         index=index,
#     252         axis=axis,
#     253         method=method,
#     254         limit=limit,
#     255         limit_direction=limit_direction,
#     256         limit_area=limit_area,
#     257         fill_value=fill_value,
#     258         **kwargs,
#     259     )
#     260 return
#
# File d:\GitPyBaMM\LRH_409\LRH_409\envSolCon\lib\site-packages\pandas\core\missing.py:344, in _interpolate_2d_with_fill(data, index, axis, method, limit, limit_direction, limit_area, fill_value, **kwargs)
#     324     _interpolate_1d(
#     325         indices=indices,
#     326         yvalues=yvalues,
#    (...)
#     333         **kwargs,
#     334     )
#     336 # Argument 1 to "apply_along_axis" has incompatible type
#     337 # "Callable[[ndarray[Any, Any]], None]"; expected
#     338 # "Callable[..., Union[_SupportsArray[dtype[<nothing>]],
#    (...)
#     342 # Sequence[Sequence[Sequence[Sequence[_SupportsArray[dtype[<nothing>]]]]]]]]"
#     343 # interp each column independently
# --> 344 np.apply_along_axis(func, axis, data)  # type: ignore[arg-type]
#     345 return
#
# File <__array_function__ internals>:180, in apply_along_axis(*args, **kwargs)
#
# File d:\GitPyBaMM\LRH_409\LRH_409\envSolCon\lib\site-packages\numpy\lib\shape_base.py:379, in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     375 except StopIteration as e:
#     376     raise ValueError(
#     377         'Cannot apply_along_axis when any iteration dimensions are 0'
#     378     ) from None
# --> 379 res = asanyarray(func1d(inarr_view[ind0], *args, **kwargs))
#     381 # build a buffer for storing evaluations of func1d.
#     382 # remove the requested axis, and add the new ones on the end.
#     383 # laid out so that each write is contiguous.
#     384 # for a tuple index inds, buff[inds] = func1d(inarr_view[inds])
#     385 buff = zeros(inarr_view.shape[:-1] + res.shape, res.dtype)
#
# File d:\GitPyBaMM\LRH_409\LRH_409\envSolCon\lib\site-packages\pandas\core\missing.py:324, in _interpolate_2d_with_fill.<locals>.func(yvalues)
#     321 def func(yvalues: np.ndarray) -> None:
#     322     # process 1-d slices in the axis direction
# --> 324     _interpolate_1d(
#     325         indices=indices,
#     326         yvalues=yvalues,
#     327         method=method,
#     328         limit=limit,
#     329         limit_direction=limit_direction,
#     330         limit_area=limit_area,
#     331         fill_value=fill_value,
#     332         bounds_error=False,
#     333         **kwargs,
#     334     )
#
# File d:\GitPyBaMM\LRH_409\LRH_409\envSolCon\lib\site-packages\pandas\core\missing.py:406, in _interpolate_1d(indices, yvalues, method, limit, limit_direction, limit_area, fill_value, bounds_error, order, **kwargs)
#     403 # These are sets of index pointers to invalid values... i.e. {0, 1, etc...
#     404 all_nans = set(np.flatnonzero(invalid))
# --> 406 first_valid_index = find_valid_index(yvalues, how="first")
#     407 if first_valid_index is None:  # no nan found in start
#     408     first_valid_index = 0
#
# File d:\GitPyBaMM\LRH_409\LRH_409\envSolCon\lib\site-packages\pandas\core\missing.py:191, in find_valid_index(values, how)
#     188 if len(values) == 0:  # early stop
#     189     return None
# --> 191 is_valid = ~isna(values)
#     193 if values.ndim == 2:
#     194     is_valid = is_valid.any(1)  # reduce axis 1
#
# File d:\GitPyBaMM\LRH_409\LRH_409\envSolCon\lib\site-packages\pandas\core\dtypes\missing.py:144, in isna(obj)
#      67 def isna(obj):
#      68     """
#      69     Detect missing values for an array-like object.
#      70
#    (...)
#     142     Name: 1, dtype: bool
#     143     """
# --> 144     return _isna(obj)
#
# File d:\GitPyBaMM\LRH_409\LRH_409\envSolCon\lib\site-packages\pandas\core\dtypes\missing.py:173, in _isna(obj, inf_as_na)
#     171     return False
#     172 elif isinstance(obj, (np.ndarray, ABCExtensionArray)):
# --> 173     return _isna_array(obj, inf_as_na=inf_as_na)
#     174 elif isinstance(obj, ABCIndex):
#     175     # Try to use cached isna, which also short-circuits for integer dtypes
#     176     #  and avoids materializing RangeIndex._values
#     177     if not obj._can_hold_na:
#
# File d:\GitPyBaMM\LRH_409\LRH_409\envSolCon\lib\site-packages\pandas\core\dtypes\missing.py:263, in _isna_array(values, inf_as_na)
#     261         result = ~np.isfinite(values)
#     262     else:
# --> 263         result = np.isnan(values)
#     265 return result
#
# KeyboardInterrupt:

# %% [markdown]
# # Post-processing

# %%
# Now follow Niall's operation: make list into pandas DataFrame
z_1CellAllRPTs_df = pd.DataFrame(data=z_1CellAllRPTs, columns=['PE_lo', 'NE_lo', 'PE_hi', 'NE_hi', 'Gr_frac'])
Cap_1CellAllRPTs_df = pd.DataFrame(
    data=Cap_1CellAllRPTs, 
    columns=[
    'Cell Cap', 'PE Cap', 'NE(tot) Cap', 
    'NE(Gr) Cap', 'NE(Si) Cap', 'Offset'])
Err_1CellAllRPTs_df = pd.DataFrame(data={'RMSE (V)':Err_1CellAllRPTs})   # RMSE for one cell, all RPTs
SoH = Cap_1CellAllRPTs_df['Cell Cap']/Cap_1CellAllRPTs_df['Cell Cap'][0]
LAM_pe = 1 - (Cap_1CellAllRPTs_df['PE Cap']/Cap_1CellAllRPTs_df['PE Cap'][0])
LAM_ne_tot = 1 - (Cap_1CellAllRPTs_df['NE(tot) Cap']/Cap_1CellAllRPTs_df['NE(tot) Cap'][0])
LAM_ne_Gr = 1 - (Cap_1CellAllRPTs_df['NE(Gr) Cap']/Cap_1CellAllRPTs_df['NE(Gr) Cap'][0])
LAM_ne_Si = 1 - (Cap_1CellAllRPTs_df['NE(Si) Cap']/Cap_1CellAllRPTs_df['NE(Si) Cap'][0])
LLI = ((
        Cap_1CellAllRPTs_df['PE Cap'][0] - Cap_1CellAllRPTs_df['PE Cap'] - 
        (Cap_1CellAllRPTs_df['Offset'][0]-Cap_1CellAllRPTs_df['Offset'])       )
    /Cap_1CellAllRPTs_df['Cell Cap'][0] )
# Compile the DM parameters into a dataframe
DM_df = pd.DataFrame(
    data={
    'SoH':SoH, 'LAM PE':LAM_pe, 'LAM NE_tot':LAM_ne_tot, 
    'LAM NE_Gr':LAM_ne_Gr, 'LAM NE_Si':LAM_ne_Si, 'LLI':LLI})

# %%
# One figure for one RPT of one cell; therefore 9 cells; each cell has 13 RPT max; 
# total figure will be: 13*9=117 
# in each figure: sub-plot-1 for voltage fit for the best; 
#                 sub-plot-2 Dataset-number-RMSE
# another 3 plots same as Niall, but with one more plot for all voltage (best fit)
font = {'family' : 'DejaVu Sans','size'   : 17}
mpl.rc('font', **font)
fig_DMA_output, ax = plt.subplots(2,2, figsize=(11,8))
for Fit_1CellAll1RPT,Cell_i_Dis_1RPT in zip(Fit_1CellAllRPTs,Exp_1CellAllRPTs):
    SOC_OCV_Temp = Fit_1CellAll1RPT.to_numpy()
    SOC_OCV_Exp  = Cell_i_Dis_1RPT.to_numpy()
    T_plot_scale = max(Cell_i_Dis_1RPT["Charge (mA.h)"])/500
    ax[0,0].plot(T_plot_scale-SOC_OCV_Exp[:,2] *T_plot_scale,SOC_OCV_Exp [:,1],linewidth=lw*0.5, ls='-', color='k',label='Exp', ) 
    ax[0,0].plot(T_plot_scale-SOC_OCV_Temp[:,0]*T_plot_scale,SOC_OCV_Temp[:,1],linewidth=lw*0.5, ls='--',color='b',label='Fit', ) 
ax[0,0].set_xlabel('Time (h)')
ax[0,0].set_ylabel('Voltage (V)')
# ax[0,0].invert_xaxis()

DM_df.plot(ax=ax[1,1], marker='o')
Cap_1CellAllRPTs_df_Ah = Cap_1CellAllRPTs_df /1e3  # temperry change to Ah
Cap_1CellAllRPTs_df_Ah.plot(ax=ax[1,0], marker='o')
Err_temp = Err_1CellAllRPTs_df.to_numpy()
ax[0,1].plot(np.arange(0,len(Err_temp)), Err_temp*1e3, linewidth=lw, ls='-',color='b',marker='o')

ax[1,1].set_ylabel('DM Fraction'); 
ax[1,1].yaxis.set_label_coords(-0.15,0.50) # need to adjust to have the best show 
ax[1,0].set_ylabel('Capacity (Ah)')
ax[0,1].set_ylabel('RMSE (mV)')
ax[0,1].set_xlabel('RPT number')
ax[1,0].set_xlabel('RPT number')
ax[1,1].set_xlabel('RPT number')
ax[1,0].legend(prop={'family':'DejaVu Sans','size':fs-3}, 
    loc='lower center', bbox_to_anchor=(0.5,0.15),
    ncol=2,frameon=True,markerscale=1,borderpad=0.2,handlelength=1.5,columnspacing=1)
ax[1,1].legend(prop={'family':'DejaVu Sans','size':fs-3},
    loc='lower center', bbox_to_anchor=(0.5,0.4),
    ncol=2,frameon=True,markerscale=1,borderpad=0.2,handlelength=1.5,columnspacing=1) # loc='best',

fig_DMA_output.tight_layout()
#if Save == True:
fig_DMA_output.savefig(
    SavePath + f"Fig. 1 Cell_{str_cell}_DMA_Summary.png", dpi=dpi)

# %%
# finally, save fig and data:
df_temp  = DM_df.join(Cap_1CellAllRPTs_df)
df_temp  = df_temp.join(z_1CellAllRPTs_df)
df_temp  = df_temp.join(Err_1CellAllRPTs_df)
df_temp.head()
df_temp.to_csv(SavePath + f"Cell_{str_cell}_DMA_Summary.csv")
