# %%
import pybamm

# %%
Para_0=pybamm.ParameterValues("Li2023_Coupled");
c_e = pybamm.linspace(0, 1e4, 100)
D_e = Para_0["Electrolyte diffusivity [m2.s-1]"]
pybamm.plot(c_e, D_e(c_e, 273.15+40))
sigma_e = Para_0['Electrolyte conductivity [S.m-1]']
pybamm.plot(c_e, sigma_e(c_e, 273.15+40))
pybamm.plot(c_e, sigma_e(c_e, 273.15+25))
pybamm.plot(c_e, sigma_e(c_e, 273.15+5))
# Out:
# <AxesSubplot:>
