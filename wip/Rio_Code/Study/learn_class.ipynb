# %%
import pybamm
Rio_base_BatModel = pybamm.BaseBatteryModel()
Rio_base_Model = pybamm.BaseModel()
Rio_base_SPM = pybamm.lithium_ion.SPM()
Rio_base_DFN = pybamm.lithium_ion.DFN()

# %%
Rio_SPMe = pybamm.lithium_ion.SPMe()

# %%
Rio_base_Model._timescale.evaluate()
dir(Rio_base_Model)
param = pybamm.ParameterValues("Chen2020")

# %%
# param.T_init
dir(param)
#current_with_time = param.evaluate(Rio_base_Model.param.current_with_time)  
print(param.cuent_with_time)
#print(Rio_base_Model.param.current_with_time)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\GitPyBaMM\LRH_409\LRH_409\envPBGEM\PyBaMM-GEM\wip\Rio_Code\Study\learn_class.ipynb Cell 4 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/d%3A/GitPyBaMM/LRH_409/LRH_409/envPBGEM/PyBaMM-GEM/wip/Rio_Code/Study/learn_class.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> dir(param)
#       <a href='vscode-notebook-cell:/d%3A/GitPyBaMM/LRH_409/LRH_409/envPBGEM/PyBaMM-GEM/wip/Rio_Code/Study/learn_class.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> #current_with_time = param.evaluate(Rio_base_Model.param.current_with_time)
# ----> <a href='vscode-notebook-cell:/d%3A/GitPyBaMM/LRH_409/LRH_409/envPBGEM/PyBaMM-GEM/wip/Rio_Code/Study/learn_class.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> print(param.cuent_with_time)
#
# AttributeError: 'ParameterValues' object has no attribute 'cuent_with_time'

# %%
param.process_model(Rio_base_DFN)

# %%
Rio_SPMe.latexify()
# Out:
# \large{\underline{\textbf{Single Particle Model with electrolyte Equations}}}\
# \\\\\ \textbf{Discharge capacity [A.h]}\\\\\frac{d}{d t} Q_{Ah} = \frac{\hat{I
# } \tau}{3600}\\\\Q_{Ah} = 0.0\quad at\; t=0\\\\\\ \textbf{X-averaged negative
# particle concentration}\\\\\frac{\partial}{\partial t} \bar{c}_{s\,n} = \frac{
# \nabla\cdot \left(\frac{D \left(\nabla \bar{c}_{s\,n}\right)}{\hat{D}_{}_{diff
#  n}}\quad 0 < r < 1\\\\\bar{c}_{s\,n} = \int c{}_n\, dxn\quad at\; t=0\\\\\fra
# c{\partial}{\partial r} \bar{c}_{s\,n} = 0.0\quad r = 0\\\\\frac{\partial}{\pa
# rtial r} \bar{c}_{s\,n} = - \frac{0.333333333333333 C_{diff n} I a{}_n \int \h
# at{R}_{}\, dxn}{\frac{D}{\hat{D}_{}_{R\,n} l_{n} \int \epsilon_{s n}\, dxn}\qu
# ad r = 1\\\\\\ \textbf{X-averaged positive particle concentration}\\\\\frac{\p
# artial}{\partial t} \bar{c}_{s\,p} = \frac{\nabla\cdot \left(\frac{D \left(\na
# bla \bar{c}_{s\,p}\right)}{\hat{D}_{}_{diff p}}\quad 0 < r < 1\\\\\bar{c}_{s\,
# ...

# %%
Rio_SPMe.variable_names()
# Out:
# ['Time',
#  'Time [s]',
#  'Time [min]',
#  'Time [h]',
#  'x',
#  'x [m]',
#  'x_n',
#  'x_n [m]',
#  'x_s',
#  'x_s [m]',
#  'x_p',
#  'x_p [m]',
#  'r_p',
#  'r_p [m]',
#  'r_n',
#  'r_n [m]',
#  'Current density variable',
#  'Total current density',
#  'Total current density [A.m-2]',
#  'Current [A]',
#  'C-rate',
#  'Discharge capacity [A.h]',
#  'Porosity',
#  'Separator porosity',
#  'Positive electrode porosity',
#  'X-averaged separator porosity',
#  'X-averaged positive electrode porosity',
#  'Negative electrode porosity',
#  'X-averaged negative electrode porosity',
#  'Leading-order porosity',
#  'Leading-order separator porosity',
#  'Leading-order positive electrode porosity',
#  'Leading-order x-averaged separator porosity',
#  'Leading-order x-averaged positive electrode porosity',
#  'Leading-order negative electrode porosity',
#  'Leading-order x-averaged negative electrode porosity',
#  'Porosity change',
#  'Separator porosity change',
# ...

# %%
ChemistryChen=pybamm.parameter_sets.Chen2020
Para_0=pybamm.ParameterValues(chemistry=ChemistryChen)

# %%
Para_0.process_model(Rio_base_DFN)

# %%
Rio_base_DFN.param.n.b_e.name
# Out:
# 'Negative electrode Bruggeman coefficient (electrolyte)'

# %%
#dir(Rio_base_DFN.param.n.b_e)

# %%
isinstance(Rio_base_BatModel, pybamm.BaseBatteryModel)

isinstance(Rio_base_BatModel, pybamm.BaseModel)

isinstance(Rio_base_DFN, pybamm.lithium_ion.SPM)
# Out:
# False

# %%
dir(Rio_base_DFN)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_algebraic',
#  '_boundary_conditions',
#  '_build_model',
#  '_built',
#  '_built_fundamental_and_external',
#  '_concatenated_algebraic',
#  '_concatenated_initial_conditions',
#  '_concatenated_rhs',
#  '_events',
#  '_find_symbols',
#  '_initial_conditions',
#  '_input_parameters',
#  '_jacobian',
#  '_jacobian_algebraic',
#  '_length_scales',
#  '_mass_matrix',
#  '_mass_matrix_inv',
#  '_name',
#  '_options',
#  '_param',
#  '_parameter_info',
#  '_parameters',
#  '_rhs',
#  '_summary_variables',
#  '_timescale',
#  '_variables',
#  '_variables_casadi',
# ...
