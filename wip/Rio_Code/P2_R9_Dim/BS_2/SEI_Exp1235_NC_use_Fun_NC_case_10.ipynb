# %%
""" 
This script is the baseline for main file to run functions from
GEM-2_Ruihe 
"""
# Load modules
import pybamm as pb;import pandas as pd;import numpy as np;
import os, json,openpyxl,traceback,multiprocessing,scipy.optimize,sys
import matplotlib.pyplot as plt;
import pickle,imageio,timeit,random,time, signal
from scipy.io import savemat,loadmat;
from pybamm import constants,exp;import matplotlib as mpl

# %%
########################     Global settings!!!
rows_per_file = 1;  Scan_end_end = 12  
purpose_i = "SEI_Exp1235_NC" 


# define options:
On_HPC =  False;        Runshort="GEM-2"; Add_Rest = False
Plot_Exp=True;          Timeout=True;     Return_Sol=True;   
Check_Small_Time=True;  R_from_GITT = True
fs = 13; dpi = 100; Re_No =0
Options = [ 
    On_HPC,Runshort,Add_Rest,
    Plot_Exp,Timeout,Return_Sol,
    Check_Small_Time,R_from_GITT,
    dpi,fs]
Timelimit = int(3600*48) # give 48 hours!


if On_HPC:
    i_bundle = int(os.environ["PBS_ARRAY_INDEX"])
else:
    i_bundle = 10; 
Scan_start = (i_bundle-1)*rows_per_file+1;    
Scan_end   = min(Scan_start + rows_per_file-1, Scan_end_end)    
purpose = f"{purpose_i}_Case_{Scan_start}_{Scan_end}"
Target  = f'/{purpose}/'
# interpetation: Simnon suggested, with cracking activation, heat transfer
para_csv = f"Bundle_{i_bundle}.csv"  # name of the random file to get parameters

# Path setting:
if On_HPC:                          # Run on HPC
    Path_csv = f"InputData/{purpose_i}/" 
    Path_Input = "InputData/" 
    BasicPath=os.getcwd() 
    Para_file = Path_csv +  para_csv
else:
    # Add path to system to ensure Fun_P2 can be used
    import sys  
    str_path_0 = os.path.abspath(os.path.join(pb.__path__[0],'..'))
    str_path_1 = os.path.abspath(
        os.path.join(str_path_0,"wip/Rio_Code/Fun_P2"))
    sys.path.append(str_path_1) 
    Path_Input = os.path.expanduser(
        "~/EnvPBGEM_NC/SimSave/InputData/") # for Linux
    BasicPath =  os.path.expanduser(
        "~/EnvPBGEM_NC/SimSave/P2_R9_Dim")
    Para_file = Path_Input+f'{purpose_i}/'+para_csv
# import all functions 
from Fun_NC import * 


# Load input file
Para_dict_list = load_combinations_from_csv(Para_file)
pool_no = len(Para_dict_list) # do parallel computing if needed
# Out:
# Total scan case is 1

# %%
midc_merge_all = [];  Sol_RPT_all = [];  Sol_AGE_all = []
Path_List = [BasicPath, Path_Input,Target,purpose] 
# Run the model
if Re_No == 0:
    midc_merge,Sol_RPT,Sol_AGE,DeBug_Lists = Run_P2_Excel (
        Para_dict_list[0], Path_List, 
        Re_No, Timelimit, Options) 
elif Re_No > 0:
    pass
# Out:
# Start Now! Scan 10 Re 0
# Finish reading Experiment!
# Aging T is 10degC
# Has Overwritten Initial outer SEI thickness [m] to be 7.66e-09 and Negative electrode porosity to be 0.238 to account for initial capacity loss of 0.135 Ah
# Scan 10 Re 0: DryOut = Off
# Scan 10 Re 0: Spent 4.540 s on Initialization
# At t = 367.549, , mxstep steps taken before reaching tout.
# At t = 127.549, , mxstep steps taken before reaching tout.
# At t = 358.353, , mxstep steps taken before reaching tout.
# At t = 118.353, , mxstep steps taken before reaching tout.
# At t = 118.353 and h = 5.04905e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 238.517, , mxstep steps taken before reaching tout.
# At t = 238.517 and h = 3.61507e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 88.5176, , mxstep steps taken before reaching tout.
# At t = 88.5176, , mxstep steps taken before reaching tout.
# At t = 88.5176 and h = 4.69719e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# Succeed to run break in for the 0th time with capacity increase of 0Ah and perturbation of 0.00e+00Ah
#
# Scan 10 Re 0: Finish break-in cycle within 12 minutes, 45 seconds
# Scan 10 Re 0: Finish post-process for break-in cycle within 1 minute, 1 second
# At t = 66.4753, , mxstep steps taken before reaching tout.
# At t = 66.4753, , mxstep steps taken before reaching tout.
# At t = 66.4753, , mxstep steps taken before reaching tout.
# At t = 539.678, , mxstep steps taken before reaching tout.
# At t = 59.6781 and h = 1.0294e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 59.6781, , mxstep steps taken before reaching tout.
# At t = 59.6781, repeated recoverable residual errors.
# At t = 539.237, , mxstep steps taken before reaching tout.
# At t = 59.2369, , mxstep steps taken before reaching tout.
# At t = 59.2369, , mxstep steps taken before reaching tout.
# At t = 59.2369, , mxstep steps taken before reaching tout.
# At t = 538.797, , mxstep steps taken before reaching tout.
# At t = 58.7972, , mxstep steps taken before reaching tout.
# At t = 58.7972, , mxstep steps taken before reaching tout.
# At t = 58.7972, , mxstep steps taken before reaching tout.
# At t = 538.359 and h = 3.8211e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 58.3589, , mxstep steps taken before reaching tout.
# At t = 58.3589, , mxstep steps taken before reaching tout.
# At t = 58.3589 and h = 3.39072e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 537.922, , mxstep steps taken before reaching tout.
# At t = 57.9222 and h = 3.85382e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 57.9222, , mxstep steps taken before reaching tout.
# At t = 57.9222, , mxstep steps taken before reaching tout.
# At t = 537.487 and h = 1.59956e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 57.4869, , mxstep steps taken before reaching tout.
# At t = 57.4868, , mxstep steps taken before reaching tout.
# At t = 57.4868, , mxstep steps taken before reaching tout.
# At t = 537.053 and h = 2.03096e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 57.053, , mxstep steps taken before reaching tout.
# At t = 57.053, , mxstep steps taken before reaching tout.
# At t = 57.053 and h = 1.83262e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 536.621, , mxstep steps taken before reaching tout.
# At t = 56.6207, , mxstep steps taken before reaching tout.
# At t = 56.6207 and h = 8.63823e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 56.6206, , mxstep steps taken before reaching tout.
# At t = 536.19, , mxstep steps taken before reaching tout.
# At t = 56.1896, , mxstep steps taken before reaching tout.
# At t = 56.1896, , mxstep steps taken before reaching tout.
# At t = 56.1896 and h = 1.25718e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 535.76, , mxstep steps taken before reaching tout.
# At t = 55.76, , mxstep steps taken before reaching tout.
# At t = 55.76, , mxstep steps taken before reaching tout.
# At t = 55.76 and h = 7.22296e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 535.332, , mxstep steps taken before reaching tout.
# At t = 55.3318, , mxstep steps taken before reaching tout.
# At t = 55.3318, , mxstep steps taken before reaching tout.
# At t = 55.3318, , mxstep steps taken before reaching tout.
# At t = 534.905, , mxstep steps taken before reaching tout.
# At t = 54.905, , mxstep steps taken before reaching tout.
# At t = 54.905, , mxstep steps taken before reaching tout.
# At t = 54.905, , mxstep steps taken before reaching tout.
# At t = 534.48, , mxstep steps taken before reaching tout.
# At t = 54.4796, , mxstep steps taken before reaching tout.
# At t = 54.4795, , mxstep steps taken before reaching tout.
# At t = 54.4795, , mxstep steps taken before reaching tout.
# At t = 534.056, , mxstep steps taken before reaching tout.
# At t = 54.0555, , mxstep steps taken before reaching tout.
# At t = 54.0555, , mxstep steps taken before reaching tout.
# At t = 54.0555, , mxstep steps taken before reaching tout.
# At t = 533.633, , mxstep steps taken before reaching tout.
# At t = 53.6327 and h = 2.09523e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 53.6327, , mxstep steps taken before reaching tout.
# At t = 53.6327, , mxstep steps taken before reaching tout.
# At t = 533.211, , mxstep steps taken before reaching tout.
# At t = 53.2113, , mxstep steps taken before reaching tout.
# At t = 53.2113, , mxstep steps taken before reaching tout.
# At t = 53.2113, , mxstep steps taken before reaching tout.
# At t = 532.791, , mxstep steps taken before reaching tout.
# At t = 52.7913, , mxstep steps taken before reaching tout.
# At t = 52.7913, , mxstep steps taken before reaching tout.
# At t = 52.7913, , mxstep steps taken before reaching tout.
# At t = 532.372, , mxstep steps taken before reaching tout.
# At t = 52.3724, , mxstep steps taken before reaching tout.
# At t = 52.3724, , mxstep steps taken before reaching tout.
# At t = 52.3724, , mxstep steps taken before reaching tout.
# At t = 531.955 and h = 6.65208e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 51.955, , mxstep steps taken before reaching tout.
# At t = 51.955, , mxstep steps taken before reaching tout.
# At t = 51.955, , mxstep steps taken before reaching tout.
# At t = 531.539, , mxstep steps taken before reaching tout.
# At t = 51.5388, , mxstep steps taken before reaching tout.
# At t = 51.5388, , mxstep steps taken before reaching tout.
# At t = 51.5388, , mxstep steps taken before reaching tout.
# At t = 531.124, , mxstep steps taken before reaching tout.
# At t = 51.1238, , mxstep steps taken before reaching tout.
# At t = 51.1238, , mxstep steps taken before reaching tout.
# At t = 51.1238 and h = 2.54194e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 530.71 and h = 4.41594e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 50.7102, , mxstep steps taken before reaching tout.
# At t = 50.7101, , mxstep steps taken before reaching tout.
# At t = 50.7101 and h = 2.32715e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 530.298, , mxstep steps taken before reaching tout.
# At t = 50.2977, , mxstep steps taken before reaching tout.
# At t = 50.2977, , mxstep steps taken before reaching tout.
# At t = 50.2976, , mxstep steps taken before reaching tout.
# At t = 529.887, , mxstep steps taken before reaching tout.
# At t = 49.8865, , mxstep steps taken before reaching tout.
# At t = 49.8865, , mxstep steps taken before reaching tout.
# At t = 49.8865 and h = 1.72646e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.477, , mxstep steps taken before reaching tout.
# At t = 49.4765, , mxstep steps taken before reaching tout.
# At t = 49.4765, , mxstep steps taken before reaching tout.
# At t = 49.4765, , mxstep steps taken before reaching tout.
# At t = 529.068, , mxstep steps taken before reaching tout.
# At t = 49.0678, , mxstep steps taken before reaching tout.
# At t = 49.0678, , mxstep steps taken before reaching tout.
# At t = 49.0678, , mxstep steps taken before reaching tout.
# At t = 528.66, , mxstep steps taken before reaching tout.
# At t = 528.254, , mxstep steps taken before reaching tout.
# At t = 527.849, , mxstep steps taken before reaching tout.
# At t = 527.445, , mxstep steps taken before reaching tout.
# At t = 527.042, , mxstep steps taken before reaching tout.
# At t = 526.64, , mxstep steps taken before reaching tout.
# At t = 526.24, , mxstep steps taken before reaching tout.
# At t = 525.84, , mxstep steps taken before reaching tout.
# At t = 525.442, , mxstep steps taken before reaching tout.
# At t = 525.045, , mxstep steps taken before reaching tout.
# At t = 524.649, , mxstep steps taken before reaching tout.
# At t = 524.254, , mxstep steps taken before reaching tout.
# At t = 523.86, , mxstep steps taken before reaching tout.
# At t = 523.467, , mxstep steps taken before reaching tout.
# At t = 523.076, , mxstep steps taken before reaching tout.
# At t = 522.685, , mxstep steps taken before reaching tout.
# At t = 522.296, , mxstep steps taken before reaching tout.
# At t = 521.907, , mxstep steps taken before reaching tout.
# At t = 521.52, , mxstep steps taken before reaching tout.
# At t = 521.133 and h = 2.52243e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 520.748, , mxstep steps taken before reaching tout.
# At t = 520.363, , mxstep steps taken before reaching tout.
# At t = 519.98, , mxstep steps taken before reaching tout.
# At t = 519.598, , mxstep steps taken before reaching tout.
# At t = 519.216, , mxstep steps taken before reaching tout.
# At t = 518.836, , mxstep steps taken before reaching tout.
# At t = 518.456, , mxstep steps taken before reaching tout.
# At t = 518.078, , mxstep steps taken before reaching tout.
# At t = 517.7, , mxstep steps taken before reaching tout.
# At t = 517.324, , mxstep steps taken before reaching tout.
# At t = 516.948, , mxstep steps taken before reaching tout.
# At t = 516.573, , mxstep steps taken before reaching tout.
# At t = 516.2, , mxstep steps taken before reaching tout.
# At t = 515.827, , mxstep steps taken before reaching tout.
# At t = 515.455, , mxstep steps taken before reaching tout.
# At t = 515.084, , mxstep steps taken before reaching tout.
# At t = 514.714, , mxstep steps taken before reaching tout.
# At t = 514.345, , mxstep steps taken before reaching tout.
# At t = 513.976, , mxstep steps taken before reaching tout.
# At t = 513.609, , mxstep steps taken before reaching tout.
# At t = 513.243, , mxstep steps taken before reaching tout.
# At t = 512.877, , mxstep steps taken before reaching tout.
# At t = 512.512, , mxstep steps taken before reaching tout.
# At t = 512.148, , mxstep steps taken before reaching tout.
# At t = 511.785, , mxstep steps taken before reaching tout.
# At t = 511.423, , mxstep steps taken before reaching tout.
# At t = 511.062, , mxstep steps taken before reaching tout.
# Succeed to run the ageing set for 77 cycles the 1th time
# Scan 10 Re 0: Finish for No.0 ageing cycles within 8 hours, 47 minutes, 42 seconds
# Scan 10 Re 0: Finish post-process for No.77 ageing cycles within 816.394 ms
# At t = 298.985 and h = 2.95204e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 289.92 and h = 2.35896e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 181.529, , mxstep steps taken before reaching tout.
# At t = 181.529, , mxstep steps taken before reaching tout.
# Succeed to run RPT for the 1th time
# Scan 10 Re 0: Finish for No.77 RPT cycles within 10 minutes, 15 seconds
# Scan 10 Re 0: Finish post-process for No.77 RPT cycles within 13.432 s
# At t = 507.915, , mxstep steps taken before reaching tout.
# At t = 507.558, , mxstep steps taken before reaching tout.
# At t = 507.205, , mxstep steps taken before reaching tout.
# At t = 506.853, , mxstep steps taken before reaching tout.
# At t = 506.502, , mxstep steps taken before reaching tout.
# At t = 506.152, , mxstep steps taken before reaching tout.
# At t = 505.802, , mxstep steps taken before reaching tout.
# At t = 505.453, , mxstep steps taken before reaching tout.
# At t = 505.105, , mxstep steps taken before reaching tout.
# At t = 504.758, , mxstep steps taken before reaching tout.
# At t = 504.411, , mxstep steps taken before reaching tout.
# At t = 504.065, , mxstep steps taken before reaching tout.
# At t = 503.72, , mxstep steps taken before reaching tout.
# At t = 503.376, , mxstep steps taken before reaching tout.
# At t = 503.032, , mxstep steps taken before reaching tout.
# At t = 502.689, , mxstep steps taken before reaching tout.
# At t = 502.347, , mxstep steps taken before reaching tout.
# At t = 502.005, , mxstep steps taken before reaching tout.
# At t = 501.665 and h = 7.26828e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 501.325, , mxstep steps taken before reaching tout.
# At t = 500.985, , mxstep steps taken before reaching tout.
# At t = 500.647, , mxstep steps taken before reaching tout.
# At t = 500.309, , mxstep steps taken before reaching tout.
# At t = 499.971, , mxstep steps taken before reaching tout.
# At t = 499.635, , mxstep steps taken before reaching tout.
# At t = 499.299, , mxstep steps taken before reaching tout.
# At t = 498.964, , mxstep steps taken before reaching tout.
# At t = 498.629, , mxstep steps taken before reaching tout.
# At t = 498.295 and h = 1.4668e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 497.962 and h = 4.14242e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 497.63, , mxstep steps taken before reaching tout.
# At t = 497.298, , mxstep steps taken before reaching tout.
# At t = 496.966, , mxstep steps taken before reaching tout.
# At t = 496.636, , mxstep steps taken before reaching tout.
# At t = 496.306, , mxstep steps taken before reaching tout.
# At t = 495.977 and h = 1.09967e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 495.648, , mxstep steps taken before reaching tout.
# At t = 495.32, , mxstep steps taken before reaching tout.
# At t = 494.993, , mxstep steps taken before reaching tout.
# At t = 494.666, , mxstep steps taken before reaching tout.
# At t = 494.34, , mxstep steps taken before reaching tout.
# At t = 494.014 and h = 4.25381e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 493.69, , mxstep steps taken before reaching tout.
# At t = 493.365, , mxstep steps taken before reaching tout.
# At t = 493.042, , mxstep steps taken before reaching tout.
# At t = 492.719, , mxstep steps taken before reaching tout.
# At t = 492.394, , mxstep steps taken before reaching tout.
# At t = 492.071, , mxstep steps taken before reaching tout.
# At t = 491.753, , mxstep steps taken before reaching tout.
# At t = 491.429, , mxstep steps taken before reaching tout.
# At t = 491.109, , mxstep steps taken before reaching tout.
# At t = 490.79, , mxstep steps taken before reaching tout.
# At t = 490.471, , mxstep steps taken before reaching tout.
# At t = 490.152, , mxstep steps taken before reaching tout.
# At t = 489.835, , mxstep steps taken before reaching tout.
# At t = 489.518, , mxstep steps taken before reaching tout.
# At t = 489.203, , mxstep steps taken before reaching tout.
# At t = 488.885, , mxstep steps taken before reaching tout.
# At t = 488.57, , mxstep steps taken before reaching tout.
# At t = 488.256, , mxstep steps taken before reaching tout.
# At t = 487.941, , mxstep steps taken before reaching tout.
# At t = 487.627 and h = 5.65756e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 487.314 and h = 7.82881e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 487.001, , mxstep steps taken before reaching tout.
# At t = 486.689, , mxstep steps taken before reaching tout.
# At t = 486.378, , mxstep steps taken before reaching tout.
# At t = 486.067, , mxstep steps taken before reaching tout.
# At t = 485.757, , mxstep steps taken before reaching tout.
# At t = 485.447, , mxstep steps taken before reaching tout.
# At t = 485.138 and h = 7.64657e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 484.829, , mxstep steps taken before reaching tout.
# At t = 484.521, , mxstep steps taken before reaching tout.
# At t = 484.213, , mxstep steps taken before reaching tout.
# At t = 483.906, , mxstep steps taken before reaching tout.
# At t = 483.599, , mxstep steps taken before reaching tout.
# At t = 483.293 and h = 7.42721e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# Succeed to run the ageing set for 77 cycles the 1th time
# Scan 10 Re 0: Finish for No.77 ageing cycles within 5 hours, 36 minutes, 25 seconds
# Scan 10 Re 0: Finish post-process for No.154 ageing cycles within 350.383 ms
# At t = 242.688 and h = 1.6552e-13, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 233.758, , mxstep steps taken before reaching tout.
# At t = 233.758, , mxstep steps taken before reaching tout.
# At t = 113.758 and h = 2.33235e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 140.672 and h = 6.80759e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 140.672 and h = 2.79349e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 140.672, , mxstep steps taken before reaching tout.
# Succeed to run RPT for the 1th time
# Scan 10 Re 0: Finish for No.154 RPT cycles within 10 minutes, 18 seconds
# Scan 10 Re 0: Finish post-process for No.154 RPT cycles within 13.308 s
# At t = 480.615, , mxstep steps taken before reaching tout.
# At t = 480.311 and h = 6.24495e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 480.011, , mxstep steps taken before reaching tout.
# At t = 479.71, , mxstep steps taken before reaching tout.
# At t = 239.71, , mxstep steps taken before reaching tout.
# At t = 119.71, , mxstep steps taken before reaching tout.
# At t = 59.7104, , mxstep steps taken before reaching tout.
# At t = 479.411, , mxstep steps taken before reaching tout.
# At t = 239.411, , mxstep steps taken before reaching tout.
# At t = 119.411, , mxstep steps taken before reaching tout.
# At t = 59.4107, , mxstep steps taken before reaching tout.
# At t = 479.111, , mxstep steps taken before reaching tout.
# At t = 239.111, , mxstep steps taken before reaching tout.
# At t = 119.111, , mxstep steps taken before reaching tout.
# At t = 59.1114 and h = 7.00493e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 478.813, , mxstep steps taken before reaching tout.
# At t = 238.813, , mxstep steps taken before reaching tout.
# At t = 118.813 and h = 2.64678e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 58.8128, , mxstep steps taken before reaching tout.
# At t = 478.515, , mxstep steps taken before reaching tout.
# At t = 238.515, , mxstep steps taken before reaching tout.
# At t = 118.515 and h = 9.30312e-16, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 58.5146, , mxstep steps taken before reaching tout.
# At t = 478.217, , mxstep steps taken before reaching tout.
# At t = 238.217 and h = 7.24108e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 118.217, , mxstep steps taken before reaching tout.
# At t = 58.2168 and h = 4.12724e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 477.92, , mxstep steps taken before reaching tout.
# At t = 237.92, , mxstep steps taken before reaching tout.
# At t = 117.92, , mxstep steps taken before reaching tout.
# At t = 57.9197, , mxstep steps taken before reaching tout.
# At t = 477.623, , mxstep steps taken before reaching tout.
# At t = 237.623, , mxstep steps taken before reaching tout.
# At t = 117.623, , mxstep steps taken before reaching tout.
# At t = 57.6228, , mxstep steps taken before reaching tout.
# At t = 477.327, , mxstep steps taken before reaching tout.
# At t = 237.327 and h = 1.16386e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 117.327 and h = 2.91261e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 57.3266 and h = 1.93413e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 477.031, , mxstep steps taken before reaching tout.
# At t = 237.031, , mxstep steps taken before reaching tout.
# At t = 117.031, , mxstep steps taken before reaching tout.
# At t = 57.0308, , mxstep steps taken before reaching tout.
# At t = 476.736, , mxstep steps taken before reaching tout.
# At t = 236.736, , mxstep steps taken before reaching tout.
# At t = 116.736, , mxstep steps taken before reaching tout.
# At t = 56.7355, , mxstep steps taken before reaching tout.
# At t = 476.441, , mxstep steps taken before reaching tout.
# At t = 236.441, , mxstep steps taken before reaching tout.
# At t = 116.44, , mxstep steps taken before reaching tout.
# At t = 56.4405, , mxstep steps taken before reaching tout.
# At t = 476.146, , mxstep steps taken before reaching tout.
# At t = 236.146, , mxstep steps taken before reaching tout.
# At t = 116.146, , mxstep steps taken before reaching tout.
# At t = 56.1461, , mxstep steps taken before reaching tout.
# At t = 475.852, , mxstep steps taken before reaching tout.
# At t = 235.852, , mxstep steps taken before reaching tout.
# At t = 115.852, , mxstep steps taken before reaching tout.
# At t = 55.8522, , mxstep steps taken before reaching tout.
# At t = 475.559, , mxstep steps taken before reaching tout.
# At t = 235.559, , mxstep steps taken before reaching tout.
# At t = 115.559, , mxstep steps taken before reaching tout.
# At t = 55.5588, , mxstep steps taken before reaching tout.
# At t = 475.266, , mxstep steps taken before reaching tout.
# At t = 235.266, , mxstep steps taken before reaching tout.
# At t = 115.266, , mxstep steps taken before reaching tout.
# At t = 55.2658, , mxstep steps taken before reaching tout.
# At t = 474.973, , mxstep steps taken before reaching tout.
# At t = 234.973 and h = 4.36777e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 114.973, , mxstep steps taken before reaching tout.
# At t = 54.9734, , mxstep steps taken before reaching tout.
# At t = 474.681 and h = 1.7731e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 234.681, , mxstep steps taken before reaching tout.
# At t = 114.681 and h = 4.69489e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 54.6811, , mxstep steps taken before reaching tout.
# At t = 474.39, , mxstep steps taken before reaching tout.
# At t = 234.39, , mxstep steps taken before reaching tout.
# At t = 114.39, repeated recoverable residual errors.
# At t = 54.3898 and h = 6.4211e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 474.098 and h = 3.86885e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 234.098, , mxstep steps taken before reaching tout.
# At t = 114.098, , mxstep steps taken before reaching tout.
# At t = 54.0984, , mxstep steps taken before reaching tout.
# At t = 473.808 and h = 1.15593e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 233.808 and h = 3.91376e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 113.808, , mxstep steps taken before reaching tout.
# At t = 53.8078, , mxstep steps taken before reaching tout.
# At t = 473.518, , mxstep steps taken before reaching tout.
# At t = 233.517, , mxstep steps taken before reaching tout.
# At t = 113.518, , mxstep steps taken before reaching tout.
# At t = 53.5175, , mxstep steps taken before reaching tout.
# At t = 473.228, , mxstep steps taken before reaching tout.
# At t = 233.228, , mxstep steps taken before reaching tout.
# At t = 113.228, , mxstep steps taken before reaching tout.
# At t = 53.2277 and h = 3.42666e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 472.938, , mxstep steps taken before reaching tout.
# At t = 232.938, , mxstep steps taken before reaching tout.
# At t = 112.938 and h = 1.88502e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 52.9383 and h = 4.36579e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 472.649, , mxstep steps taken before reaching tout.
# At t = 232.649, , mxstep steps taken before reaching tout.
# At t = 112.649, , mxstep steps taken before reaching tout.
# At t = 52.6495, , mxstep steps taken before reaching tout.
# At t = 472.361, , mxstep steps taken before reaching tout.
# At t = 232.361, , mxstep steps taken before reaching tout.
# At t = 112.361, , mxstep steps taken before reaching tout.
# At t = 52.3611, , mxstep steps taken before reaching tout.
# At t = 472.073, , mxstep steps taken before reaching tout.
# At t = 232.073 and h = 6.38537e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 112.073, , mxstep steps taken before reaching tout.
# At t = 52.073, , mxstep steps taken before reaching tout.
# At t = 471.785, , mxstep steps taken before reaching tout.
# At t = 231.785, , mxstep steps taken before reaching tout.
# At t = 111.785, , mxstep steps taken before reaching tout.
# At t = 51.7855, , mxstep steps taken before reaching tout.
# At t = 471.498, , mxstep steps taken before reaching tout.
# At t = 231.498, , mxstep steps taken before reaching tout.
# At t = 111.498, , mxstep steps taken before reaching tout.
# At t = 51.4982, , mxstep steps taken before reaching tout.
# At t = 471.212, , mxstep steps taken before reaching tout.
# At t = 231.212, , mxstep steps taken before reaching tout.
# At t = 111.212, , mxstep steps taken before reaching tout.
# At t = 51.2115 and h = 1.59258e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 470.925, , mxstep steps taken before reaching tout.
# At t = 230.925, , mxstep steps taken before reaching tout.
# At t = 110.925, , mxstep steps taken before reaching tout.
# At t = 50.9253, , mxstep steps taken before reaching tout.
# At t = 470.639, , mxstep steps taken before reaching tout.
# At t = 230.639, , mxstep steps taken before reaching tout.
# At t = 110.639, , mxstep steps taken before reaching tout.
# At t = 50.6394, , mxstep steps taken before reaching tout.
# At t = 470.354 and h = 2.42608e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 230.354, , mxstep steps taken before reaching tout.
# At t = 110.354, , mxstep steps taken before reaching tout.
# At t = 50.354, , mxstep steps taken before reaching tout.
# At t = 470.069, , mxstep steps taken before reaching tout.
# At t = 230.069, , mxstep steps taken before reaching tout.
# At t = 110.069, , mxstep steps taken before reaching tout.
# At t = 50.0691 and h = 2.08348e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 469.785, , mxstep steps taken before reaching tout.
# At t = 229.785, , mxstep steps taken before reaching tout.
# At t = 109.785, , mxstep steps taken before reaching tout.
# At t = 49.7845, , mxstep steps taken before reaching tout.
# At t = 469.5, , mxstep steps taken before reaching tout.
# At t = 229.5 and h = 2.11386e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 109.5, repeated recoverable residual errors.
# At t = 49.5005, , mxstep steps taken before reaching tout.
# At t = 469.217, , mxstep steps taken before reaching tout.
# At t = 229.217 and h = 4.71719e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 109.217, , mxstep steps taken before reaching tout.
# At t = 49.2167 and h = 1.41672e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 468.933, , mxstep steps taken before reaching tout.
# At t = 228.933, , mxstep steps taken before reaching tout.
# At t = 108.933, , mxstep steps taken before reaching tout.
# At t = 48.9335, , mxstep steps taken before reaching tout.
# At t = 468.651 and h = 1.41318e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 228.651 and h = 7.23371e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 108.651, , mxstep steps taken before reaching tout.
# At t = 48.6506, , mxstep steps taken before reaching tout.
# At t = 468.368, , mxstep steps taken before reaching tout.
# At t = 228.368, , mxstep steps taken before reaching tout.
# At t = 108.368, , mxstep steps taken before reaching tout.
# At t = 48.3682, , mxstep steps taken before reaching tout.
# At t = 468.086, , mxstep steps taken before reaching tout.
# At t = 228.086, , mxstep steps taken before reaching tout.
# At t = 108.086, , mxstep steps taken before reaching tout.
# At t = 467.805, , mxstep steps taken before reaching tout.
# At t = 227.805, , mxstep steps taken before reaching tout.
# At t = 107.805, , mxstep steps taken before reaching tout.
# At t = 467.523, , mxstep steps taken before reaching tout.
# At t = 227.523, , mxstep steps taken before reaching tout.
# At t = 107.523, , mxstep steps taken before reaching tout.
# At t = 467.243, , mxstep steps taken before reaching tout.
# At t = 227.243, , mxstep steps taken before reaching tout.
# At t = 107.243, , mxstep steps taken before reaching tout.
# At t = 466.962, , mxstep steps taken before reaching tout.
# At t = 226.962, , mxstep steps taken before reaching tout.
# At t = 106.962, , mxstep steps taken before reaching tout.
# At t = 466.683, , mxstep steps taken before reaching tout.
# At t = 226.682, , mxstep steps taken before reaching tout.
# At t = 106.683, , mxstep steps taken before reaching tout.
# At t = 466.403, , mxstep steps taken before reaching tout.
# At t = 226.403, , mxstep steps taken before reaching tout.
# At t = 106.403, , mxstep steps taken before reaching tout.
# At t = 466.124, , mxstep steps taken before reaching tout.
# At t = 226.124, , mxstep steps taken before reaching tout.
# At t = 106.124, , mxstep steps taken before reaching tout.
# At t = 465.845, , mxstep steps taken before reaching tout.
# At t = 225.845, , mxstep steps taken before reaching tout.
# At t = 105.845, , mxstep steps taken before reaching tout.
# At t = 465.567, , mxstep steps taken before reaching tout.
# At t = 225.567, , mxstep steps taken before reaching tout.
# At t = 105.567, , mxstep steps taken before reaching tout.
# At t = 465.289 and h = 1.16472e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 225.289, , mxstep steps taken before reaching tout.
# At t = 105.289, , mxstep steps taken before reaching tout.
# At t = 465.012, , mxstep steps taken before reaching tout.
# At t = 225.012, , mxstep steps taken before reaching tout.
# At t = 105.012, , mxstep steps taken before reaching tout.
# At t = 464.735, , mxstep steps taken before reaching tout.
# At t = 224.735, , mxstep steps taken before reaching tout.
# At t = 104.735, , mxstep steps taken before reaching tout.
# At t = 464.458 and h = 1.1846e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 224.458, , mxstep steps taken before reaching tout.
# At t = 104.458, , mxstep steps taken before reaching tout.
# At t = 464.182, , mxstep steps taken before reaching tout.
# At t = 224.182 and h = 1.38808e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 104.182, , mxstep steps taken before reaching tout.
# At t = 463.906, , mxstep steps taken before reaching tout.
# At t = 223.906, , mxstep steps taken before reaching tout.
# At t = 103.906, , mxstep steps taken before reaching tout.
# At t = 463.63, , mxstep steps taken before reaching tout.
# At t = 223.63, , mxstep steps taken before reaching tout.
# At t = 103.63 and h = 7.27231e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 463.355, , mxstep steps taken before reaching tout.
# At t = 223.355, , mxstep steps taken before reaching tout.
# At t = 103.355, , mxstep steps taken before reaching tout.
# At t = 463.081, , mxstep steps taken before reaching tout.
# At t = 223.081, , mxstep steps taken before reaching tout.
# At t = 103.081, , mxstep steps taken before reaching tout.
# At t = 462.806, repeated recoverable residual errors.
# At t = 222.806, , mxstep steps taken before reaching tout.
# At t = 102.806, , mxstep steps taken before reaching tout.
# At t = 462.533, , mxstep steps taken before reaching tout.
# At t = 222.533, , mxstep steps taken before reaching tout.
# At t = 102.533, , mxstep steps taken before reaching tout.
# At t = 462.259, , mxstep steps taken before reaching tout.
# At t = 222.259, , mxstep steps taken before reaching tout.
# At t = 102.259, , mxstep steps taken before reaching tout.
# At t = 461.986, , mxstep steps taken before reaching tout.
# At t = 221.986, , mxstep steps taken before reaching tout.
# At t = 101.986, , mxstep steps taken before reaching tout.
# At t = 461.713, , mxstep steps taken before reaching tout.
# At t = 221.713, , mxstep steps taken before reaching tout.
# At t = 101.713, , mxstep steps taken before reaching tout.
# At t = 461.441, , mxstep steps taken before reaching tout.
# At t = 221.441, , mxstep steps taken before reaching tout.
# At t = 101.441, , mxstep steps taken before reaching tout.
# At t = 461.169, , mxstep steps taken before reaching tout.
# At t = 221.169, , mxstep steps taken before reaching tout.
# At t = 101.169, , mxstep steps taken before reaching tout.
# At t = 460.898, , mxstep steps taken before reaching tout.
# At t = 220.898, , mxstep steps taken before reaching tout.
# At t = 100.898, , mxstep steps taken before reaching tout.
# At t = 460.626 and h = 1.64805e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 220.626 and h = 8.88313e-16, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 100.626, , mxstep steps taken before reaching tout.
# At t = 460.356 and h = 9.69753e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 220.356, , mxstep steps taken before reaching tout.
# At t = 100.356, , mxstep steps taken before reaching tout.
# At t = 460.085 and h = 7.19326e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 220.085, , mxstep steps taken before reaching tout.
# At t = 100.085, , mxstep steps taken before reaching tout.
# At t = 459.815, , mxstep steps taken before reaching tout.
# At t = 219.815, , mxstep steps taken before reaching tout.
# At t = 99.8153, , mxstep steps taken before reaching tout.
# At t = 459.546, , mxstep steps taken before reaching tout.
# At t = 219.546, , mxstep steps taken before reaching tout.
# At t = 99.5457, , mxstep steps taken before reaching tout.
# At t = 459.276, , mxstep steps taken before reaching tout.
# At t = 219.276, , mxstep steps taken before reaching tout.
# At t = 99.2764, , mxstep steps taken before reaching tout.
# Succeed to run the ageing set for 77 cycles the 1th time
# Scan 10 Re 0: Finish for No.154 ageing cycles within 13 hours, 14 minutes, 46 seconds
# Scan 10 Re 0: Finish post-process for No.231 ageing cycles within 406.817 ms
# At t = 454.652 and h = 2.23743e-13, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 193.827, , mxstep steps taken before reaching tout.
# At t = 193.827 and h = 7.56867e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185.008 and h = 1.49648e-13, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185.008 and h = 9.53111e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 126.201 and h = 2.49524e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 126.201 and h = 3.26978e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 126.201, , mxstep steps taken before reaching tout.
# Succeed to run RPT for the 1th time
# Scan 10 Re 0: Finish for No.231 RPT cycles within 11 minutes, 19 seconds
# Scan 10 Re 0: Finish post-process for No.231 RPT cycles within 15.102 s
# At t = 522.896, , mxstep steps taken before reaching tout.
# At t = 456.917, , mxstep steps taken before reaching tout.
# At t = 216.917, , mxstep steps taken before reaching tout.
# At t = 96.917, , mxstep steps taken before reaching tout.
# At t = 456.647, , mxstep steps taken before reaching tout.
# At t = 216.647, , mxstep steps taken before reaching tout.
# At t = 96.6474 and h = 1.34869e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 456.382, , mxstep steps taken before reaching tout.
# At t = 216.382, , mxstep steps taken before reaching tout.
# At t = 96.382, , mxstep steps taken before reaching tout.
# At t = 456.117, , mxstep steps taken before reaching tout.
# At t = 216.117, , mxstep steps taken before reaching tout.
# At t = 96.1171 and h = 1.05763e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 455.852, , mxstep steps taken before reaching tout.
# At t = 215.852, , mxstep steps taken before reaching tout.
# At t = 95.8524, , mxstep steps taken before reaching tout.
# At t = 455.588 and h = 2.20315e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 215.588, , mxstep steps taken before reaching tout.
# At t = 95.5882, , mxstep steps taken before reaching tout.
# At t = 455.324, , mxstep steps taken before reaching tout.
# At t = 215.324, , mxstep steps taken before reaching tout.
# At t = 95.3242, , mxstep steps taken before reaching tout.
# At t = 455.061, , mxstep steps taken before reaching tout.
# At t = 215.061 and h = 1.72417e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 95.0605, , mxstep steps taken before reaching tout.
# At t = 454.797, , mxstep steps taken before reaching tout.
# At t = 214.797, , mxstep steps taken before reaching tout.
# At t = 94.7974, , mxstep steps taken before reaching tout.
# At t = 454.534, , mxstep steps taken before reaching tout.
# At t = 214.534, , mxstep steps taken before reaching tout.
# At t = 94.5344, , mxstep steps taken before reaching tout.
# At t = 454.272, , mxstep steps taken before reaching tout.
# At t = 214.272, , mxstep steps taken before reaching tout.
# At t = 94.2719, , mxstep steps taken before reaching tout.
# At t = 454.01, , mxstep steps taken before reaching tout.
# At t = 214.01, , mxstep steps taken before reaching tout.
# At t = 94.0098, , mxstep steps taken before reaching tout.
# At t = 453.748, , mxstep steps taken before reaching tout.
# At t = 213.748, , mxstep steps taken before reaching tout.
# At t = 93.7479, , mxstep steps taken before reaching tout.
# At t = 453.486, , mxstep steps taken before reaching tout.
# At t = 213.486, , mxstep steps taken before reaching tout.
# At t = 93.4865, , mxstep steps taken before reaching tout.
# At t = 453.225, , mxstep steps taken before reaching tout.
# At t = 213.225, , mxstep steps taken before reaching tout.
# At t = 93.2253, , mxstep steps taken before reaching tout.
# At t = 452.964, , mxstep steps taken before reaching tout.
# At t = 212.964, , mxstep steps taken before reaching tout.
# At t = 92.9645 and h = 1.63809e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 452.704, , mxstep steps taken before reaching tout.
# At t = 212.704, , mxstep steps taken before reaching tout.
# At t = 92.7039, , mxstep steps taken before reaching tout.
# At t = 452.444, , mxstep steps taken before reaching tout.
# At t = 212.444 and h = 3.55353e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 92.4439, , mxstep steps taken before reaching tout.
# At t = 452.184 and h = 8.26945e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 212.184, , mxstep steps taken before reaching tout.
# At t = 92.184 and h = 6.70122e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 451.925, , mxstep steps taken before reaching tout.
# At t = 211.925, , mxstep steps taken before reaching tout.
# At t = 91.9245, , mxstep steps taken before reaching tout.
# At t = 451.665, , mxstep steps taken before reaching tout.
# At t = 211.665, , mxstep steps taken before reaching tout.
# At t = 91.6654, , mxstep steps taken before reaching tout.
# At t = 451.407, , mxstep steps taken before reaching tout.
# At t = 211.407, , mxstep steps taken before reaching tout.
# At t = 91.4066, , mxstep steps taken before reaching tout.
# At t = 451.148 and h = 3.89882e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 211.148, , mxstep steps taken before reaching tout.
# At t = 91.148, , mxstep steps taken before reaching tout.
# At t = 450.89, , mxstep steps taken before reaching tout.
# At t = 210.89, , mxstep steps taken before reaching tout.
# At t = 90.8899, , mxstep steps taken before reaching tout.
# At t = 450.632, , mxstep steps taken before reaching tout.
# At t = 210.632 and h = 1.24002e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 90.6321, , mxstep steps taken before reaching tout.
# At t = 450.375, , mxstep steps taken before reaching tout.
# At t = 210.375, , mxstep steps taken before reaching tout.
# At t = 90.3746, , mxstep steps taken before reaching tout.
# At t = 450.118 and h = 9.55056e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 210.118 and h = 1.83531e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 90.1175, , mxstep steps taken before reaching tout.
# At t = 449.861, , mxstep steps taken before reaching tout.
# At t = 209.861, , mxstep steps taken before reaching tout.
# At t = 89.8606, , mxstep steps taken before reaching tout.
# At t = 449.604, , mxstep steps taken before reaching tout.
# At t = 209.604, , mxstep steps taken before reaching tout.
# At t = 89.6042, , mxstep steps taken before reaching tout.
# At t = 449.348, , mxstep steps taken before reaching tout.
# At t = 209.348, , mxstep steps taken before reaching tout.
# At t = 89.3479, , mxstep steps taken before reaching tout.
# At t = 449.092, , mxstep steps taken before reaching tout.
# At t = 209.092, , mxstep steps taken before reaching tout.
# At t = 89.0921, , mxstep steps taken before reaching tout.
# At t = 448.837, , mxstep steps taken before reaching tout.
# At t = 208.837, repeated recoverable residual errors.
# At t = 88.8365, , mxstep steps taken before reaching tout.
# At t = 448.581, , mxstep steps taken before reaching tout.
# At t = 208.581, , mxstep steps taken before reaching tout.
# At t = 88.5813, , mxstep steps taken before reaching tout.
# At t = 448.326, , mxstep steps taken before reaching tout.
# At t = 208.326, , mxstep steps taken before reaching tout.
# At t = 88.3264, , mxstep steps taken before reaching tout.
# At t = 448.072, , mxstep steps taken before reaching tout.
# At t = 208.072, , mxstep steps taken before reaching tout.
# At t = 88.0718, , mxstep steps taken before reaching tout.
# At t = 447.818, , mxstep steps taken before reaching tout.
# At t = 207.818, , mxstep steps taken before reaching tout.
# At t = 87.8176 and h = 3.99344e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 447.564, , mxstep steps taken before reaching tout.
# At t = 207.564, , mxstep steps taken before reaching tout.
# At t = 87.5636, , mxstep steps taken before reaching tout.
# At t = 447.31, , mxstep steps taken before reaching tout.
# At t = 207.31, , mxstep steps taken before reaching tout.
# At t = 87.31, , mxstep steps taken before reaching tout.
# At t = 447.057, , mxstep steps taken before reaching tout.
# At t = 207.057, , mxstep steps taken before reaching tout.
# At t = 87.0566, , mxstep steps taken before reaching tout.
# At t = 446.804, , mxstep steps taken before reaching tout.
# At t = 206.804 and h = 2.42539e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 86.8036 and h = 3.77265e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 446.551, , mxstep steps taken before reaching tout.
# At t = 206.551, , mxstep steps taken before reaching tout.
# At t = 86.5509, , mxstep steps taken before reaching tout.
# At t = 446.298, , mxstep steps taken before reaching tout.
# At t = 206.298, , mxstep steps taken before reaching tout.
# At t = 86.2984, , mxstep steps taken before reaching tout.
# At t = 446.046, , mxstep steps taken before reaching tout.
# At t = 206.046, , mxstep steps taken before reaching tout.
# At t = 86.0464, , mxstep steps taken before reaching tout.
# At t = 445.795, , mxstep steps taken before reaching tout.
# At t = 205.794, , mxstep steps taken before reaching tout.
# At t = 85.7945, , mxstep steps taken before reaching tout.
# At t = 445.543, , mxstep steps taken before reaching tout.
# At t = 205.543, , mxstep steps taken before reaching tout.
# At t = 85.5431, , mxstep steps taken before reaching tout.
# At t = 445.292 and h = 5.96002e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 205.292, , mxstep steps taken before reaching tout.
# At t = 85.2919, , mxstep steps taken before reaching tout.
# At t = 445.041, , mxstep steps taken before reaching tout.
# At t = 205.041, , mxstep steps taken before reaching tout.
# At t = 85.041 and h = 2.69103e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 444.79, , mxstep steps taken before reaching tout.
# At t = 204.791, , mxstep steps taken before reaching tout.
# At t = 84.7905 and h = 9.62966e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 444.54, , mxstep steps taken before reaching tout.
# At t = 204.54, , mxstep steps taken before reaching tout.
# At t = 84.5401 and h = 1.69522e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 444.29, , mxstep steps taken before reaching tout.
# At t = 204.29, , mxstep steps taken before reaching tout.
# At t = 84.2902, , mxstep steps taken before reaching tout.
# At t = 444.041, , mxstep steps taken before reaching tout.
# At t = 204.041, , mxstep steps taken before reaching tout.
# At t = 84.0405, , mxstep steps taken before reaching tout.
# At t = 443.791, , mxstep steps taken before reaching tout.
# At t = 203.791, , mxstep steps taken before reaching tout.
# At t = 83.7911, , mxstep steps taken before reaching tout.
# At t = 443.542, , mxstep steps taken before reaching tout.
# At t = 203.542, , mxstep steps taken before reaching tout.
# At t = 83.542, , mxstep steps taken before reaching tout.
# At t = 443.293, , mxstep steps taken before reaching tout.
# At t = 203.293 and h = 8.70931e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 83.2932, , mxstep steps taken before reaching tout.
# At t = 443.045, , mxstep steps taken before reaching tout.
# At t = 203.045 and h = 2.33138e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 83.0448, , mxstep steps taken before reaching tout.
# At t = 442.797, , mxstep steps taken before reaching tout.
# At t = 202.797, , mxstep steps taken before reaching tout.
# At t = 82.7965, , mxstep steps taken before reaching tout.
# At t = 442.549 and h = 3.18118e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 202.549, , mxstep steps taken before reaching tout.
# At t = 82.5486, , mxstep steps taken before reaching tout.
# At t = 442.301 and h = 8.94379e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 202.301, , mxstep steps taken before reaching tout.
# At t = 82.301, , mxstep steps taken before reaching tout.
# At t = 442.054, , mxstep steps taken before reaching tout.
# At t = 202.054, , mxstep steps taken before reaching tout.
# At t = 82.0537, , mxstep steps taken before reaching tout.
# At t = 441.807, , mxstep steps taken before reaching tout.
# At t = 201.807, , mxstep steps taken before reaching tout.
# At t = 81.8067, , mxstep steps taken before reaching tout.
# At t = 441.56 and h = 1.61922e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 201.56, , mxstep steps taken before reaching tout.
# At t = 81.5599, , mxstep steps taken before reaching tout.
# At t = 441.314, , mxstep steps taken before reaching tout.
# At t = 201.313, , mxstep steps taken before reaching tout.
# At t = 81.3135, , mxstep steps taken before reaching tout.
# At t = 441.067 and h = 2.75353e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 201.067 and h = 1.08609e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 81.0673, , mxstep steps taken before reaching tout.
# At t = 440.822, , mxstep steps taken before reaching tout.
# At t = 200.822, , mxstep steps taken before reaching tout.
# At t = 80.8216, , mxstep steps taken before reaching tout.
# ...
# At t = 52.4627, , mxstep steps taken before reaching tout.
# At t = 52.4627, , mxstep steps taken before reaching tout.
# At t = 292.322 and h = 1.35084e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 52.3216, , mxstep steps taken before reaching tout.
# At t = 52.3215, , mxstep steps taken before reaching tout.
# At t = 52.3215 and h = 4.40129e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 292.181, , mxstep steps taken before reaching tout.
# At t = 52.1809, , mxstep steps taken before reaching tout.
# At t = 52.1809, , mxstep steps taken before reaching tout.
# At t = 52.1809, , mxstep steps taken before reaching tout.
# At t = 292.041, , mxstep steps taken before reaching tout.
# At t = 52.0408, , mxstep steps taken before reaching tout.
# At t = 52.0408, , mxstep steps taken before reaching tout.
# At t = 52.0408, , mxstep steps taken before reaching tout.
# At t = 291.901, , mxstep steps taken before reaching tout.
# At t = 51.9009, , mxstep steps taken before reaching tout.
# At t = 51.9009, , mxstep steps taken before reaching tout.
# At t = 51.9009, , mxstep steps taken before reaching tout.
# At t = 291.761 and h = 7.7599e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 51.7607, , mxstep steps taken before reaching tout.
# At t = 51.7607, , mxstep steps taken before reaching tout.
# At t = 51.7607, , mxstep steps taken before reaching tout.
# At t = 291.621 and h = 1.78717e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 51.6208, , mxstep steps taken before reaching tout.
# At t = 51.6208, , mxstep steps taken before reaching tout.
# At t = 51.6208 and h = 1.68317e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 291.481, , mxstep steps taken before reaching tout.
# At t = 51.481, , mxstep steps taken before reaching tout.
# At t = 51.481, , mxstep steps taken before reaching tout.
# At t = 51.481, , mxstep steps taken before reaching tout.
# At t = 291.341 and h = 2.23204e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 51.3411, , mxstep steps taken before reaching tout.
# At t = 51.3411, , mxstep steps taken before reaching tout.
# At t = 51.3412, , mxstep steps taken before reaching tout.
# At t = 291.201, , mxstep steps taken before reaching tout.
# At t = 51.2007, , mxstep steps taken before reaching tout.
# At t = 51.2007, , mxstep steps taken before reaching tout.
# At t = 51.2007, , mxstep steps taken before reaching tout.
# At t = 291.061, , mxstep steps taken before reaching tout.
# At t = 51.061 and h = 8.14128e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 51.061, , mxstep steps taken before reaching tout.
# At t = 51.061, , mxstep steps taken before reaching tout.
# At t = 290.922, , mxstep steps taken before reaching tout.
# At t = 50.922, , mxstep steps taken before reaching tout.
# At t = 50.922, , mxstep steps taken before reaching tout.
# At t = 50.9221, , mxstep steps taken before reaching tout.
# At t = 290.782, , mxstep steps taken before reaching tout.
# At t = 50.7822 and h = 1.17432e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 50.7822, , mxstep steps taken before reaching tout.
# At t = 50.7822, , mxstep steps taken before reaching tout.
# At t = 290.642, , mxstep steps taken before reaching tout.
# At t = 50.6425, , mxstep steps taken before reaching tout.
# At t = 50.6425, , mxstep steps taken before reaching tout.
# At t = 50.6425, , mxstep steps taken before reaching tout.
# At t = 290.503, , mxstep steps taken before reaching tout.
# At t = 50.5033, , mxstep steps taken before reaching tout.
# At t = 50.5033, , mxstep steps taken before reaching tout.
# At t = 50.5033, , mxstep steps taken before reaching tout.
# At t = 290.364, , mxstep steps taken before reaching tout.
# At t = 50.3637, , mxstep steps taken before reaching tout.
# At t = 50.3637, , mxstep steps taken before reaching tout.
# At t = 50.3637, , mxstep steps taken before reaching tout.
# At t = 290.224, , mxstep steps taken before reaching tout.
# At t = 50.2244, , mxstep steps taken before reaching tout.
# At t = 50.2244 and h = 1.53844e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 50.2244, , mxstep steps taken before reaching tout.
# At t = 290.085, , mxstep steps taken before reaching tout.
# At t = 50.0853 and h = 1.02887e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 50.0853, , mxstep steps taken before reaching tout.
# At t = 50.0853, , mxstep steps taken before reaching tout.
# At t = 289.946 and h = 1.38707e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 49.9464 and h = 7.13554e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 49.9464 and h = 7.60884e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 49.9464 and h = 5.33066e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 289.807, , mxstep steps taken before reaching tout.
# At t = 49.8069, , mxstep steps taken before reaching tout.
# At t = 49.8069, , mxstep steps taken before reaching tout.
# At t = 49.8069, , mxstep steps taken before reaching tout.
# At t = 289.668, , mxstep steps taken before reaching tout.
# At t = 49.6682, , mxstep steps taken before reaching tout.
# At t = 49.6682, , mxstep steps taken before reaching tout.
# At t = 49.6683, , mxstep steps taken before reaching tout.
# At t = 289.529, , mxstep steps taken before reaching tout.
# At t = 49.5289, , mxstep steps taken before reaching tout.
# At t = 49.5289 and h = 9.76895e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 49.5289, , mxstep steps taken before reaching tout.
# At t = 289.39, , mxstep steps taken before reaching tout.
# At t = 49.3901 and h = 3.49103e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 49.3901, , mxstep steps taken before reaching tout.
# At t = 49.3902, , mxstep steps taken before reaching tout.
# At t = 289.251, , mxstep steps taken before reaching tout.
# At t = 49.251, , mxstep steps taken before reaching tout.
# At t = 49.251, , mxstep steps taken before reaching tout.
# At t = 49.251, , mxstep steps taken before reaching tout.
# At t = 289.113, , mxstep steps taken before reaching tout.
# At t = 49.1132, , mxstep steps taken before reaching tout.
# At t = 49.1132, , mxstep steps taken before reaching tout.
# At t = 49.1132 and h = 2.3162e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# Succeed to run the ageing set for 77 cycles the 1th time
# Scan 10 Re 0: Finish for No.1001 ageing cycles within 13 hours, 7 minutes, 30 seconds
# Scan 10 Re 0: Finish post-process for No.1078 ageing cycles within 367.842 ms
# At t = 380.17, , mxstep steps taken before reaching tout.
# At t = 140.17 and h = 2.91612e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 373.012, , mxstep steps taken before reaching tout.
# At t = 133.012 and h = 9.51161e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 285.718, , mxstep steps taken before reaching tout.
# At t = 285.718, , mxstep steps taken before reaching tout.
# At t = 135.718, , mxstep steps taken before reaching tout.
# At t = 135.718 and h = 1.10629e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 135.718 and h = 4.04067e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 120.29, , mxstep steps taken before reaching tout.
# At t = 120.29, , mxstep steps taken before reaching tout.
# At t = 120.29, , mxstep steps taken before reaching tout.
# At t = 85.0128 and h = 1.32661e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 85.0128, , mxstep steps taken before reaching tout.
# At t = 85.0128, , mxstep steps taken before reaching tout.
# Succeed to run RPT for the 1th time
# Scan 10 Re 0: Finish for No.1078 RPT cycles within 22 minutes, 12 seconds
# Scan 10 Re 0: Finish post-process for No.1078 RPT cycles within 12.483 s
# At t = 354.718, , mxstep steps taken before reaching tout.
# At t = 114.718 and h = 1.47645e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 114.718, , mxstep steps taken before reaching tout.
# At t = 54.7185, , mxstep steps taken before reaching tout.
# At t = 287.911, , mxstep steps taken before reaching tout.
# At t = 47.9106, , mxstep steps taken before reaching tout.
# At t = 47.9106, , mxstep steps taken before reaching tout.
# At t = 47.9106, , mxstep steps taken before reaching tout.
# At t = 287.765, , mxstep steps taken before reaching tout.
# At t = 47.7654, , mxstep steps taken before reaching tout.
# At t = 47.7654, , mxstep steps taken before reaching tout.
# At t = 47.7653, , mxstep steps taken before reaching tout.
# At t = 287.628 and h = 6.66199e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 47.6278, , mxstep steps taken before reaching tout.
# At t = 47.6278 and h = 3.1997e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 47.6278, , mxstep steps taken before reaching tout.
# At t = 287.49 and h = 7.0199e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 47.4896, , mxstep steps taken before reaching tout.
# At t = 47.4896, , mxstep steps taken before reaching tout.
# At t = 47.4896, , mxstep steps taken before reaching tout.
# At t = 287.352, , mxstep steps taken before reaching tout.
# At t = 47.3516, , mxstep steps taken before reaching tout.
# At t = 47.3516, , mxstep steps taken before reaching tout.
# At t = 47.3516 and h = 3.54359e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 287.214, , mxstep steps taken before reaching tout.
# At t = 47.2135, , mxstep steps taken before reaching tout.
# At t = 47.2135, , mxstep steps taken before reaching tout.
# At t = 47.2135, , mxstep steps taken before reaching tout.
# At t = 287.076 and h = 1.03604e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 47.0762, , mxstep steps taken before reaching tout.
# At t = 47.0762, , mxstep steps taken before reaching tout.
# At t = 47.0762, , mxstep steps taken before reaching tout.
# At t = 286.938, , mxstep steps taken before reaching tout.
# At t = 286.8, , mxstep steps taken before reaching tout.
# At t = 286.662, , mxstep steps taken before reaching tout.
# At t = 286.525, , mxstep steps taken before reaching tout.
# At t = 286.387, , mxstep steps taken before reaching tout.
# At t = 286.249, , mxstep steps taken before reaching tout.
# At t = 286.112, , mxstep steps taken before reaching tout.
# At t = 285.974, , mxstep steps taken before reaching tout.
# At t = 285.838, , mxstep steps taken before reaching tout.
# At t = 285.7, , mxstep steps taken before reaching tout.
# At t = 285.562, , mxstep steps taken before reaching tout.
# At t = 285.425, , mxstep steps taken before reaching tout.
# At t = 285.288, , mxstep steps taken before reaching tout.
# At t = 285.151, , mxstep steps taken before reaching tout.
# At t = 285.014, , mxstep steps taken before reaching tout.
# At t = 284.877, , mxstep steps taken before reaching tout.
# At t = 284.74, , mxstep steps taken before reaching tout.
# At t = 284.604, , mxstep steps taken before reaching tout.
# At t = 284.466, , mxstep steps taken before reaching tout.
# At t = 284.33, , mxstep steps taken before reaching tout.
# At t = 284.193 and h = 1.70893e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 284.056 and h = 1.21326e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 283.92, , mxstep steps taken before reaching tout.
# At t = 283.784, , mxstep steps taken before reaching tout.
# At t = 283.647, , mxstep steps taken before reaching tout.
# At t = 283.51, , mxstep steps taken before reaching tout.
# At t = 283.375, , mxstep steps taken before reaching tout.
# At t = 283.239 and h = 1.13786e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 283.102, , mxstep steps taken before reaching tout.
# At t = 282.966, , mxstep steps taken before reaching tout.
# At t = 282.83, , mxstep steps taken before reaching tout.
# At t = 282.694, , mxstep steps taken before reaching tout.
# At t = 282.558, , mxstep steps taken before reaching tout.
# At t = 282.422, , mxstep steps taken before reaching tout.
# At t = 282.286, , mxstep steps taken before reaching tout.
# At t = 282.15, , mxstep steps taken before reaching tout.
# At t = 282.014, , mxstep steps taken before reaching tout.
# At t = 281.878, , mxstep steps taken before reaching tout.
# At t = 281.743, , mxstep steps taken before reaching tout.
# At t = 281.607, , mxstep steps taken before reaching tout.
# At t = 281.472, , mxstep steps taken before reaching tout.
# At t = 281.337, , mxstep steps taken before reaching tout.
# At t = 281.201 and h = 2.65073e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 281.066 and h = 2.80068e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 280.931, , mxstep steps taken before reaching tout.
# At t = 280.795, , mxstep steps taken before reaching tout.
# At t = 280.66, , mxstep steps taken before reaching tout.
# At t = 280.525, , mxstep steps taken before reaching tout.
# At t = 280.39, , mxstep steps taken before reaching tout.
# At t = 280.255, , mxstep steps taken before reaching tout.
# At t = 280.12 and h = 7.01428e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 279.985, , mxstep steps taken before reaching tout.
# At t = 279.85, , mxstep steps taken before reaching tout.
# At t = 279.715, , mxstep steps taken before reaching tout.
# At t = 279.58, , mxstep steps taken before reaching tout.
# At t = 279.446, , mxstep steps taken before reaching tout.
# At t = 279.311, , mxstep steps taken before reaching tout.
# At t = 279.177, , mxstep steps taken before reaching tout.
# At t = 279.042, , mxstep steps taken before reaching tout.
# At t = 278.908, , mxstep steps taken before reaching tout.
# At t = 278.774, , mxstep steps taken before reaching tout.
# At t = 278.639, , mxstep steps taken before reaching tout.
# At t = 278.505 and h = 1.08827e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 278.371, , mxstep steps taken before reaching tout.
# At t = 278.236, , mxstep steps taken before reaching tout.
# At t = 278.102, , mxstep steps taken before reaching tout.
# At t = 277.968, , mxstep steps taken before reaching tout.
# At t = 277.834 and h = 1.9441e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 277.701, , mxstep steps taken before reaching tout.
# Succeed to run the ageing set for 77 cycles the 1th time
# Scan 10 Re 0: Finish for No.1078 ageing cycles within 5 hours, 51 minutes, 13 seconds
# Scan 10 Re 0: Finish post-process for No.1155 ageing cycles within 353.415 ms
# At t = 356.072 and h = 3.54365e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 116.072, , mxstep steps taken before reaching tout.
# At t = 116.072 and h = 5.40069e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 349.041, , mxstep steps taken before reaching tout.
# At t = 109.041, , mxstep steps taken before reaching tout.
# At t = 109.041 and h = 4.30848e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 262.947 and h = 4.76575e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 262.947 and h = 5.88762e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 112.946 and h = 8.85347e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 112.946, , mxstep steps taken before reaching tout.
# At t = 112.946, , mxstep steps taken before reaching tout.
# At t = 118.211, , mxstep steps taken before reaching tout.
# At t = 118.211, , mxstep steps taken before reaching tout.
# At t = 118.211, , mxstep steps taken before reaching tout.
# At t = 84.0235, , mxstep steps taken before reaching tout.
# At t = 84.0235, , mxstep steps taken before reaching tout.
# At t = 84.0235, , mxstep steps taken before reaching tout.
# Succeed to run RPT for the 1th time
