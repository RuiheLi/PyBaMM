# %%
""" 
This script is the baseline for main file to run functions from
GEM-2_Ruihe 
"""
# Load modules
import pybamm as pb;import pandas as pd;import numpy as np;
import os, json,openpyxl,traceback,multiprocessing,scipy.optimize,sys
import matplotlib.pyplot as plt;
import pickle,imageio,timeit,random,time, signal
from scipy.io import savemat,loadmat;
from pybamm import constants,exp;import matplotlib as mpl

# %%
########################     Global settings!!!
rows_per_file = 1;  Scan_end_end = 12  
purpose_i = "SEI_Exp1235_NC" 


# define options:
On_HPC =  False;        Runshort="GEM-2"; Add_Rest = False
Plot_Exp=True;          Timeout=True;     Return_Sol=True;   
Check_Small_Time=True;  R_from_GITT = True
fs = 13; dpi = 100; Re_No =0
Options = [ 
    On_HPC,Runshort,Add_Rest,
    Plot_Exp,Timeout,Return_Sol,
    Check_Small_Time,R_from_GITT,
    dpi,fs]
Timelimit = int(3600*48) # give 48 hours!


if On_HPC:
    i_bundle = int(os.environ["PBS_ARRAY_INDEX"])
else:
    i_bundle = 1; 
Scan_start = (i_bundle-1)*rows_per_file+1;    
Scan_end   = min(Scan_start + rows_per_file-1, Scan_end_end)    
purpose = f"{purpose_i}_Case_{Scan_start}_{Scan_end}"
Target  = f'/{purpose}/'
# interpetation: Simnon suggested, with cracking activation, heat transfer
para_csv = f"Bundle_{i_bundle}.csv"  # name of the random file to get parameters

# Path setting:
if On_HPC:                          # Run on HPC
    Path_csv = f"InputData/{purpose_i}/" 
    Path_Input = "InputData/" 
    BasicPath=os.getcwd() 
    Para_file = Path_csv +  para_csv
else:
    # Add path to system to ensure Fun_P2 can be used
    import sys  
    str_path_0 = os.path.abspath(os.path.join(pb.__path__[0],'..'))
    str_path_1 = os.path.abspath(
        os.path.join(str_path_0,"wip/Rio_Code/Fun_P2"))
    sys.path.append(str_path_1) 
    Path_Input = os.path.expanduser(
        "~/EnvPBGEM_NC/SimSave/InputData/") # for Linux
    BasicPath =  os.path.expanduser(
        "~/EnvPBGEM_NC/SimSave/P2_R9_Dim")
    Para_file = Path_Input+f'{purpose_i}/'+para_csv
# import all functions 
from Fun_NC import * 


# Load input file
Para_dict_list = load_combinations_from_csv(Para_file)
pool_no = len(Para_dict_list) # do parallel computing if needed
# Out:
# Total scan case is 1

# %%
midc_merge_all = [];  Sol_RPT_all = [];  Sol_AGE_all = []
Path_List = [BasicPath, Path_Input,Target,purpose] 
# Run the model
if Re_No == 0:
    midc_merge,Sol_RPT,Sol_AGE,DeBug_Lists = Run_P2_Excel (
        Para_dict_list[0], Path_List, 
        Re_No, Timelimit, Options) 
elif Re_No > 0:
    pass
# Out:
# Start Now! Scan 1 Re 0
# Finish reading Experiment!
# Aging T is 10degC
# Has Overwritten Initial outer SEI thickness [m] to be 7.66e-09 and Negative electrode porosity to be 0.238 to account for initial capacity loss of 0.135 Ah
# Scan 1 Re 0: DryOut = Off
# Scan 1 Re 0: Spent 5.691 s on Initialization
# At t = 367.549 and h = 5.14692e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 127.549, , mxstep steps taken before reaching tout.
# At t = 358.354 and h = 7.30783e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 118.353, , mxstep steps taken before reaching tout.
# At t = 118.353, , mxstep steps taken before reaching tout.
# At t = 238.517, , mxstep steps taken before reaching tout.
# At t = 238.517 and h = 3.2338e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 88.5176 and h = 3.56486e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 88.5176 and h = 6.20528e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 88.5176, , mxstep steps taken before reaching tout.
# At t = 125.881, , mxstep steps taken before reaching tout.
# At t = 125.881, , mxstep steps taken before reaching tout.
# Succeed to run break in for the 0th time with capacity increase of 0Ah and perturbation of 0.00e+00Ah
#
# Scan 1 Re 0: Finish break-in cycle within 23 minutes, 51 seconds
# Scan 1 Re 0: Finish post-process for break-in cycle within 1 minute, 0 seconds
# At t = 301.882, , mxstep steps taken before reaching tout.
# At t = 61.8823, , mxstep steps taken before reaching tout.
# At t = 61.8823, , mxstep steps taken before reaching tout.
# At t = 505.555 and h = 2.66377e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 530.509, , mxstep steps taken before reaching tout.
# At t = 50.5092, , mxstep steps taken before reaching tout.
# At t = 50.5092, , mxstep steps taken before reaching tout.
# At t = 50.5092, , mxstep steps taken before reaching tout.
# At t = 529.573, , mxstep steps taken before reaching tout.
# At t = 529.604, , mxstep steps taken before reaching tout.
# At t = 529.603, , mxstep steps taken before reaching tout.
# At t = 529.602, , mxstep steps taken before reaching tout.
# At t = 529.602, , mxstep steps taken before reaching tout.
# At t = 529.602, , mxstep steps taken before reaching tout.
# At t = 529.601, , mxstep steps taken before reaching tout.
# At t = 529.601, , mxstep steps taken before reaching tout.
# At t = 529.601, , mxstep steps taken before reaching tout.
# At t = 529.601, , mxstep steps taken before reaching tout.
# At t = 529.6, , mxstep steps taken before reaching tout.
# At t = 529.6, , mxstep steps taken before reaching tout.
# At t = 529.6, , mxstep steps taken before reaching tout.
# At t = 529.599, , mxstep steps taken before reaching tout.
# At t = 529.599, , mxstep steps taken before reaching tout.
# At t = 529.599, , mxstep steps taken before reaching tout.
# At t = 529.598, , mxstep steps taken before reaching tout.
# At t = 529.598, , mxstep steps taken before reaching tout.
# At t = 529.598, , mxstep steps taken before reaching tout.
# At t = 529.598, , mxstep steps taken before reaching tout.
# At t = 529.597, , mxstep steps taken before reaching tout.
# At t = 529.597, , mxstep steps taken before reaching tout.
# At t = 529.597, , mxstep steps taken before reaching tout.
# At t = 529.596, , mxstep steps taken before reaching tout.
# At t = 529.596, , mxstep steps taken before reaching tout.
# At t = 529.596, , mxstep steps taken before reaching tout.
# At t = 529.595, , mxstep steps taken before reaching tout.
# At t = 529.595, , mxstep steps taken before reaching tout.
# At t = 529.595, , mxstep steps taken before reaching tout.
# At t = 529.595, , mxstep steps taken before reaching tout.
# At t = 529.594, , mxstep steps taken before reaching tout.
# At t = 529.594 and h = 1.11513e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.594 and h = 2.20528e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.593, , mxstep steps taken before reaching tout.
# At t = 529.593, , mxstep steps taken before reaching tout.
# At t = 529.593, , mxstep steps taken before reaching tout.
# At t = 529.592, , mxstep steps taken before reaching tout.
# At t = 529.592, , mxstep steps taken before reaching tout.
# At t = 529.592, , mxstep steps taken before reaching tout.
# At t = 529.592 and h = 4.84486e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.591, , mxstep steps taken before reaching tout.
# At t = 529.591, , mxstep steps taken before reaching tout.
# At t = 529.591, , mxstep steps taken before reaching tout.
# At t = 529.59, , mxstep steps taken before reaching tout.
# At t = 529.59, , mxstep steps taken before reaching tout.
# At t = 529.59, , mxstep steps taken before reaching tout.
# At t = 529.589 and h = 1.29785e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.589, , mxstep steps taken before reaching tout.
# At t = 529.589, , mxstep steps taken before reaching tout.
# At t = 529.589, , mxstep steps taken before reaching tout.
# At t = 529.588, , mxstep steps taken before reaching tout.
# At t = 529.588, , mxstep steps taken before reaching tout.
# At t = 529.588, , mxstep steps taken before reaching tout.
# At t = 529.587, , mxstep steps taken before reaching tout.
# At t = 529.587, , mxstep steps taken before reaching tout.
# At t = 529.587, , mxstep steps taken before reaching tout.
# At t = 529.587, , mxstep steps taken before reaching tout.
# At t = 529.586, , mxstep steps taken before reaching tout.
# At t = 529.586, , mxstep steps taken before reaching tout.
# At t = 529.586, , mxstep steps taken before reaching tout.
# At t = 529.585, , mxstep steps taken before reaching tout.
# At t = 529.585, , mxstep steps taken before reaching tout.
# At t = 529.585, , mxstep steps taken before reaching tout.
# At t = 529.584, , mxstep steps taken before reaching tout.
# At t = 529.584, , mxstep steps taken before reaching tout.
# At t = 529.584, , mxstep steps taken before reaching tout.
# At t = 529.583, , mxstep steps taken before reaching tout.
# At t = 529.583 and h = 1.56115e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.583, , mxstep steps taken before reaching tout.
# At t = 529.583, , mxstep steps taken before reaching tout.
# At t = 529.582, , mxstep steps taken before reaching tout.
# At t = 529.582, , mxstep steps taken before reaching tout.
# At t = 529.582, , mxstep steps taken before reaching tout.
# At t = 529.581 and h = 9.55204e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.581, , mxstep steps taken before reaching tout.
# At t = 529.581, , mxstep steps taken before reaching tout.
# At t = 529.581 and h = 1.64956e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.58, , mxstep steps taken before reaching tout.
# At t = 529.58, , mxstep steps taken before reaching tout.
# At t = 529.58 and h = 6.26607e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.579 and h = 1.74184e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.579, , mxstep steps taken before reaching tout.
# At t = 529.579, , mxstep steps taken before reaching tout.
# At t = 529.578, , mxstep steps taken before reaching tout.
# At t = 529.578, , mxstep steps taken before reaching tout.
# At t = 529.578, , mxstep steps taken before reaching tout.
# At t = 529.578, , mxstep steps taken before reaching tout.
# At t = 529.577, , mxstep steps taken before reaching tout.
# At t = 529.577 and h = 2.09629e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.577, , mxstep steps taken before reaching tout.
# At t = 529.576 and h = 1.99251e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.576, , mxstep steps taken before reaching tout.
# At t = 529.576, , mxstep steps taken before reaching tout.
# At t = 529.576, , mxstep steps taken before reaching tout.
# At t = 529.575, , mxstep steps taken before reaching tout.
# At t = 529.575, , mxstep steps taken before reaching tout.
# At t = 529.575, , mxstep steps taken before reaching tout.
# At t = 529.574 and h = 1.75153e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.574, , mxstep steps taken before reaching tout.
# At t = 529.574, , mxstep steps taken before reaching tout.
# At t = 529.573, , mxstep steps taken before reaching tout.
# At t = 529.573, , mxstep steps taken before reaching tout.
# At t = 529.573, , mxstep steps taken before reaching tout.
# At t = 529.573, , mxstep steps taken before reaching tout.
# At t = 529.572, , mxstep steps taken before reaching tout.
# At t = 529.572 and h = 1.20527e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.572, , mxstep steps taken before reaching tout.
# At t = 529.571, , mxstep steps taken before reaching tout.
# At t = 529.571, , mxstep steps taken before reaching tout.
# At t = 529.571 and h = 1.59422e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.571, , mxstep steps taken before reaching tout.
# At t = 529.57, , mxstep steps taken before reaching tout.
# At t = 529.57, , mxstep steps taken before reaching tout.
# At t = 529.57, , mxstep steps taken before reaching tout.
# At t = 529.569, , mxstep steps taken before reaching tout.
# At t = 529.569, , mxstep steps taken before reaching tout.
# At t = 529.569, , mxstep steps taken before reaching tout.
# At t = 529.569, , mxstep steps taken before reaching tout.
# At t = 529.568, , mxstep steps taken before reaching tout.
# At t = 529.568, , mxstep steps taken before reaching tout.
# At t = 529.568, , mxstep steps taken before reaching tout.
# At t = 529.567, , mxstep steps taken before reaching tout.
# At t = 529.567, , mxstep steps taken before reaching tout.
# At t = 529.567, , mxstep steps taken before reaching tout.
# At t = 529.567, , mxstep steps taken before reaching tout.
# At t = 529.566 and h = 1.2375e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.566, , mxstep steps taken before reaching tout.
# At t = 529.566, , mxstep steps taken before reaching tout.
# At t = 529.565, , mxstep steps taken before reaching tout.
# At t = 529.565, , mxstep steps taken before reaching tout.
# At t = 529.565, , mxstep steps taken before reaching tout.
# At t = 529.564, , mxstep steps taken before reaching tout.
# At t = 529.564, , mxstep steps taken before reaching tout.
# At t = 529.564, , mxstep steps taken before reaching tout.
# At t = 529.564, , mxstep steps taken before reaching tout.
# At t = 529.563, , mxstep steps taken before reaching tout.
# At t = 529.563, , mxstep steps taken before reaching tout.
# At t = 529.563 and h = 2.26943e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.562, , mxstep steps taken before reaching tout.
# At t = 529.562, , mxstep steps taken before reaching tout.
# At t = 529.562, , mxstep steps taken before reaching tout.
# At t = 529.562, , mxstep steps taken before reaching tout.
# At t = 529.561, , mxstep steps taken before reaching tout.
# At t = 529.561, , mxstep steps taken before reaching tout.
# At t = 529.561, , mxstep steps taken before reaching tout.
# At t = 529.56, , mxstep steps taken before reaching tout.
# At t = 529.56, , mxstep steps taken before reaching tout.
# At t = 529.56 and h = 6.98638e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.56, , mxstep steps taken before reaching tout.
# At t = 529.559, , mxstep steps taken before reaching tout.
# At t = 529.559, , mxstep steps taken before reaching tout.
# At t = 529.559, , mxstep steps taken before reaching tout.
# At t = 529.558, , mxstep steps taken before reaching tout.
# At t = 529.558, repeated recoverable residual errors.
# At t = 529.558, , mxstep steps taken before reaching tout.
# At t = 529.557, , mxstep steps taken before reaching tout.
# At t = 529.557, , mxstep steps taken before reaching tout.
# At t = 529.557, , mxstep steps taken before reaching tout.
# At t = 529.557, , mxstep steps taken before reaching tout.
# At t = 529.556, , mxstep steps taken before reaching tout.
# At t = 529.556, , mxstep steps taken before reaching tout.
# At t = 529.556, , mxstep steps taken before reaching tout.
# At t = 529.555, , mxstep steps taken before reaching tout.
# At t = 529.555, , mxstep steps taken before reaching tout.
# At t = 529.555, , mxstep steps taken before reaching tout.
# At t = 529.555, , mxstep steps taken before reaching tout.
# At t = 529.554, , mxstep steps taken before reaching tout.
# At t = 529.554, , mxstep steps taken before reaching tout.
# At t = 529.554, , mxstep steps taken before reaching tout.
# At t = 529.553, , mxstep steps taken before reaching tout.
# At t = 529.553, , mxstep steps taken before reaching tout.
# At t = 529.553, , mxstep steps taken before reaching tout.
# At t = 529.553, , mxstep steps taken before reaching tout.
# At t = 529.552, , mxstep steps taken before reaching tout.
# At t = 529.552, , mxstep steps taken before reaching tout.
# At t = 529.552 and h = 4.10759e-16, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.551 and h = 1.31213e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.551, , mxstep steps taken before reaching tout.
# At t = 529.551, , mxstep steps taken before reaching tout.
# At t = 529.551, , mxstep steps taken before reaching tout.
# At t = 529.55, , mxstep steps taken before reaching tout.
# At t = 529.55, , mxstep steps taken before reaching tout.
# At t = 529.55, , mxstep steps taken before reaching tout.
# At t = 529.549, , mxstep steps taken before reaching tout.
# At t = 529.549 and h = 2.95557e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.549, , mxstep steps taken before reaching tout.
# At t = 529.549, , mxstep steps taken before reaching tout.
# At t = 529.548, , mxstep steps taken before reaching tout.
# At t = 529.548, , mxstep steps taken before reaching tout.
# At t = 529.548, , mxstep steps taken before reaching tout.
# At t = 529.547, , mxstep steps taken before reaching tout.
# At t = 529.547 and h = 1.65305e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.547, , mxstep steps taken before reaching tout.
# At t = 529.547, , mxstep steps taken before reaching tout.
# At t = 529.546, , mxstep steps taken before reaching tout.
# At t = 529.546, , mxstep steps taken before reaching tout.
# At t = 529.546, , mxstep steps taken before reaching tout.
# At t = 529.545, , mxstep steps taken before reaching tout.
# At t = 529.545, , mxstep steps taken before reaching tout.
# At t = 529.545, , mxstep steps taken before reaching tout.
# At t = 529.545, , mxstep steps taken before reaching tout.
# At t = 529.544 and h = 6.59938e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.544, , mxstep steps taken before reaching tout.
# At t = 529.544, , mxstep steps taken before reaching tout.
# At t = 529.543, , mxstep steps taken before reaching tout.
# At t = 529.543 and h = 3.66255e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.543, , mxstep steps taken before reaching tout.
# At t = 529.543, , mxstep steps taken before reaching tout.
# At t = 529.542 and h = 2.84416e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.542, , mxstep steps taken before reaching tout.
# At t = 529.542, , mxstep steps taken before reaching tout.
# At t = 529.541, , mxstep steps taken before reaching tout.
# At t = 529.541, , mxstep steps taken before reaching tout.
# At t = 529.541, , mxstep steps taken before reaching tout.
# At t = 529.54, , mxstep steps taken before reaching tout.
# At t = 529.54, , mxstep steps taken before reaching tout.
# At t = 529.54, , mxstep steps taken before reaching tout.
# At t = 529.54, , mxstep steps taken before reaching tout.
# At t = 529.539, , mxstep steps taken before reaching tout.
# At t = 529.539, , mxstep steps taken before reaching tout.
# At t = 529.539, , mxstep steps taken before reaching tout.
# At t = 529.538 and h = 6.60866e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.538, , mxstep steps taken before reaching tout.
# At t = 529.538, , mxstep steps taken before reaching tout.
# At t = 529.538 and h = 1.7641e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.537, , mxstep steps taken before reaching tout.
# At t = 529.537, , mxstep steps taken before reaching tout.
# At t = 529.537, , mxstep steps taken before reaching tout.
# At t = 529.537, , mxstep steps taken before reaching tout.
# At t = 529.536, , mxstep steps taken before reaching tout.
# At t = 529.536, , mxstep steps taken before reaching tout.
# At t = 529.536, , mxstep steps taken before reaching tout.
# At t = 529.535, , mxstep steps taken before reaching tout.
# At t = 529.535, , mxstep steps taken before reaching tout.
# At t = 529.535, , mxstep steps taken before reaching tout.
# At t = 529.535, , mxstep steps taken before reaching tout.
# At t = 529.534, , mxstep steps taken before reaching tout.
# At t = 529.534, , mxstep steps taken before reaching tout.
# At t = 529.534, , mxstep steps taken before reaching tout.
# At t = 529.533, repeated recoverable residual errors.
# At t = 529.533, , mxstep steps taken before reaching tout.
# At t = 529.533, , mxstep steps taken before reaching tout.
# At t = 529.533 and h = 4.66366e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.532, , mxstep steps taken before reaching tout.
# At t = 529.532, , mxstep steps taken before reaching tout.
# At t = 529.532, , mxstep steps taken before reaching tout.
# At t = 529.531, , mxstep steps taken before reaching tout.
# At t = 529.531, , mxstep steps taken before reaching tout.
# At t = 529.531 and h = 6.66609e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.531, , mxstep steps taken before reaching tout.
# At t = 529.53, , mxstep steps taken before reaching tout.
# At t = 529.53, , mxstep steps taken before reaching tout.
# At t = 529.53, , mxstep steps taken before reaching tout.
# At t = 529.529, , mxstep steps taken before reaching tout.
# Succeed to run the ageing set for 257 cycles the 1th time
# Scan 1 Re 0: Finish for No.0 ageing cycles within 13 hours, 10 minutes, 53 seconds
# Scan 1 Re 0: Finish post-process for No.257 ageing cycles within 385.096 ms
# At t = 346.425, , mxstep steps taken before reaching tout.
# At t = 106.424, , mxstep steps taken before reaching tout.
# At t = 106.424 and h = 1.06137e-13, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 337.267 and h = 1.67999e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 97.2667 and h = 5.48564e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 97.2667, , mxstep steps taken before reaching tout.
# At t = 220.18, , mxstep steps taken before reaching tout.
# At t = 220.18, , mxstep steps taken before reaching tout.
# At t = 115.554, , mxstep steps taken before reaching tout.
# At t = 115.554, , mxstep steps taken before reaching tout.
# At t = 115.554 and h = 2.14111e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# Succeed to run RPT for the 1th time
# Scan 1 Re 0: Finish for No.257 RPT cycles within 16 minutes, 10 seconds
# Scan 1 Re 0: Finish post-process for No.257 RPT cycles within 13.534 s
# At t = 301.78, , mxstep steps taken before reaching tout.
# At t = 61.78, , mxstep steps taken before reaching tout.
# At t = 61.78, , mxstep steps taken before reaching tout.
# At t = 505.553 and h = 1.79831e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 530.397, , mxstep steps taken before reaching tout.
# At t = 50.3975, , mxstep steps taken before reaching tout.
# At t = 50.3975, , mxstep steps taken before reaching tout.
# At t = 50.3975, , mxstep steps taken before reaching tout.
# At t = 529.464, , mxstep steps taken before reaching tout.
# At t = 529.495, , mxstep steps taken before reaching tout.
# At t = 529.493, , mxstep steps taken before reaching tout.
# At t = 529.493, , mxstep steps taken before reaching tout.
# At t = 529.493, , mxstep steps taken before reaching tout.
# At t = 529.492, , mxstep steps taken before reaching tout.
# At t = 529.492, , mxstep steps taken before reaching tout.
# At t = 529.492, , mxstep steps taken before reaching tout.
# At t = 529.492, , mxstep steps taken before reaching tout.
# At t = 529.491, , mxstep steps taken before reaching tout.
# At t = 529.491, , mxstep steps taken before reaching tout.
# At t = 529.491, , mxstep steps taken before reaching tout.
# At t = 529.49, , mxstep steps taken before reaching tout.
# At t = 529.49, , mxstep steps taken before reaching tout.
# At t = 529.49, , mxstep steps taken before reaching tout.
# At t = 529.49, , mxstep steps taken before reaching tout.
# At t = 529.489, , mxstep steps taken before reaching tout.
# At t = 529.489, , mxstep steps taken before reaching tout.
# At t = 529.489, , mxstep steps taken before reaching tout.
# At t = 529.489, , mxstep steps taken before reaching tout.
# At t = 529.488, , mxstep steps taken before reaching tout.
# At t = 529.488, , mxstep steps taken before reaching tout.
# At t = 529.488, , mxstep steps taken before reaching tout.
# At t = 529.487, , mxstep steps taken before reaching tout.
# At t = 529.487 and h = 5.92994e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.487, , mxstep steps taken before reaching tout.
# At t = 529.487, , mxstep steps taken before reaching tout.
# At t = 529.486, , mxstep steps taken before reaching tout.
# At t = 529.486 and h = 3.77423e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.486 and h = 3.55122e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.485 and h = 9.8247e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.485, , mxstep steps taken before reaching tout.
# At t = 529.485, , mxstep steps taken before reaching tout.
# At t = 529.485 and h = 7.00172e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.484, , mxstep steps taken before reaching tout.
# At t = 529.484, , mxstep steps taken before reaching tout.
# At t = 529.484, , mxstep steps taken before reaching tout.
# At t = 529.484, , mxstep steps taken before reaching tout.
# At t = 529.483, , mxstep steps taken before reaching tout.
# At t = 529.483, , mxstep steps taken before reaching tout.
# At t = 529.483, , mxstep steps taken before reaching tout.
# At t = 529.482, , mxstep steps taken before reaching tout.
# At t = 529.482 and h = 1.36692e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.482, , mxstep steps taken before reaching tout.
# At t = 529.482, , mxstep steps taken before reaching tout.
# At t = 529.481, , mxstep steps taken before reaching tout.
# At t = 529.481, , mxstep steps taken before reaching tout.
# At t = 529.481 and h = 2.67101e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.481, , mxstep steps taken before reaching tout.
# At t = 529.48, , mxstep steps taken before reaching tout.
# At t = 529.48, , mxstep steps taken before reaching tout.
# At t = 529.48, , mxstep steps taken before reaching tout.
# At t = 529.48, , mxstep steps taken before reaching tout.
# At t = 529.479, , mxstep steps taken before reaching tout.
# At t = 529.479, , mxstep steps taken before reaching tout.
# At t = 529.479, , mxstep steps taken before reaching tout.
# At t = 529.478, , mxstep steps taken before reaching tout.
# At t = 529.478, , mxstep steps taken before reaching tout.
# At t = 529.478, , mxstep steps taken before reaching tout.
# At t = 529.478, , mxstep steps taken before reaching tout.
# At t = 529.477, , mxstep steps taken before reaching tout.
# At t = 529.477, , mxstep steps taken before reaching tout.
# At t = 529.477, , mxstep steps taken before reaching tout.
# At t = 529.476, , mxstep steps taken before reaching tout.
# At t = 529.476, , mxstep steps taken before reaching tout.
# At t = 529.476, , mxstep steps taken before reaching tout.
# At t = 529.476, , mxstep steps taken before reaching tout.
# At t = 529.476, , mxstep steps taken before reaching tout.
# At t = 529.475, , mxstep steps taken before reaching tout.
# At t = 529.475, , mxstep steps taken before reaching tout.
# At t = 529.475, , mxstep steps taken before reaching tout.
# At t = 529.474, , mxstep steps taken before reaching tout.
# At t = 529.474, , mxstep steps taken before reaching tout.
# At t = 529.474, , mxstep steps taken before reaching tout.
# At t = 529.474, , mxstep steps taken before reaching tout.
# At t = 529.473, , mxstep steps taken before reaching tout.
# At t = 529.473, , mxstep steps taken before reaching tout.
# At t = 529.473 and h = 2.35312e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.472, , mxstep steps taken before reaching tout.
# At t = 529.472, , mxstep steps taken before reaching tout.
# At t = 529.472, , mxstep steps taken before reaching tout.
# At t = 529.472, , mxstep steps taken before reaching tout.
# At t = 529.471, , mxstep steps taken before reaching tout.
# At t = 529.471, , mxstep steps taken before reaching tout.
# At t = 529.471, , mxstep steps taken before reaching tout.
# At t = 529.471, , mxstep steps taken before reaching tout.
# At t = 529.47, , mxstep steps taken before reaching tout.
# At t = 529.47, , mxstep steps taken before reaching tout.
# At t = 529.47 and h = 1.89581e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.469, , mxstep steps taken before reaching tout.
# At t = 529.469, , mxstep steps taken before reaching tout.
# At t = 529.469, , mxstep steps taken before reaching tout.
# At t = 529.469, , mxstep steps taken before reaching tout.
# At t = 529.468, , mxstep steps taken before reaching tout.
# At t = 529.468, , mxstep steps taken before reaching tout.
# At t = 529.468, , mxstep steps taken before reaching tout.
# At t = 529.468, , mxstep steps taken before reaching tout.
# At t = 529.467, , mxstep steps taken before reaching tout.
# At t = 529.467 and h = 5.16131e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.467 and h = 1.81567e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.466, , mxstep steps taken before reaching tout.
# At t = 529.466, , mxstep steps taken before reaching tout.
# At t = 529.466, , mxstep steps taken before reaching tout.
# At t = 529.466, , mxstep steps taken before reaching tout.
# At t = 529.465, , mxstep steps taken before reaching tout.
# At t = 529.465 and h = 7.01356e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.465, , mxstep steps taken before reaching tout.
# At t = 529.465 and h = 1.72841e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.464, , mxstep steps taken before reaching tout.
# At t = 529.464, , mxstep steps taken before reaching tout.
# At t = 529.464, , mxstep steps taken before reaching tout.
# At t = 529.464, , mxstep steps taken before reaching tout.
# At t = 529.463 and h = 4.11434e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.463, , mxstep steps taken before reaching tout.
# At t = 529.463 and h = 3.28158e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.463, , mxstep steps taken before reaching tout.
# At t = 529.462, , mxstep steps taken before reaching tout.
# At t = 529.462, , mxstep steps taken before reaching tout.
# At t = 529.462, , mxstep steps taken before reaching tout.
# At t = 529.461, , mxstep steps taken before reaching tout.
# At t = 529.461, , mxstep steps taken before reaching tout.
# At t = 529.461, , mxstep steps taken before reaching tout.
# At t = 529.461, , mxstep steps taken before reaching tout.
# At t = 529.46, , mxstep steps taken before reaching tout.
# At t = 529.46, , mxstep steps taken before reaching tout.
# At t = 529.46, , mxstep steps taken before reaching tout.
# At t = 529.46, , mxstep steps taken before reaching tout.
# At t = 529.459, , mxstep steps taken before reaching tout.
# At t = 529.459, , mxstep steps taken before reaching tout.
# At t = 529.459, , mxstep steps taken before reaching tout.
# At t = 529.458 and h = 1.60922e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.458, , mxstep steps taken before reaching tout.
# At t = 529.458, , mxstep steps taken before reaching tout.
# At t = 529.458, , mxstep steps taken before reaching tout.
# At t = 529.457, , mxstep steps taken before reaching tout.
# At t = 529.457, , mxstep steps taken before reaching tout.
# At t = 529.457, , mxstep steps taken before reaching tout.
# At t = 529.457, , mxstep steps taken before reaching tout.
# At t = 529.456, , mxstep steps taken before reaching tout.
# At t = 529.456, , mxstep steps taken before reaching tout.
# At t = 529.456, , mxstep steps taken before reaching tout.
# At t = 529.456, , mxstep steps taken before reaching tout.
# At t = 529.455 and h = 2.07453e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.455, , mxstep steps taken before reaching tout.
# At t = 529.455, , mxstep steps taken before reaching tout.
# At t = 529.454 and h = 4.67624e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.454, , mxstep steps taken before reaching tout.
# At t = 529.454, , mxstep steps taken before reaching tout.
# At t = 529.454, , mxstep steps taken before reaching tout.
# At t = 529.453, , mxstep steps taken before reaching tout.
# At t = 529.453, , mxstep steps taken before reaching tout.
# At t = 529.453, , mxstep steps taken before reaching tout.
# At t = 529.453, , mxstep steps taken before reaching tout.
# At t = 529.452, , mxstep steps taken before reaching tout.
# At t = 529.452, , mxstep steps taken before reaching tout.
# At t = 529.452, , mxstep steps taken before reaching tout.
# At t = 529.452 and h = 1.74551e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.451, , mxstep steps taken before reaching tout.
# At t = 529.451, , mxstep steps taken before reaching tout.
# At t = 529.451 and h = 1.42741e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.45, , mxstep steps taken before reaching tout.
# At t = 529.45, , mxstep steps taken before reaching tout.
# At t = 529.45, , mxstep steps taken before reaching tout.
# At t = 529.45, , mxstep steps taken before reaching tout.
# At t = 529.449, , mxstep steps taken before reaching tout.
# At t = 529.449, , mxstep steps taken before reaching tout.
# At t = 529.449 and h = 2.56737e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.449, , mxstep steps taken before reaching tout.
# At t = 529.448, , mxstep steps taken before reaching tout.
# At t = 529.448, , mxstep steps taken before reaching tout.
# At t = 529.448, , mxstep steps taken before reaching tout.
# At t = 529.448, , mxstep steps taken before reaching tout.
# At t = 529.447, , mxstep steps taken before reaching tout.
# At t = 529.447, , mxstep steps taken before reaching tout.
# At t = 529.447, , mxstep steps taken before reaching tout.
# At t = 529.447 and h = 1.28311e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.446, , mxstep steps taken before reaching tout.
# At t = 529.446, , mxstep steps taken before reaching tout.
# At t = 529.446, , mxstep steps taken before reaching tout.
# At t = 529.445 and h = 2.60843e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.445, , mxstep steps taken before reaching tout.
# At t = 529.445, , mxstep steps taken before reaching tout.
# At t = 529.445, , mxstep steps taken before reaching tout.
# At t = 529.444, , mxstep steps taken before reaching tout.
# At t = 529.444, , mxstep steps taken before reaching tout.
# At t = 529.444, , mxstep steps taken before reaching tout.
# At t = 529.444, , mxstep steps taken before reaching tout.
# At t = 529.443 and h = 2.02482e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.443, , mxstep steps taken before reaching tout.
# At t = 529.443, , mxstep steps taken before reaching tout.
# At t = 529.443, , mxstep steps taken before reaching tout.
# At t = 529.442 and h = 8.78429e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.442, , mxstep steps taken before reaching tout.
# At t = 529.442, , mxstep steps taken before reaching tout.
# At t = 529.442, , mxstep steps taken before reaching tout.
# At t = 529.441, , mxstep steps taken before reaching tout.
# At t = 529.441, , mxstep steps taken before reaching tout.
# At t = 529.441, , mxstep steps taken before reaching tout.
# At t = 529.441 and h = 4.99791e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.44 and h = 4.27377e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.44, , mxstep steps taken before reaching tout.
# At t = 529.44, , mxstep steps taken before reaching tout.
# At t = 529.439, , mxstep steps taken before reaching tout.
# At t = 529.439, , mxstep steps taken before reaching tout.
# At t = 529.439, , mxstep steps taken before reaching tout.
# At t = 529.439, , mxstep steps taken before reaching tout.
# At t = 529.438, , mxstep steps taken before reaching tout.
# At t = 529.438, , mxstep steps taken before reaching tout.
# At t = 529.438, , mxstep steps taken before reaching tout.
# At t = 529.438, , mxstep steps taken before reaching tout.
# At t = 529.437, , mxstep steps taken before reaching tout.
# At t = 529.437, , mxstep steps taken before reaching tout.
# At t = 529.437 and h = 3.65786e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.437, , mxstep steps taken before reaching tout.
# At t = 529.436, , mxstep steps taken before reaching tout.
# At t = 529.436, , mxstep steps taken before reaching tout.
# At t = 529.436, , mxstep steps taken before reaching tout.
# At t = 529.435, , mxstep steps taken before reaching tout.
# At t = 529.435, , mxstep steps taken before reaching tout.
# At t = 529.435, , mxstep steps taken before reaching tout.
# At t = 529.435 and h = 7.11827e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.434, , mxstep steps taken before reaching tout.
# At t = 529.434, , mxstep steps taken before reaching tout.
# At t = 529.434, , mxstep steps taken before reaching tout.
# At t = 529.434, , mxstep steps taken before reaching tout.
# At t = 529.433 and h = 5.02379e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.433 and h = 1.14651e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.433, , mxstep steps taken before reaching tout.
# At t = 529.433 and h = 6.48832e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.432, , mxstep steps taken before reaching tout.
# At t = 529.432, , mxstep steps taken before reaching tout.
# At t = 529.432, , mxstep steps taken before reaching tout.
# At t = 529.432, , mxstep steps taken before reaching tout.
# At t = 529.431, , mxstep steps taken before reaching tout.
# At t = 529.431 and h = 1.52059e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.431, , mxstep steps taken before reaching tout.
# At t = 529.431, , mxstep steps taken before reaching tout.
# At t = 529.43, , mxstep steps taken before reaching tout.
# At t = 529.43, , mxstep steps taken before reaching tout.
# At t = 529.43, , mxstep steps taken before reaching tout.
# At t = 529.429, , mxstep steps taken before reaching tout.
# At t = 529.429, , mxstep steps taken before reaching tout.
# At t = 529.429, , mxstep steps taken before reaching tout.
# At t = 529.429, , mxstep steps taken before reaching tout.
# At t = 529.428, , mxstep steps taken before reaching tout.
# At t = 529.428, , mxstep steps taken before reaching tout.
# At t = 529.428, , mxstep steps taken before reaching tout.
# At t = 529.428, , mxstep steps taken before reaching tout.
# At t = 529.427, , mxstep steps taken before reaching tout.
# At t = 529.427, , mxstep steps taken before reaching tout.
# At t = 529.427, , mxstep steps taken before reaching tout.
# At t = 529.427, , mxstep steps taken before reaching tout.
# At t = 529.426 and h = 7.05569e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.426, , mxstep steps taken before reaching tout.
# Succeed to run the ageing set for 257 cycles the 1th time
# Scan 1 Re 0: Finish for No.257 ageing cycles within 12 hours, 44 minutes, 30 seconds
# Scan 1 Re 0: Finish post-process for No.514 ageing cycles within 172.131 ms
# At t = 326.714, , mxstep steps taken before reaching tout.
# At t = 317.594 and h = 7.85744e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 203.678 and h = 4.67262e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 203.678 and h = 7.65079e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 105.896 and h = 3.05918e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 105.896, , mxstep steps taken before reaching tout.
# At t = 105.896, , mxstep steps taken before reaching tout.
# Succeed to run RPT for the 1th time
# Scan 1 Re 0: Finish for No.514 RPT cycles within 13 minutes, 27 seconds
# Scan 1 Re 0: Finish post-process for No.514 RPT cycles within 14.944 s
# At t = 301.687 and h = 1.49591e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 61.6864, , mxstep steps taken before reaching tout.
# At t = 61.6864, , mxstep steps taken before reaching tout.
# At t = 505.555, , mxstep steps taken before reaching tout.
# At t = 530.295, , mxstep steps taken before reaching tout.
# At t = 50.2946, , mxstep steps taken before reaching tout.
# At t = 50.2946, , mxstep steps taken before reaching tout.
# At t = 50.2946, , mxstep steps taken before reaching tout.
# At t = 529.363 and h = 1.0934e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.394, , mxstep steps taken before reaching tout.
# At t = 529.393, , mxstep steps taken before reaching tout.
# At t = 529.392, , mxstep steps taken before reaching tout.
# At t = 529.392, , mxstep steps taken before reaching tout.
# At t = 529.392, , mxstep steps taken before reaching tout.
# At t = 529.392, , mxstep steps taken before reaching tout.
# At t = 529.391, , mxstep steps taken before reaching tout.
# At t = 529.391 and h = 2.91384e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.391 and h = 9.84393e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.391, , mxstep steps taken before reaching tout.
# At t = 529.39, , mxstep steps taken before reaching tout.
# At t = 529.39, , mxstep steps taken before reaching tout.
# At t = 529.39, , mxstep steps taken before reaching tout.
# At t = 529.39 and h = 1.45204e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.389, , mxstep steps taken before reaching tout.
# At t = 529.389, , mxstep steps taken before reaching tout.
# At t = 529.389, , mxstep steps taken before reaching tout.
# At t = 529.389 and h = 6.71852e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.388, , mxstep steps taken before reaching tout.
# At t = 529.388, , mxstep steps taken before reaching tout.
# At t = 529.388, , mxstep steps taken before reaching tout.
# At t = 529.388, , mxstep steps taken before reaching tout.
# At t = 529.387 and h = 3.99784e-16, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.387 and h = 1.84813e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.387, , mxstep steps taken before reaching tout.
# At t = 529.387, , mxstep steps taken before reaching tout.
# At t = 529.386, , mxstep steps taken before reaching tout.
# At t = 529.386 and h = 5.89048e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.386, , mxstep steps taken before reaching tout.
# At t = 529.386, , mxstep steps taken before reaching tout.
# At t = 529.385, , mxstep steps taken before reaching tout.
# At t = 529.385, , mxstep steps taken before reaching tout.
# At t = 529.385, , mxstep steps taken before reaching tout.
# At t = 529.385, , mxstep steps taken before reaching tout.
# At t = 529.384, , mxstep steps taken before reaching tout.
# At t = 529.384, , mxstep steps taken before reaching tout.
# At t = 529.384, , mxstep steps taken before reaching tout.
# At t = 529.384, , mxstep steps taken before reaching tout.
# At t = 529.383, , mxstep steps taken before reaching tout.
# At t = 529.383, , mxstep steps taken before reaching tout.
# At t = 529.383 and h = 6.04988e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.383, , mxstep steps taken before reaching tout.
# At t = 529.382, , mxstep steps taken before reaching tout.
# At t = 529.382, , mxstep steps taken before reaching tout.
# At t = 529.382, , mxstep steps taken before reaching tout.
# At t = 529.382, , mxstep steps taken before reaching tout.
# At t = 529.381 and h = 6.94638e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.381 and h = 1.20456e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.381, , mxstep steps taken before reaching tout.
# At t = 529.381, , mxstep steps taken before reaching tout.
# At t = 529.38, , mxstep steps taken before reaching tout.
# At t = 529.38, , mxstep steps taken before reaching tout.
# At t = 529.38 and h = 2.37693e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.38, , mxstep steps taken before reaching tout.
# At t = 529.379, , mxstep steps taken before reaching tout.
# At t = 529.379, , mxstep steps taken before reaching tout.
# At t = 529.379 and h = 1.1964e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.379, , mxstep steps taken before reaching tout.
# At t = 529.378, , mxstep steps taken before reaching tout.
# At t = 529.378 and h = 8.96426e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.378, , mxstep steps taken before reaching tout.
# At t = 529.378, , mxstep steps taken before reaching tout.
# At t = 529.377 and h = 2.08703e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.377, , mxstep steps taken before reaching tout.
# At t = 529.377, , mxstep steps taken before reaching tout.
# At t = 529.377, , mxstep steps taken before reaching tout.
# At t = 529.376, , mxstep steps taken before reaching tout.
# At t = 529.376, , mxstep steps taken before reaching tout.
# At t = 529.376, , mxstep steps taken before reaching tout.
# At t = 529.376, , mxstep steps taken before reaching tout.
# At t = 529.375, , mxstep steps taken before reaching tout.
# At t = 529.375, , mxstep steps taken before reaching tout.
# At t = 529.375, , mxstep steps taken before reaching tout.
# At t = 529.375, , mxstep steps taken before reaching tout.
# At t = 529.374, , mxstep steps taken before reaching tout.
# At t = 529.374 and h = 3.42933e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.374, , mxstep steps taken before reaching tout.
# At t = 529.374, , mxstep steps taken before reaching tout.
# At t = 529.373, , mxstep steps taken before reaching tout.
# At t = 529.373, , mxstep steps taken before reaching tout.
# At t = 529.373, , mxstep steps taken before reaching tout.
# At t = 529.373, , mxstep steps taken before reaching tout.
# At t = 529.372 and h = 4.94994e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.372, , mxstep steps taken before reaching tout.
# At t = 529.372, , mxstep steps taken before reaching tout.
# At t = 529.372, , mxstep steps taken before reaching tout.
# At t = 529.371, , mxstep steps taken before reaching tout.
# At t = 529.371, , mxstep steps taken before reaching tout.
# At t = 529.371, , mxstep steps taken before reaching tout.
# At t = 529.371, , mxstep steps taken before reaching tout.
# At t = 529.37, , mxstep steps taken before reaching tout.
# At t = 529.37, , mxstep steps taken before reaching tout.
# At t = 529.37, , mxstep steps taken before reaching tout.
# At t = 529.37 and h = 9.49953e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.369, , mxstep steps taken before reaching tout.
# At t = 529.369, , mxstep steps taken before reaching tout.
# At t = 529.369, , mxstep steps taken before reaching tout.
# At t = 529.369, , mxstep steps taken before reaching tout.
# At t = 529.368, , mxstep steps taken before reaching tout.
# At t = 529.368, , mxstep steps taken before reaching tout.
# At t = 529.368, , mxstep steps taken before reaching tout.
# At t = 529.368, , mxstep steps taken before reaching tout.
# At t = 529.367, , mxstep steps taken before reaching tout.
# At t = 529.367, , mxstep steps taken before reaching tout.
# At t = 529.367, , mxstep steps taken before reaching tout.
# At t = 529.367, , mxstep steps taken before reaching tout.
# At t = 529.366, , mxstep steps taken before reaching tout.
# At t = 529.366, , mxstep steps taken before reaching tout.
# At t = 529.366, , mxstep steps taken before reaching tout.
# At t = 529.366, , mxstep steps taken before reaching tout.
# At t = 529.365, , mxstep steps taken before reaching tout.
# At t = 529.365, , mxstep steps taken before reaching tout.
# At t = 529.365, , mxstep steps taken before reaching tout.
# At t = 529.365, , mxstep steps taken before reaching tout.
# At t = 529.364, , mxstep steps taken before reaching tout.
# At t = 529.364, , mxstep steps taken before reaching tout.
# At t = 529.364, , mxstep steps taken before reaching tout.
# At t = 529.364, , mxstep steps taken before reaching tout.
# At t = 529.363, , mxstep steps taken before reaching tout.
# At t = 529.363, , mxstep steps taken before reaching tout.
# At t = 529.363, , mxstep steps taken before reaching tout.
# At t = 529.363, , mxstep steps taken before reaching tout.
# At t = 529.362, , mxstep steps taken before reaching tout.
# At t = 529.362, , mxstep steps taken before reaching tout.
# At t = 529.362, , mxstep steps taken before reaching tout.
# At t = 529.362, , mxstep steps taken before reaching tout.
# At t = 529.361, , mxstep steps taken before reaching tout.
# At t = 529.361, , mxstep steps taken before reaching tout.
# At t = 529.361, , mxstep steps taken before reaching tout.
# At t = 529.361 and h = 2.91988e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.36, , mxstep steps taken before reaching tout.
# At t = 529.36, , mxstep steps taken before reaching tout.
# At t = 529.36, , mxstep steps taken before reaching tout.
# At t = 529.36, , mxstep steps taken before reaching tout.
# At t = 529.359, , mxstep steps taken before reaching tout.
# At t = 529.359, , mxstep steps taken before reaching tout.
# At t = 529.359, , mxstep steps taken before reaching tout.
# At t = 529.359, , mxstep steps taken before reaching tout.
# At t = 529.358, , mxstep steps taken before reaching tout.
# At t = 529.358 and h = 1.20122e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.358, , mxstep steps taken before reaching tout.
# At t = 529.358, , mxstep steps taken before reaching tout.
# At t = 529.357, , mxstep steps taken before reaching tout.
# At t = 529.357 and h = 3.31155e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.357, , mxstep steps taken before reaching tout.
# At t = 529.357 and h = 6.14838e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.357, , mxstep steps taken before reaching tout.
# At t = 529.356, , mxstep steps taken before reaching tout.
# At t = 529.356, , mxstep steps taken before reaching tout.
# At t = 529.356, , mxstep steps taken before reaching tout.
# At t = 529.356, , mxstep steps taken before reaching tout.
# At t = 529.355, , mxstep steps taken before reaching tout.
# At t = 529.355, , mxstep steps taken before reaching tout.
# At t = 529.355, , mxstep steps taken before reaching tout.
# At t = 529.355, , mxstep steps taken before reaching tout.
# At t = 529.354, , mxstep steps taken before reaching tout.
# At t = 529.354, , mxstep steps taken before reaching tout.
# At t = 529.354, , mxstep steps taken before reaching tout.
# At t = 529.354, , mxstep steps taken before reaching tout.
# At t = 529.353, , mxstep steps taken before reaching tout.
# ...
# At t = 528.731, , mxstep steps taken before reaching tout.
# At t = 528.731, , mxstep steps taken before reaching tout.
# At t = 528.731, , mxstep steps taken before reaching tout.
# At t = 528.73, , mxstep steps taken before reaching tout.
# At t = 528.73, , mxstep steps taken before reaching tout.
# At t = 528.73, , mxstep steps taken before reaching tout.
# At t = 528.73, , mxstep steps taken before reaching tout.
# At t = 528.73, , mxstep steps taken before reaching tout.
# At t = 528.73, , mxstep steps taken before reaching tout.
# At t = 528.729, , mxstep steps taken before reaching tout.
# At t = 528.729, , mxstep steps taken before reaching tout.
# At t = 528.729, , mxstep steps taken before reaching tout.
# At t = 528.729 and h = 4.6011e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.729, , mxstep steps taken before reaching tout.
# At t = 528.729 and h = 1.57154e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.729 and h = 3.60753e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.728 and h = 1.37414e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.728 and h = 8.68005e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.728, , mxstep steps taken before reaching tout.
# At t = 528.728, , mxstep steps taken before reaching tout.
# At t = 528.728, , mxstep steps taken before reaching tout.
# At t = 528.728, , mxstep steps taken before reaching tout.
# At t = 528.728, , mxstep steps taken before reaching tout.
# At t = 528.727, , mxstep steps taken before reaching tout.
# At t = 528.727, , mxstep steps taken before reaching tout.
# At t = 528.727, , mxstep steps taken before reaching tout.
# At t = 528.727, , mxstep steps taken before reaching tout.
# At t = 528.727, , mxstep steps taken before reaching tout.
# At t = 528.727, , mxstep steps taken before reaching tout.
# At t = 528.727, , mxstep steps taken before reaching tout.
# At t = 528.726, , mxstep steps taken before reaching tout.
# At t = 528.726, , mxstep steps taken before reaching tout.
# At t = 528.726, , mxstep steps taken before reaching tout.
# At t = 528.726, , mxstep steps taken before reaching tout.
# At t = 528.726, , mxstep steps taken before reaching tout.
# At t = 528.726, , mxstep steps taken before reaching tout.
# At t = 528.725, , mxstep steps taken before reaching tout.
# At t = 528.725, , mxstep steps taken before reaching tout.
# At t = 528.725, , mxstep steps taken before reaching tout.
# At t = 528.725, , mxstep steps taken before reaching tout.
# At t = 528.725, , mxstep steps taken before reaching tout.
# At t = 528.725, , mxstep steps taken before reaching tout.
# At t = 528.725, , mxstep steps taken before reaching tout.
# At t = 528.724, , mxstep steps taken before reaching tout.
# At t = 528.724, , mxstep steps taken before reaching tout.
# At t = 528.724, , mxstep steps taken before reaching tout.
# At t = 528.724, , mxstep steps taken before reaching tout.
# At t = 528.724, , mxstep steps taken before reaching tout.
# At t = 528.724, , mxstep steps taken before reaching tout.
# At t = 528.723, , mxstep steps taken before reaching tout.
# At t = 528.723, , mxstep steps taken before reaching tout.
# At t = 528.723 and h = 2.26554e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.723, , mxstep steps taken before reaching tout.
# At t = 528.723, , mxstep steps taken before reaching tout.
# At t = 528.723, , mxstep steps taken before reaching tout.
# At t = 528.723, , mxstep steps taken before reaching tout.
# At t = 528.722, , mxstep steps taken before reaching tout.
# At t = 528.722 and h = 8.85904e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.722, , mxstep steps taken before reaching tout.
# At t = 528.722, , mxstep steps taken before reaching tout.
# At t = 528.722, , mxstep steps taken before reaching tout.
# At t = 528.722, , mxstep steps taken before reaching tout.
# At t = 528.722, , mxstep steps taken before reaching tout.
# At t = 528.721, , mxstep steps taken before reaching tout.
# At t = 528.721, , mxstep steps taken before reaching tout.
# At t = 528.721, , mxstep steps taken before reaching tout.
# At t = 528.721 and h = 5.65865e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.721, , mxstep steps taken before reaching tout.
# At t = 528.721, , mxstep steps taken before reaching tout.
# At t = 528.721, , mxstep steps taken before reaching tout.
# At t = 528.72, , mxstep steps taken before reaching tout.
# At t = 528.72 and h = 1.34474e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.72, , mxstep steps taken before reaching tout.
# At t = 528.72, , mxstep steps taken before reaching tout.
# At t = 528.72, , mxstep steps taken before reaching tout.
# At t = 528.72, , mxstep steps taken before reaching tout.
# At t = 528.72 and h = 1.02069e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.719, , mxstep steps taken before reaching tout.
# At t = 528.719, , mxstep steps taken before reaching tout.
# At t = 528.719, , mxstep steps taken before reaching tout.
# At t = 528.719, , mxstep steps taken before reaching tout.
# At t = 528.719, , mxstep steps taken before reaching tout.
# At t = 528.719, , mxstep steps taken before reaching tout.
# At t = 528.718, , mxstep steps taken before reaching tout.
# At t = 528.718, , mxstep steps taken before reaching tout.
# At t = 528.718, , mxstep steps taken before reaching tout.
# At t = 528.718 and h = 4.33877e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.718, , mxstep steps taken before reaching tout.
# At t = 528.718 and h = 3.08686e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.718, , mxstep steps taken before reaching tout.
# At t = 528.717, , mxstep steps taken before reaching tout.
# At t = 528.717, , mxstep steps taken before reaching tout.
# At t = 528.717, , mxstep steps taken before reaching tout.
# At t = 528.717, , mxstep steps taken before reaching tout.
# At t = 528.717, , mxstep steps taken before reaching tout.
# At t = 528.717, , mxstep steps taken before reaching tout.
# At t = 528.717, , mxstep steps taken before reaching tout.
# At t = 528.716, , mxstep steps taken before reaching tout.
# At t = 528.716, , mxstep steps taken before reaching tout.
# At t = 528.716, , mxstep steps taken before reaching tout.
# At t = 528.716, , mxstep steps taken before reaching tout.
# At t = 528.716, , mxstep steps taken before reaching tout.
# At t = 528.716, , mxstep steps taken before reaching tout.
# At t = 528.716, , mxstep steps taken before reaching tout.
# At t = 528.715, , mxstep steps taken before reaching tout.
# At t = 528.715, , mxstep steps taken before reaching tout.
# At t = 528.715, , mxstep steps taken before reaching tout.
# At t = 528.715 and h = 4.48253e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.715 and h = 5.58324e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.715, , mxstep steps taken before reaching tout.
# At t = 528.714 and h = 1.78871e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.714, , mxstep steps taken before reaching tout.
# At t = 528.714, , mxstep steps taken before reaching tout.
# At t = 528.714 and h = 4.32054e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.714, , mxstep steps taken before reaching tout.
# At t = 528.714, , mxstep steps taken before reaching tout.
# At t = 528.714, , mxstep steps taken before reaching tout.
# At t = 528.714, , mxstep steps taken before reaching tout.
# At t = 528.713, , mxstep steps taken before reaching tout.
# At t = 528.713 and h = 3.11321e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.713, , mxstep steps taken before reaching tout.
# At t = 528.713, , mxstep steps taken before reaching tout.
# At t = 528.713, , mxstep steps taken before reaching tout.
# At t = 528.713 and h = 1.08719e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.712, , mxstep steps taken before reaching tout.
# At t = 528.712, , mxstep steps taken before reaching tout.
# At t = 528.712, , mxstep steps taken before reaching tout.
# At t = 528.712, , mxstep steps taken before reaching tout.
# At t = 528.712 and h = 2.89286e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.712 and h = 3.61555e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.712, , mxstep steps taken before reaching tout.
# At t = 528.711, , mxstep steps taken before reaching tout.
# At t = 528.711, , mxstep steps taken before reaching tout.
# At t = 528.711, , mxstep steps taken before reaching tout.
# At t = 528.711, , mxstep steps taken before reaching tout.
# At t = 528.711 and h = 1.85501e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.711, , mxstep steps taken before reaching tout.
# At t = 528.711, , mxstep steps taken before reaching tout.
# At t = 528.71, , mxstep steps taken before reaching tout.
# At t = 528.71, , mxstep steps taken before reaching tout.
# At t = 528.71, , mxstep steps taken before reaching tout.
# At t = 528.71, , mxstep steps taken before reaching tout.
# At t = 528.71, , mxstep steps taken before reaching tout.
# At t = 528.71, , mxstep steps taken before reaching tout.
# At t = 528.71, , mxstep steps taken before reaching tout.
# At t = 528.709, , mxstep steps taken before reaching tout.
# At t = 528.709 and h = 7.75414e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.709, , mxstep steps taken before reaching tout.
# At t = 528.709, , mxstep steps taken before reaching tout.
# At t = 528.709, , mxstep steps taken before reaching tout.
# At t = 528.709, , mxstep steps taken before reaching tout.
# At t = 528.708, , mxstep steps taken before reaching tout.
# At t = 528.708, , mxstep steps taken before reaching tout.
# At t = 528.708, , mxstep steps taken before reaching tout.
# At t = 528.708 and h = 1.49991e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.708 and h = 8.51903e-16, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.708, , mxstep steps taken before reaching tout.
# At t = 528.708, , mxstep steps taken before reaching tout.
# At t = 528.707, , mxstep steps taken before reaching tout.
# At t = 528.707, , mxstep steps taken before reaching tout.
# At t = 528.707, , mxstep steps taken before reaching tout.
# At t = 528.707, , mxstep steps taken before reaching tout.
# At t = 528.707, , mxstep steps taken before reaching tout.
# At t = 528.707, , mxstep steps taken before reaching tout.
# At t = 528.707, , mxstep steps taken before reaching tout.
# At t = 528.706, , mxstep steps taken before reaching tout.
# At t = 528.706, , mxstep steps taken before reaching tout.
# At t = 528.706, , mxstep steps taken before reaching tout.
# At t = 528.706, , mxstep steps taken before reaching tout.
# At t = 528.706 and h = 2.98161e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.706, , mxstep steps taken before reaching tout.
# At t = 528.706 and h = 1.10417e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.705 and h = 2.42886e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.705 and h = 3.87173e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.705 and h = 8.04276e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.705, , mxstep steps taken before reaching tout.
# At t = 528.705, , mxstep steps taken before reaching tout.
# At t = 528.705 and h = 8.42679e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.705, , mxstep steps taken before reaching tout.
# At t = 528.704, , mxstep steps taken before reaching tout.
# At t = 528.704, , mxstep steps taken before reaching tout.
# At t = 528.704, , mxstep steps taken before reaching tout.
# At t = 528.704, , mxstep steps taken before reaching tout.
# At t = 528.704, , mxstep steps taken before reaching tout.
# At t = 528.704 and h = 9.95596e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.703 and h = 9.1415e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.703, , mxstep steps taken before reaching tout.
# At t = 528.703, , mxstep steps taken before reaching tout.
# At t = 528.703, , mxstep steps taken before reaching tout.
# At t = 528.703, , mxstep steps taken before reaching tout.
# At t = 528.703, , mxstep steps taken before reaching tout.
# At t = 528.703, , mxstep steps taken before reaching tout.
# At t = 528.702, , mxstep steps taken before reaching tout.
# At t = 528.702, , mxstep steps taken before reaching tout.
# At t = 528.702, , mxstep steps taken before reaching tout.
# At t = 528.702, , mxstep steps taken before reaching tout.
# At t = 528.702, , mxstep steps taken before reaching tout.
# At t = 528.702, , mxstep steps taken before reaching tout.
# At t = 528.702 and h = 9.81816e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.702, , mxstep steps taken before reaching tout.
# At t = 528.701, , mxstep steps taken before reaching tout.
# At t = 528.701, , mxstep steps taken before reaching tout.
# At t = 528.701, , mxstep steps taken before reaching tout.
# At t = 528.701, , mxstep steps taken before reaching tout.
# At t = 528.701, , mxstep steps taken before reaching tout.
# At t = 528.701 and h = 1.4648e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.7, , mxstep steps taken before reaching tout.
# At t = 528.7 and h = 8.92108e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.7, , mxstep steps taken before reaching tout.
# At t = 528.7, , mxstep steps taken before reaching tout.
# At t = 528.7, , mxstep steps taken before reaching tout.
# At t = 528.7, , mxstep steps taken before reaching tout.
# At t = 528.7, , mxstep steps taken before reaching tout.
# At t = 528.699, , mxstep steps taken before reaching tout.
# At t = 528.699, , mxstep steps taken before reaching tout.
# At t = 528.699, , mxstep steps taken before reaching tout.
# At t = 528.699, , mxstep steps taken before reaching tout.
# At t = 528.699, , mxstep steps taken before reaching tout.
# At t = 528.699, , mxstep steps taken before reaching tout.
# At t = 528.699, , mxstep steps taken before reaching tout.
# At t = 528.698, , mxstep steps taken before reaching tout.
# At t = 528.698, , mxstep steps taken before reaching tout.
# At t = 528.698, , mxstep steps taken before reaching tout.
# At t = 528.698, , mxstep steps taken before reaching tout.
# At t = 528.698, , mxstep steps taken before reaching tout.
# At t = 528.698, , mxstep steps taken before reaching tout.
# At t = 528.698, , mxstep steps taken before reaching tout.
# At t = 528.697 and h = 1.83405e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.697, , mxstep steps taken before reaching tout.
# At t = 528.697, , mxstep steps taken before reaching tout.
# At t = 528.697, , mxstep steps taken before reaching tout.
# At t = 528.697, , mxstep steps taken before reaching tout.
# At t = 528.697, , mxstep steps taken before reaching tout.
# At t = 528.697, , mxstep steps taken before reaching tout.
# Succeed to run the ageing set for 257 cycles the 1th time
# Scan 1 Re 0: Finish for No.2827 ageing cycles within 12 hours, 9 minutes, 32 seconds
# Scan 1 Re 0: Finish post-process for No.3084 ageing cycles within 210.638 ms
# At t = 172.474, , mxstep steps taken before reaching tout.
# At t = 172.474, , mxstep steps taken before reaching tout.
# At t = 163.706, , mxstep steps taken before reaching tout.
# At t = 163.706, , mxstep steps taken before reaching tout.
# At t = 125.475 and h = 4.5284e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 125.475, , mxstep steps taken before reaching tout.
# At t = 125.475, , mxstep steps taken before reaching tout.
# Succeed to run RPT for the 1th time
