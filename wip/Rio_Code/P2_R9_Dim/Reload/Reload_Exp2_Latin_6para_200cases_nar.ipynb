# %%
# we must know the experiment index, ideally also know the temperature
Temper_i = 273.15 + 40
Temp = 40.0
index_exp = 2

# %%
# magic lines that avoid re-start 
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pybamm as pb;import pandas as pd   ;import numpy as np;
import os; import seaborn as sns
import matplotlib.pyplot as plt;import os;import imageio
from scipy.io import savemat,loadmat;from pybamm import constants,exp;import matplotlib as mpl; fs=17; # or we can set import matplotlib.pyplot as plt then say 'mpl.rc...'
import openpyxl
import traceback
import multiprocessing
import scipy.optimize
import timeit
import random;import time, signal
fs=17; # python -m ipykernel install --user --name=EnvPBGEM_Linux --display-name "Python_Linux"
font = {'family' : 'DejaVu Sans','size'   : fs}
mpl.rc('font', **font)

# %%
# define global index and dict for all experiment data - prepare for read!
Exp_Path = [
    "Expt 1 - Si-based Degradation/",
    "Expt 2,2 - C-based Degradation 2/",
    "Expt 3 - Cathode Degradation and Li-Plating/",
    "Expt 4 - Drive Cycle Aging (Control)/",
    "Expt 5 - Standard Cycle Aging (Control)/",]
Exp_head = [
    "Expt 1",
    "Expt 2,2",
    "Expt 3",
    "Expt 4",
    "Expt 5",]
Exp_1_Cell = ["A","B","J","D","E","F","K","L","M"];
Exp_1_Temp = {
    "A":"10","B":"10","J":"10",
    "D":"25","E":"25","F":"25",
    "K":"40","L":"40","M":"40",}
Temp_Cell_Exp_1 = {
    "10":["A","B","J"],
    "25":["D","E","F"],
    "40":["K","L","M"],}
Exp_2_Cell = ["A","B","C","D","E","F"];
Exp_2_Temp = {
    "A":"10","B":"10",
    "C":"25","D":"25",
    "E":"40","F":"40",}
Temp_Cell_Exp_2 = {
    "10":["A","B"],
    "25":["C","D"],
    "40":["E","F"],}
Exp_3_Cell = ["A","B","C","D","E","F","G","H","I"];
Exp_3_Temp = {
    "A":"10","B":"10","C":"10",
    "D":"25","E":"25","F":"25",
    "G":"40","H":"40","I":"40"}
Temp_Cell_Exp_3 = {
    "10":["A","B","C"],
    "25":["D","E","F"],
    "40":["G","H","I"],}
Exp_4_Cell = ["A","B","C","D","E","F","G","H"];
Exp_4_Temp = {
    "A":"10","B":"10","C":"10",
    "D":"25","E":"25",
    "F":"40","G":"40","H":"40",}
Temp_Cell_Exp_4 = {
    "10":["A","B","C"],
    "25":["D","E",],
    "40":["F","G","H"],}
Exp_5_Cell = ["A","B","C","D","E","F","G","H"];
Exp_5_Temp = {
    "A":"10","B":"10","C":"10",
    "D":"25","E":"25",
    "F":"40","G":"40","H":"40",}
Temp_Cell_Exp_5 = {
    "10":["A","B","C"],
    "25":["D","E",],
    "40":["F","G","H"],}
Exp_All_Cell  = [Exp_1_Cell,Exp_2_Cell,Exp_3_Cell,Exp_4_Cell,Exp_5_Cell]
Exp_Temp_Cell = [Exp_1_Temp,Exp_2_Temp,Exp_3_Temp,Exp_4_Temp,Exp_5_Temp]
Temp_Cell_Exp_All = [Temp_Cell_Exp_1,Temp_Cell_Exp_2,Temp_Cell_Exp_3,Temp_Cell_Exp_4,Temp_Cell_Exp_5]
Mark_Cell_All = [
    {
    "A":"o","B":">","J":"v",
    "D":"o","E":">","F":"v",
    "K":"o","L":">","M":"v",},
    {
    "A":"10","B":"10",
    "C":"25","D":"25",
    "E":"40","F":"40",},
    {
    "A":"o","B":">","C":"v",
    "D":"o","E":">","F":"v",
    "G":"o","H":">","I":"v",},
    {
    "A":"o","B":">","C":"v",
    "D":"o","E":">",
    "F":"o","G":">","H":"v",},
    {
    "A":"o","B":">","C":"v",
    "D":"o","E":">",
    "F":"o","G":">","H":"v",}]
Color_Cell_All = [
    {
    "A":[2/255, 3/255, 226/255,0.7],"B":[2/255, 3/255, 226/255,0.7],"J":[2/255, 3/255, 226/255,0.7],
    "D":[0, 0, 0,0.7],"E":[0, 0, 0,0.7],"F":[0, 0, 0,0.7],
    "K":[1,0,0,0.4],"L":[1,0,0,0.4],"M":[1,0,0,0.4],},
    {
    "A":[2/255, 3/255, 226/255,0.7],"B":[2/255, 3/255, 226/255,0.7],
    "D":[0, 0, 0,0.7],"C":[0, 0, 0,0.7],
    "E":[1,0,0,0.4],"F":[1,0,0,0.4],},
    {
    "A":[2/255, 3/255, 226/255,0.7],"B":[2/255, 3/255, 226/255,0.7],"C":[2/255, 3/255, 226/255,0.7],
    "D":[0, 0, 0,0.7],"E":[0, 0, 0,0.7],"F":[0, 0, 0,0.7],
    "G":[1,0,0,0.4],"H":[1,0,0,0.4],"I":[1,0,0,0.4],},
    {
    "A":[2/255, 3/255, 226/255,0.7],"B":[2/255, 3/255, 226/255,0.7],"C":[2/255, 3/255, 226/255,0.7],
    "D":[0, 0, 0,0.7],"E":[0, 0, 0,0.7],
    "F":[1,0,0,0.4],"G":[1,0,0,0.4],"H":[1,0,0,0.4],},
    {
    "A":[2/255, 3/255, 226/255,0.7],"B":[2/255, 3/255, 226/255,0.7],"C":[2/255, 3/255, 226/255,0.7],
    "D":[0, 0, 0,0.7],"E":[0, 0, 0,0.7],
    "F":[1,0,0,0.4],"G":[1,0,0,0.4],"H":[1,0,0,0.4],}]

# %%
# ready experiment data
import sys  
str_path_0 = os.path.abspath(os.path.join(pb.__path__[0],'..'))
str_path_1 = os.path.abspath(os.path.join(str_path_0,"wip/Rio_Code/Fun_P2"))
sys.path.append(str_path_1) 
from Fun_P2 import * # directly do this for HPC
# Load Niall's data
Path_NiallDMA = os.path.expanduser("~/EnvPBGEM_Linux/SimSave/InputData/") 
Temp_Cell_Exp = Temp_Cell_Exp_All[index_exp-1] 
Exp_Any_AllData = Read_Exp(
    Path_NiallDMA,Exp_All_Cell[index_exp-1],
    Exp_Path,Exp_head,Exp_Temp_Cell[index_exp-1],
    index_exp-1)
# Out:
# Finish reading Experiment!

# %%
# Reload all 1000 scans  
BasicPath = os.path.expanduser(
    "~/EnvPBGEM_Linux/SimSave/P2_R9_Dim/Latin_6para_200cases_narrow/") # for Linux
Big_start = 1; Big_end = 200; case_no=10;
purpose = "Latin_6para_200cases_narrow"
Scan_start_all = (
    np.arange(Big_start,Big_end+1,case_no)
    ).tolist()
Scan_end_all = (
    np.arange(Big_start+case_no-1,Big_end+case_no,case_no)
    ).tolist()
# create the empty notebook
workbook = openpyxl.Workbook() 
sheet = workbook.active  
excel_name = "Summary of 200 cases-40oC"
sheet_title = "Summary-40oC" 
sheet.title = sheet_title
workbook.save(BasicPath+f"{excel_name}.xlsx" )
print("Create the summary file for the 200 cases")

# check whether all cases succeed, if so, it should contains a png file start with 0_Scan
def Check_all_succeed(Scan_start,Scan_end,BasicPath):
    # List all files in the folder   
    Round_No = f"{purpose}_Exp_{index_exp}_{Temp}oC_Case_{Scan_start}_{Scan_end}"  
    Target  = f'/Exp{index_exp}_{Round_No}/'
    target_folder = BasicPath + Target
    #print(target_folder)
    files = os.listdir(target_folder)
    # Check if any file matches the criteria
    Flag_all_succeed = False
    for file_name in files:
        if file_name.endswith('.png') and '0_Scan' in file_name:
            Flag_all_succeed = True
            break
    if Flag_all_succeed:
        print(f"All cases succeed from {Scan_start} to {Scan_end}")
    else:
        print(f"Some cases failed from {Scan_start} to {Scan_end}")
    return Flag_all_succeed

def Plot_summary(Scan_start,Scan_end,Temper_i,Exp_Any_AllData,dpi):
    Indexs =np.arange(Scan_start-1,Scan_end)
    index_list = Indexs+1
    All_Scans = {}
    Round_No = f"{purpose}_Exp_{index_exp}_{Temp}oC_Case_{Scan_start}_{Scan_end}"  
    Target  = f'Exp{index_exp}_{Round_No}/'
    for scan in index_list:
        All_Scans[str(scan)]={}
        try:
            All_Scans[str(scan)] = loadmat( 
            BasicPath +Target 
            +  "Mats/" + str(scan)+ "-Ageing_summary_only.mat")
        except:
            print(f"Nothing in Scan {scan}")
    # plot
    Num_subplot = 5;
    fig, axs = plt.subplots(Num_subplot,1, figsize=(6,13),tight_layout=True)
    cm = mpl.cm.get_cmap("cool", len(index_list))  
    for i,scan in enumerate(index_list):
        try:
            axs[0].plot(
                All_Scans[str(scan)]['Throughput capacity [kA.h]'][0], 
                All_Scans[str(scan)]['CDend SOH [%]'][0],     
                '-o',color=cm(i),  ) # label="Scan=" + str(scan)
            axs[1].plot(
                All_Scans[str(scan)]['Throughput capacity [kA.h]'][0], 
                All_Scans[str(scan)]["CDend LLI [%]"][0],'-o',color=cm(i), )
            axs[2].plot(
                All_Scans[str(scan)]["Throughput capacity [kA.h]"][0], 
                All_Scans[str(scan)]["CDend LAM_ne [%]"][0],'-o',   color=cm(i),   ) 
            axs[3].plot(
                All_Scans[str(scan)]["Throughput capacity [kA.h]"][0], 
                All_Scans[str(scan)]["CDend LAM_pe [%]"][0],    '-o', color=cm(i),  ) 
            axs[4].plot(
                All_Scans[str(scan)]["Throughput capacity [kA.h]"][0], 
                np.array(All_Scans[str(scan)]["Res_0p5C_50SOC"][0]),   '-o', color=cm(i), )
        except:
            pass
        else:
            pass 
    # Plot Charge Throughput (A.h) vs SOH
    color_exp     = [0, 0, 0, 0.3]; marker_exp     = "v";
    color_exp_Avg = [0, 0, 0, 0.7]; marker_exp_Avg = "s";

    Exp_temp_i_cell = Temp_Cell_Exp[str(int(Temper_i- 273.15))]
    XY_pack = Get_Cell_Mean_1T_1Exp(Exp_Any_AllData,Exp_temp_i_cell) 
    Exp_temp_i_cell = Temp_Cell_Exp[str(int(Temper_i- 273.15))]
    for cell in Exp_temp_i_cell:
        df = Exp_Any_AllData[cell]["Extract Data"]
        chThr_temp = np.array(df["Charge Throughput (A.h)"])/1e3
        df_DMA = Exp_Any_AllData[cell]["DMA"]["LLI_LAM"]
        axs[0].plot(
            chThr_temp,np.array(df_DMA["SoH"])*100,
            color=color_exp,marker=marker_exp,label=f"Cell {cell}") 
        axs[1].plot(
            chThr_temp,np.array(df_DMA["LLI"])*100,
            color=color_exp,marker=marker_exp,label=f"Cell {cell}")  
        axs[2].plot(
            chThr_temp,np.array(df_DMA["LAM NE_tot"])*100,
            color=color_exp,marker=marker_exp, )
        axs[3].plot(
            chThr_temp,np.array(df_DMA["LAM PE"])*100,
            color=color_exp,marker=marker_exp,)
        # update 230312- plot resistance here
        df = Exp_Any_AllData[cell]["Extract Data"]
        # Exp_1_AllData["A"]["Extract Data"]["0.1s Resistance (Ohms)"]
        index_Res = df[df['0.1s Resistance (Ohms)'].le(10)].index
        axs[4].plot(
            #df["Days of degradation"][index_Res],
            np.array(df["Charge Throughput (A.h)"][index_Res])/1e3,
            np.array(df["0.1s Resistance (Ohms)"][index_Res])*1e3,
            color=color_exp,marker=marker_exp)
    # Update 230518: Plot Experiment Average - at 1 expeirment and 1 temperature
    [X_1_st,X_5_st,Y_1_st_avg,Y_2_st_avg,
        Y_3_st_avg,Y_4_st_avg,Y_5_st_avg]  = XY_pack
    axs[0].plot(
        X_1_st,Y_1_st_avg,color=color_exp_Avg,
        marker=marker_exp_Avg,label=f"Exp-Avg") 
    axs[1].plot(
        X_1_st,Y_2_st_avg,color=color_exp_Avg,
        marker=marker_exp_Avg,label=f"Exp-Avg")  
    axs[2].plot(
        X_1_st,Y_3_st_avg,color=color_exp_Avg,
        marker=marker_exp_Avg, )
    axs[3].plot(
        X_1_st,Y_4_st_avg,
        color=color_exp_Avg,marker=marker_exp_Avg,)
    axs[4].plot(
        X_5_st,Y_5_st_avg,
        color=color_exp_Avg,marker=marker_exp_Avg)
    axs[0].set_ylabel("SOH %")
    axs[1].set_ylabel("LLI %")
    axs[2].set_ylabel("LAM NE %")
    axs[3].set_ylabel("LAM PE %")
    axs[4].set_ylabel(r"Lump resistance [m$\Omega$]")
    axs[4].set_xlabel("Charge Throughput (kA.h)")
    for i in range(0,Num_subplot):
        labels = axs[i].get_xticklabels() + axs[i].get_yticklabels(); 
        [label.set_fontname('DejaVu Sans') for label in labels]
        axs[i].tick_params(labelcolor='k', labelsize=fs, width=1) ;  del labels;
    axs[4].ticklabel_format(style='sci', axis='x', scilimits=(-1e-2,1e-2))
    axs[0].legend(prop={'family':'DejaVu Sans','size':fs-2},loc='best',frameon=False)
    axs[1].legend(prop={'family':'DejaVu Sans','size':fs-2},loc='best',frameon=False)
    fig.suptitle(
        f"0_Scan {index_list[0]}-{index_list[-1]}-Exp-{index_exp}-{str(int(Temper_i- 273.15))}"
        +r"$^\circ$C - Summary", fontsize=fs+2)
    plt.savefig(
        BasicPath + Target +  
        f"0_Scan {index_list[0]}-{index_list[-1]}-Exp-{index_exp}-{str(int(Temper_i- 273.15))}degC Summary.png", dpi=dpi)
    plt.close() 
    return

def Collect_1case_Excel(Scan_start,Scan_end):
    Indexs =np.arange(Scan_start-1,Scan_end)
    Index_List_succeed = Indexs+1
    Round_No = f"{purpose}_Exp_{index_exp}_{Temp}oC_Case_{Scan_start}_{Scan_end}" 
    Target = f'Exp{index_exp}_{Round_No}/'
    book_name_xlsx =  f'Exp{index_exp}_{Round_No}.xlsx';
    sheet_name_xlsx = 'Results';
    for k,index_i in enumerate(Index_List_succeed):
        #print(index_i)
        try:
            old_book = str(index_i) + '_' + book_name_xlsx
            #print(old_book)
            #open excel:
            data_old = openpyxl.load_workbook(
                BasicPath + Target +   "Excel/" + old_book)   
            data_tar = openpyxl.load_workbook(
                BasicPath + Target+   book_name_xlsx) 

            table_old = data_old[str(index_i)]
            nrows_old = table_old.max_row  # 获得行数
            ncolumns_old = table_old.max_column  # 获得列数

            table_tar = data_tar[sheet_name_xlsx]
            nrows_tar = table_tar.max_row # ncolumns_old + k +1 # Mark!!! Most important changes!
            ncolumns_old = table_old.max_column  # 获得列数
            list_old = [];
            #print(nrows_old,nrows_tar)
            for i in range(1,nrows_old+1):
                for j in range(1,ncolumns_old+1):
                    list_old.append(table_old.cell(row=i,column=j).value)
            
            list_old = [list_old,]
            for i in range(1, len(list_old)+1):
                    for j in range(1, len(list_old[i-1])+1):
                        #print(i,j,list_old[i-1][j-1]    )
                        table_tar.cell(nrows_tar+i, j).value = list_old[i-1][j-1]     
            data_tar.save(
                BasicPath + Target
                + book_name_xlsx) 
            data_tar.close()
        except:
            print(f"Something goes wrong for Scan {index_i}!")
        else:
            print(f"Successfuly write results for Scan {index_i}!") 
    return

# save all results into the summary file
def Collect_multicases_excel(Scan_start,Scan_end,BasicPath,excel_name,sheet_title):
    # Open the source workbook
    #    purpose = "Latin_6para_200cases_narrow"
    Round_No = f"{purpose}_Exp_{index_exp}_{Temp}oC_Case_{Scan_start}_{Scan_end}" 
    book_name_xlsx =  f'Exp{index_exp}_{Round_No}.xlsx';
    Target = f'Exp{index_exp}_{Round_No}/'
    source_workbook = openpyxl.load_workbook(
        filename=BasicPath +Target
        + book_name_xlsx)
    # Open the target workbook
    target_workbook = openpyxl.load_workbook(
        BasicPath+f"{excel_name}.xlsx" )
    # Get the active sheet of the source workbook
    source_sheet = source_workbook.active
    # Get the target sheet by name
    target_sheet = target_workbook[sheet_title]

    # Copy the values and formatting from the source sheet to the target sheet
    if Scan_start==1:
        for row in source_sheet.iter_rows(values_only=True):
            target_sheet.append(row)
    else:
        for row in source_sheet.iter_rows(values_only=True):
            if row != next(source_sheet.iter_rows(values_only=True)):
                target_sheet.append(row)

    # Save the changes to the target workbook
    target_workbook.save(BasicPath+f"{excel_name}.xlsx")
    print(f"Successfully collect Case_{Scan_start}_{Scan_end}")
    return 
# collect all results:
for Scan_start,Scan_end in zip(Scan_start_all,Scan_end_all):
    Flag_all_succeed = False # Check_all_succeed(Scan_start,Scan_end,BasicPath)
    if Flag_all_succeed:
        Collect_multicases_excel(Scan_start,Scan_end,BasicPath,excel_name,sheet_title)
    else:
        # first, plot summary
        Plot_summary(Scan_start,Scan_end,Temper_i,Exp_Any_AllData,dpi=100)
        # then collect single cases into a summary of the 10 cases
        Collect_1case_Excel(Scan_start,Scan_end)
        # finally, collect the 10 cases into a bigger file
        Collect_multicases_excel(Scan_start,Scan_end,BasicPath,excel_name,sheet_title)
# Out:
# Create the summary file for the 200 cases
# Nothing in Scan 1
# Nothing in Scan 2
# Nothing in Scan 3
# Nothing in Scan 4
# Nothing in Scan 5
# Nothing in Scan 6
# Nothing in Scan 7
# Nothing in Scan 8
# Nothing in Scan 9
# Nothing in Scan 10
# /tmp/ipykernel_9864/3882964811.py:58: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cm = mpl.cm.get_cmap("cool", len(index_list))
# Something goes wrong for Scan 1!
# Something goes wrong for Scan 2!
# Something goes wrong for Scan 3!
# Something goes wrong for Scan 4!
# Something goes wrong for Scan 5!
# Something goes wrong for Scan 6!
# Something goes wrong for Scan 7!
# Something goes wrong for Scan 8!
# Something goes wrong for Scan 9!
# Something goes wrong for Scan 10!
# Successfully collect Case_1_10
# Nothing in Scan 18
# Nothing in Scan 20
# Successfuly write results for Scan 11!
# Successfuly write results for Scan 12!
# Successfuly write results for Scan 13!
# Successfuly write results for Scan 14!
# Successfuly write results for Scan 15!
# Successfuly write results for Scan 16!
# Successfuly write results for Scan 17!
# Something goes wrong for Scan 18!
# Successfuly write results for Scan 19!
# Something goes wrong for Scan 20!
# Successfully collect Case_11_20
# Nothing in Scan 23
# Nothing in Scan 25
# Nothing in Scan 26
# Nothing in Scan 27
# Nothing in Scan 29
# Nothing in Scan 30
# Successfuly write results for Scan 21!
# Successfuly write results for Scan 22!
# Something goes wrong for Scan 23!
# Successfuly write results for Scan 24!
# Something goes wrong for Scan 25!
# Something goes wrong for Scan 26!
# Something goes wrong for Scan 27!
# Successfuly write results for Scan 28!
# Something goes wrong for Scan 29!
# Something goes wrong for Scan 30!
# Successfully collect Case_21_30
# Nothing in Scan 34
# Nothing in Scan 36
# Nothing in Scan 37
# Successfuly write results for Scan 31!
# Successfuly write results for Scan 32!
# Successfuly write results for Scan 33!
# Something goes wrong for Scan 34!
# Successfuly write results for Scan 35!
# Something goes wrong for Scan 36!
# Something goes wrong for Scan 37!
# Successfuly write results for Scan 38!
# Successfuly write results for Scan 39!
# Successfuly write results for Scan 40!
# Successfully collect Case_31_40
# Nothing in Scan 43
# Nothing in Scan 44
# Nothing in Scan 45
# Successfuly write results for Scan 41!
# Successfuly write results for Scan 42!
# Something goes wrong for Scan 43!
# Something goes wrong for Scan 44!
# Something goes wrong for Scan 45!
# Successfuly write results for Scan 46!
# Successfuly write results for Scan 47!
# Successfuly write results for Scan 48!
# Successfuly write results for Scan 49!
# Successfuly write results for Scan 50!
# Successfully collect Case_41_50
# Nothing in Scan 51
# Nothing in Scan 52
# Nothing in Scan 53
# Nothing in Scan 54
# Nothing in Scan 55
# Nothing in Scan 56
# Nothing in Scan 57
# Nothing in Scan 58
# Nothing in Scan 59
# Nothing in Scan 60
# Something goes wrong for Scan 51!
# Something goes wrong for Scan 52!
# Something goes wrong for Scan 53!
# Something goes wrong for Scan 54!
# Something goes wrong for Scan 55!
# Something goes wrong for Scan 56!
# Something goes wrong for Scan 57!
# Something goes wrong for Scan 58!
# Something goes wrong for Scan 59!
# Something goes wrong for Scan 60!
# Successfully collect Case_51_60
# Nothing in Scan 63
# Nothing in Scan 65
# Nothing in Scan 66
# Nothing in Scan 68
# Successfuly write results for Scan 61!
# Successfuly write results for Scan 62!
# Something goes wrong for Scan 63!
# Successfuly write results for Scan 64!
# Something goes wrong for Scan 65!
# Something goes wrong for Scan 66!
# Successfuly write results for Scan 67!
# Something goes wrong for Scan 68!
# Successfuly write results for Scan 69!
# Successfuly write results for Scan 70!
# Successfully collect Case_61_70
# Nothing in Scan 71
# Nothing in Scan 72
# Nothing in Scan 73
# Nothing in Scan 74
# Nothing in Scan 76
# Nothing in Scan 77
# Nothing in Scan 78
# Nothing in Scan 79
# Nothing in Scan 80
# Something goes wrong for Scan 71!
# Something goes wrong for Scan 72!
# Something goes wrong for Scan 73!
# Something goes wrong for Scan 74!
# Successfuly write results for Scan 75!
# Something goes wrong for Scan 76!
# Something goes wrong for Scan 77!
# Something goes wrong for Scan 78!
# Something goes wrong for Scan 79!
# Something goes wrong for Scan 80!
# Successfully collect Case_71_80
# Nothing in Scan 86
# Nothing in Scan 87
# Nothing in Scan 90
# Successfuly write results for Scan 81!
# Successfuly write results for Scan 82!
# Successfuly write results for Scan 83!
# Successfuly write results for Scan 84!
# Successfuly write results for Scan 85!
# Something goes wrong for Scan 86!
# Something goes wrong for Scan 87!
# Successfuly write results for Scan 88!
# Successfuly write results for Scan 89!
# Something goes wrong for Scan 90!
# Successfully collect Case_81_90
# Nothing in Scan 92
# Nothing in Scan 93
# Nothing in Scan 95
# Nothing in Scan 97
# Nothing in Scan 99
# Successfuly write results for Scan 91!
# Something goes wrong for Scan 92!
# Something goes wrong for Scan 93!
# Successfuly write results for Scan 94!
# Something goes wrong for Scan 95!
# Successfuly write results for Scan 96!
# Something goes wrong for Scan 97!
# Successfuly write results for Scan 98!
# Something goes wrong for Scan 99!
# Successfuly write results for Scan 100!
# Successfully collect Case_91_100
# Nothing in Scan 102
# Nothing in Scan 103
# Nothing in Scan 104
# Nothing in Scan 105
# Nothing in Scan 106
# Nothing in Scan 107
# Nothing in Scan 108
# Nothing in Scan 109
# Nothing in Scan 110
# Successfuly write results for Scan 101!
# Something goes wrong for Scan 102!
# Something goes wrong for Scan 103!
# Something goes wrong for Scan 104!
# Something goes wrong for Scan 105!
# Something goes wrong for Scan 106!
# Something goes wrong for Scan 107!
# Something goes wrong for Scan 108!
# Something goes wrong for Scan 109!
# Something goes wrong for Scan 110!
# Successfully collect Case_101_110
# Nothing in Scan 111
# Nothing in Scan 112
# Nothing in Scan 113
# Nothing in Scan 115
# Nothing in Scan 116
# Nothing in Scan 118
# Nothing in Scan 119
# Nothing in Scan 120
# Something goes wrong for Scan 111!
# Something goes wrong for Scan 112!
# Something goes wrong for Scan 113!
# Successfuly write results for Scan 114!
# Something goes wrong for Scan 115!
# Something goes wrong for Scan 116!
# Successfuly write results for Scan 117!
# Something goes wrong for Scan 118!
# Something goes wrong for Scan 119!
# Something goes wrong for Scan 120!
# Successfully collect Case_111_120
# Nothing in Scan 122
# Nothing in Scan 123
# Nothing in Scan 124
# Nothing in Scan 127
# Nothing in Scan 129
# Nothing in Scan 130
# Successfuly write results for Scan 121!
# Something goes wrong for Scan 122!
# Something goes wrong for Scan 123!
# Something goes wrong for Scan 124!
# Successfuly write results for Scan 125!
# Successfuly write results for Scan 126!
# Something goes wrong for Scan 127!
# Successfuly write results for Scan 128!
# Something goes wrong for Scan 129!
# Something goes wrong for Scan 130!
# Successfully collect Case_121_130
# Nothing in Scan 132
# Nothing in Scan 136
# Nothing in Scan 137
# Nothing in Scan 138
# Nothing in Scan 139
# Nothing in Scan 140
# Successfuly write results for Scan 131!
# Something goes wrong for Scan 132!
# Successfuly write results for Scan 133!
# Successfuly write results for Scan 134!
# Successfuly write results for Scan 135!
# Something goes wrong for Scan 136!
# Something goes wrong for Scan 137!
# Something goes wrong for Scan 138!
# Something goes wrong for Scan 139!
# Something goes wrong for Scan 140!
# Successfully collect Case_131_140
# Nothing in Scan 143
# Nothing in Scan 145
# Nothing in Scan 147
# Nothing in Scan 149
# Successfuly write results for Scan 141!
# Successfuly write results for Scan 142!
# Something goes wrong for Scan 143!
# Successfuly write results for Scan 144!
# Something goes wrong for Scan 145!
# Successfuly write results for Scan 146!
# Something goes wrong for Scan 147!
# Successfuly write results for Scan 148!
# Something goes wrong for Scan 149!
# Successfuly write results for Scan 150!
# Successfully collect Case_141_150
# Nothing in Scan 153
# Nothing in Scan 154
# Nothing in Scan 158
# Successfuly write results for Scan 151!
# Successfuly write results for Scan 152!
# Something goes wrong for Scan 153!
# Something goes wrong for Scan 154!
# Successfuly write results for Scan 155!
# Successfuly write results for Scan 156!
# Successfuly write results for Scan 157!
# Something goes wrong for Scan 158!
# Successfuly write results for Scan 159!
# Successfuly write results for Scan 160!
# Successfully collect Case_151_160
# Nothing in Scan 161
# Nothing in Scan 162
# Nothing in Scan 163
# Nothing in Scan 164
# Nothing in Scan 165
# Nothing in Scan 166
# Nothing in Scan 168
# Nothing in Scan 169
# Nothing in Scan 170
# Something goes wrong for Scan 161!
# Something goes wrong for Scan 162!
# Something goes wrong for Scan 163!
# Something goes wrong for Scan 164!
# Something goes wrong for Scan 165!
# Something goes wrong for Scan 166!
# Successfuly write results for Scan 167!
# Something goes wrong for Scan 168!
# Something goes wrong for Scan 169!
# Something goes wrong for Scan 170!
# Successfully collect Case_161_170
# Nothing in Scan 176
# Nothing in Scan 180
# Successfuly write results for Scan 171!
# Successfuly write results for Scan 172!
# Successfuly write results for Scan 173!
# Successfuly write results for Scan 174!
# Successfuly write results for Scan 175!
# Something goes wrong for Scan 176!
# Successfuly write results for Scan 177!
# Successfuly write results for Scan 178!
# Successfuly write results for Scan 179!
# Something goes wrong for Scan 180!
# Successfully collect Case_171_180
# Nothing in Scan 181
# Nothing in Scan 183
# Nothing in Scan 185
# Nothing in Scan 186
# Nothing in Scan 188
# Something goes wrong for Scan 181!
# Successfuly write results for Scan 182!
# Something goes wrong for Scan 183!
# Successfuly write results for Scan 184!
# Something goes wrong for Scan 185!
# Something goes wrong for Scan 186!
# Successfuly write results for Scan 187!
# Something goes wrong for Scan 188!
# Successfuly write results for Scan 189!
# Successfuly write results for Scan 190!
# Successfully collect Case_181_190
# Nothing in Scan 195
# Nothing in Scan 196
# Nothing in Scan 197
# Nothing in Scan 199
# Nothing in Scan 200
# Successfuly write results for Scan 191!
# Successfuly write results for Scan 192!
# Successfuly write results for Scan 193!
# Successfuly write results for Scan 194!
# Something goes wrong for Scan 195!
# Something goes wrong for Scan 196!
# Something goes wrong for Scan 197!
# Successfuly write results for Scan 198!
# Something goes wrong for Scan 199!
# Something goes wrong for Scan 200!
# Successfully collect Case_191_200

# %%
# tidy up the 1000 cases - delete the rows with "Unknown" - should upgrade in the future to keep 
""" from openpyxl import load_workbook
workbook = load_workbook(filename=BasicPath+f"{excel_name}.xlsx")
sheet = workbook.active
# Convert rows to a list and iterate over it in reverse order
rows = list(sheet.iter_rows(values_only=True))
for row in reversed(range(len(rows))):
    if "Unknown" in rows[row]:
        sheet.delete_rows(row + 1)  # Delete the row
workbook.save(filename=BasicPath+f"{excel_name}.xlsx") """

# %%
# replot everything:
BasicPath = os.path.expanduser(
    "~/EnvPBGEM_Linux/SimSave/P2_R9_Dim/Latin_6para_200cases_narrow/") # for Linux
if not os.path.exists(BasicPath + "Plots_collect"):
   os.mkdir(BasicPath + "Plots_collect");
if not os.path.exists(BasicPath + "Plots_collect/Allscans"):
   os.mkdir(BasicPath + "Plots_collect/Allscans");

Big_start = 1; Big_end = 200; case_no=10;
Scan_start_all = (
    np.arange(Big_start,Big_end+1,case_no)
    ).tolist()
Scan_end_all = (
    np.arange(Big_start+case_no-1,Big_end+case_no,case_no)
    ).tolist()
# cre
def Plot_summary2(Scan_start,Scan_end,Temper_i,Exp_Any_AllData,dpi):
    Indexs =np.arange(Scan_start-1,Scan_end)
    index_list = Indexs+1
    All_Scans = {}
    Round_No = f"{purpose}_Exp_{index_exp}_{Temp}oC_Case_{Scan_start}_{Scan_end}"  
    Target  = f'Exp{index_exp}_{Round_No}/'
    for scan in index_list:
        All_Scans[str(scan)]={}
        try:
            All_Scans[str(scan)] = loadmat( 
            BasicPath + Target
            +  "Mats/" + str(scan)+ "-Ageing_summary_only.mat")
        except:
            print(f"Nothing in Scan {scan}")
    # plot
    Num_subplot = 5;
    fig, axs = plt.subplots(Num_subplot,1, figsize=(6,13),tight_layout=True)
    cm = mpl.cm.get_cmap("cool", len(index_list))  
    for i,scan in enumerate(index_list):
        try:
            axs[0].plot(
                All_Scans[str(scan)]['Throughput capacity [kA.h]'][0], 
                All_Scans[str(scan)]['CDend SOH [%]'][0],     
                '-o',color=cm(i),  ) # label="Scan=" + str(scan)
            axs[1].plot(
                All_Scans[str(scan)]['Throughput capacity [kA.h]'][0], 
                All_Scans[str(scan)]["CDend LLI [%]"][0],'-o',color=cm(i), )
            axs[2].plot(
                All_Scans[str(scan)]["Throughput capacity [kA.h]"][0], 
                All_Scans[str(scan)]["CDend LAM_ne [%]"][0],'-o',   color=cm(i),   ) 
            axs[3].plot(
                All_Scans[str(scan)]["Throughput capacity [kA.h]"][0], 
                All_Scans[str(scan)]["CDend LAM_pe [%]"][0],    '-o', color=cm(i),  ) 
            axs[4].plot(
                All_Scans[str(scan)]["Throughput capacity [kA.h]"][0], 
                np.array(All_Scans[str(scan)]["Res_0p5C_50SOC"][0]),   '-o', color=cm(i), )
        except:
            pass
        else:
            pass 
    # Plot Charge Throughput (A.h) vs SOH
    color_exp     = [0, 0, 0, 0.3]; marker_exp     = "v";
    color_exp_Avg = [0, 0, 0, 0.7]; marker_exp_Avg = "s";

    Exp_temp_i_cell = Temp_Cell_Exp[str(int(Temper_i- 273.15))]
    XY_pack = Get_Cell_Mean_1T_1Exp(Exp_Any_AllData,Exp_temp_i_cell) 
    Exp_temp_i_cell = Temp_Cell_Exp[str(int(Temper_i- 273.15))]
    for cell in Exp_temp_i_cell:
        df = Exp_Any_AllData[cell]["Extract Data"]
        chThr_temp = np.array(df["Charge Throughput (A.h)"])/1e3
        df_DMA = Exp_Any_AllData[cell]["DMA"]["LLI_LAM"]
        axs[0].plot(
            chThr_temp,np.array(df_DMA["SoH"])*100,
            color=color_exp,marker=marker_exp,label=f"Cell {cell}") 
        axs[1].plot(
            chThr_temp,np.array(df_DMA["LLI"])*100,
            color=color_exp,marker=marker_exp,label=f"Cell {cell}")  
        axs[2].plot(
            chThr_temp,np.array(df_DMA["LAM NE_tot"])*100,
            color=color_exp,marker=marker_exp, )
        axs[3].plot(
            chThr_temp,np.array(df_DMA["LAM PE"])*100,
            color=color_exp,marker=marker_exp,)
        # update 230312- plot resistance here
        df = Exp_Any_AllData[cell]["Extract Data"]
        # Exp_1_AllData["A"]["Extract Data"]["0.1s Resistance (Ohms)"]
        index_Res = df[df['0.1s Resistance (Ohms)'].le(10)].index
        axs[4].plot(
            #df["Days of degradation"][index_Res],
            np.array(df["Charge Throughput (A.h)"][index_Res])/1e3,
            np.array(df["0.1s Resistance (Ohms)"][index_Res])*1e3,
            color=color_exp,marker=marker_exp)
    # Update 230518: Plot Experiment Average - at 1 expeirment and 1 temperature
    [X_1_st,X_5_st,Y_1_st_avg,Y_2_st_avg,
        Y_3_st_avg,Y_4_st_avg,Y_5_st_avg]  = XY_pack
    axs[0].plot(
        X_1_st,Y_1_st_avg,color=color_exp_Avg,
        marker=marker_exp_Avg,label=f"Exp-Avg") 
    axs[1].plot(
        X_1_st,Y_2_st_avg,color=color_exp_Avg,
        marker=marker_exp_Avg,label=f"Exp-Avg")  
    axs[2].plot(
        X_1_st,Y_3_st_avg,color=color_exp_Avg,
        marker=marker_exp_Avg, )
    axs[3].plot(
        X_1_st,Y_4_st_avg,
        color=color_exp_Avg,marker=marker_exp_Avg,)
    axs[4].plot(
        X_5_st,Y_5_st_avg,
        color=color_exp_Avg,marker=marker_exp_Avg)
    axs[0].set_ylabel("SOH %")
    axs[1].set_ylabel("LLI %")
    axs[2].set_ylabel("LAM NE %")
    axs[3].set_ylabel("LAM PE %")
    axs[4].set_ylabel(r"Lump resistance [m$\Omega$]")
    axs[4].set_xlabel("Charge Throughput (kA.h)")
    for i in range(0,Num_subplot):
        labels = axs[i].get_xticklabels() + axs[i].get_yticklabels(); 
        [label.set_fontname('DejaVu Sans') for label in labels]
        axs[i].tick_params(labelcolor='k', labelsize=fs, width=1) ;  del labels;
    axs[4].ticklabel_format(style='sci', axis='x', scilimits=(-1e-2,1e-2))
    axs[0].legend(prop={'family':'DejaVu Sans','size':fs-2},loc='best',frameon=False)
    axs[1].legend(prop={'family':'DejaVu Sans','size':fs-2},loc='best',frameon=False)
    fig.suptitle(
        f"1_Scan {index_list[0]}-{index_list[-1]}-Exp-{index_exp}-{str(int(Temper_i- 273.15))}"
        +r"$^\circ$C - Summary", fontsize=fs+2)
    plt.savefig(
        BasicPath + f"Plots_collect/Allscans/" +  
        f"0_Scan {index_list[0]}-{index_list[-1]}-Exp-{index_exp}-{str(int(Temper_i- 273.15))}degC Summary.png", dpi=dpi)
    plt.close() 
    return

for Scan_start,Scan_end in zip(Scan_start_all,Scan_end_all):
    Plot_summary2(Scan_start,Scan_end,Temper_i,Exp_Any_AllData,dpi=300)
# Out:
# Nothing in Scan 1
# Nothing in Scan 2
# Nothing in Scan 3
# Nothing in Scan 4
# Nothing in Scan 5
# Nothing in Scan 6
# Nothing in Scan 7
# Nothing in Scan 8
# Nothing in Scan 9
# Nothing in Scan 10
# /tmp/ipykernel_9864/4230911810.py:34: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cm = mpl.cm.get_cmap("cool", len(index_list))
# Nothing in Scan 18
# Nothing in Scan 20
# Nothing in Scan 23
# Nothing in Scan 25
# Nothing in Scan 26
# Nothing in Scan 27
# Nothing in Scan 29
# Nothing in Scan 30
# Nothing in Scan 34
# Nothing in Scan 36
# Nothing in Scan 37
# Nothing in Scan 43
# Nothing in Scan 44
# Nothing in Scan 45
# Nothing in Scan 51
# Nothing in Scan 52
# Nothing in Scan 53
# Nothing in Scan 54
# Nothing in Scan 55
# Nothing in Scan 56
# Nothing in Scan 57
# Nothing in Scan 58
# Nothing in Scan 59
# Nothing in Scan 60
# Nothing in Scan 63
# Nothing in Scan 65
# Nothing in Scan 66
# Nothing in Scan 68
# Nothing in Scan 71
# Nothing in Scan 72
# Nothing in Scan 73
# Nothing in Scan 74
# Nothing in Scan 76
# Nothing in Scan 77
# Nothing in Scan 78
# Nothing in Scan 79
# Nothing in Scan 80
# Nothing in Scan 86
# Nothing in Scan 87
# Nothing in Scan 90
# Nothing in Scan 92
# Nothing in Scan 93
# Nothing in Scan 95
# Nothing in Scan 97
# Nothing in Scan 99
# Nothing in Scan 102
# Nothing in Scan 103
# Nothing in Scan 104
# Nothing in Scan 105
# Nothing in Scan 106
# Nothing in Scan 107
# Nothing in Scan 108
# Nothing in Scan 109
# Nothing in Scan 110
# Nothing in Scan 111
# Nothing in Scan 112
# Nothing in Scan 113
# Nothing in Scan 115
# Nothing in Scan 116
# Nothing in Scan 118
# Nothing in Scan 119
# Nothing in Scan 120
# Nothing in Scan 122
# Nothing in Scan 123
# Nothing in Scan 124
# Nothing in Scan 127
# Nothing in Scan 129
# Nothing in Scan 130
# Nothing in Scan 132
# Nothing in Scan 136
# Nothing in Scan 137
# Nothing in Scan 138
# Nothing in Scan 139
# Nothing in Scan 140
# Nothing in Scan 143
# Nothing in Scan 145
# Nothing in Scan 147
# Nothing in Scan 149
# Nothing in Scan 153
# Nothing in Scan 154
# Nothing in Scan 158
# Nothing in Scan 161
# Nothing in Scan 162
# Nothing in Scan 163
# Nothing in Scan 164
# Nothing in Scan 165
# Nothing in Scan 166
# Nothing in Scan 168
# Nothing in Scan 169
# Nothing in Scan 170
# Nothing in Scan 176
# Nothing in Scan 180
# Nothing in Scan 181
# Nothing in Scan 183
# Nothing in Scan 185
# Nothing in Scan 186
# Nothing in Scan 188
# Nothing in Scan 195
# Nothing in Scan 196
# Nothing in Scan 197
# Nothing in Scan 199
# Nothing in Scan 200

# %%
Num_subplot = 5;
Selected = [142]
fig, axs = plt.subplots(Num_subplot,1, figsize=(6,13),tight_layout=True)
cm = mpl.cm.get_cmap("cool", 3) 
All_Scans = {}

for i,Temp in enumerate([10.0,25.0,40.0]):
    scan = 142
    Scan_start = ((scan - 1) // 10) * 10 + 1
    Scan_end = Scan_start + 9 
    Round_No = f"{purpose}_Exp_{index_exp}_{Temp}oC_Case_{Scan_start}_{Scan_end}"  
    Target  = f'Exp{index_exp}_{Round_No}/'
    All_Scans[str(scan)] = loadmat( 
        BasicPath +  Target
        +  "Mats/" + str(scan)+ "-Ageing_summary_only.mat")
    axs[0].plot(
        All_Scans[str(scan)]['Throughput capacity [kA.h]'][0], 
        All_Scans[str(scan)]['CDend SOH [%]'][0],     
        '-o',color=cm(i), label=f"T={int(Temp)}") # 
    axs[1].plot(
        All_Scans[str(scan)]['Throughput capacity [kA.h]'][0], 
        All_Scans[str(scan)]["CDend LLI [%]"][0],'-o',color=cm(i), )
    axs[2].plot(
        All_Scans[str(scan)]["Throughput capacity [kA.h]"][0], 
        All_Scans[str(scan)]["CDend LAM_ne [%]"][0],'-o',   color=cm(i),   ) 
    axs[3].plot(
        All_Scans[str(scan)]["Throughput capacity [kA.h]"][0], 
        All_Scans[str(scan)]["CDend LAM_pe [%]"][0],    '-o', color=cm(i),  ) 
    axs[4].plot(
        All_Scans[str(scan)]["Throughput capacity [kA.h]"][0], 
        np.array(All_Scans[str(scan)]["Res_0p5C_50SOC"][0]),   '-o', color=cm(i), )
axs[0].set_ylabel("SOH %")
axs[1].set_ylabel("LLI %")
axs[2].set_ylabel("LAM NE %")
axs[3].set_ylabel("LAM PE %")
axs[4].set_ylabel(r"Lump resistance [m$\Omega$]")
axs[4].set_xlabel("Charge Throughput (kA.h)")
for i in range(0,Num_subplot):
    labels = axs[i].get_xticklabels() + axs[i].get_yticklabels(); 
    [label.set_fontname('DejaVu Sans') for label in labels]
    axs[i].tick_params(labelcolor='k', labelsize=fs, width=1) ;  del labels;
axs[4].ticklabel_format(style='sci', axis='x', scilimits=(-1e-2,1e-2))
axs[0].legend(
    prop={'family':'DejaVu Sans','size':fs-2},
    loc='best',ncol=1,frameon=False)
# Out:
# /tmp/ipykernel_9864/2027008147.py:4: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cm = mpl.cm.get_cmap("cool", 3)

# %%
# finish now, should hand over to the next one
def Plot_Selected_scans(Selected,Temper_i,Exp_Any_AllData,Str_1,dpi):
    # plot
    Num_subplot = 5;
    fig, axs = plt.subplots(Num_subplot,1, figsize=(6,13),tight_layout=True)
    cm = mpl.cm.get_cmap("cool", len(Selected)) 
    All_Scans = {}
    Temp = Temper_i - 273.15
    
    for i,scan in enumerate(Selected):
        Scan_start = ((scan - 1) // 10) * 10 + 1
        Scan_end = Scan_start + 9 
        Round_No = f"{purpose}_Exp_{index_exp}_{Temp}oC_Case_{Scan_start}_{Scan_end}"  
        Target  = f'Exp{index_exp}_{Round_No}/'
        try:
            All_Scans[str(scan)] = loadmat( 
                BasicPath +  Target
                +  "Mats/" + str(scan)+ "-Ageing_summary_only.mat")
            axs[0].plot(
                All_Scans[str(scan)]['Throughput capacity [kA.h]'][0], 
                All_Scans[str(scan)]['CDend SOH [%]'][0],     
                '-o',color=cm(i), label="Scan=" + str(scan)) # 
            axs[1].plot(
                All_Scans[str(scan)]['Throughput capacity [kA.h]'][0], 
                All_Scans[str(scan)]["CDend LLI [%]"][0],'-o',color=cm(i), )
            axs[2].plot(
                All_Scans[str(scan)]["Throughput capacity [kA.h]"][0], 
                All_Scans[str(scan)]["CDend LAM_ne [%]"][0],'-o',   color=cm(i),   ) 
            axs[3].plot(
                All_Scans[str(scan)]["Throughput capacity [kA.h]"][0], 
                All_Scans[str(scan)]["CDend LAM_pe [%]"][0],    '-o', color=cm(i),  ) 
            axs[4].plot(
                All_Scans[str(scan)]["Throughput capacity [kA.h]"][0], 
                np.array(All_Scans[str(scan)]["Res_0p5C_50SOC"][0]),   '-o', color=cm(i), )
        except:
            pass
        else:
            pass 
    # Plot Charge Throughput (A.h) vs SOH
    color_exp     = [0, 0, 0, 0.3]; marker_exp     = "v";
    color_exp_Avg = [0, 0, 0, 0.7]; marker_exp_Avg = "s";

    Exp_temp_i_cell = Temp_Cell_Exp[str(int(Temper_i- 273.15))]
    XY_pack = Get_Cell_Mean_1T_1Exp(Exp_Any_AllData,Exp_temp_i_cell) 
    Exp_temp_i_cell = Temp_Cell_Exp[str(int(Temper_i- 273.15))]
    for cell in Exp_temp_i_cell:
        df = Exp_Any_AllData[cell]["Extract Data"]
        chThr_temp = np.array(df["Charge Throughput (A.h)"])/1e3
        df_DMA = Exp_Any_AllData[cell]["DMA"]["LLI_LAM"]
        axs[0].plot(
            chThr_temp,np.array(df_DMA["SoH"])*100,
            color=color_exp,marker=marker_exp,label=f"Cell {cell}") 
        axs[1].plot(
            chThr_temp,np.array(df_DMA["LLI"])*100,
            color=color_exp,marker=marker_exp,label=f"Cell {cell}")  
        axs[2].plot(
            chThr_temp,np.array(df_DMA["LAM NE_tot"])*100,
            color=color_exp,marker=marker_exp, )
        axs[3].plot(
            chThr_temp,np.array(df_DMA["LAM PE"])*100,
            color=color_exp,marker=marker_exp,)
        # update 230312- plot resistance here
        df = Exp_Any_AllData[cell]["Extract Data"]
        # Exp_1_AllData["A"]["Extract Data"]["0.1s Resistance (Ohms)"]
        index_Res = df[df['0.1s Resistance (Ohms)'].le(10)].index
        axs[4].plot(
            #df["Days of degradation"][index_Res],
            np.array(df["Charge Throughput (A.h)"][index_Res])/1e3,
            np.array(df["0.1s Resistance (Ohms)"][index_Res])*1e3,
            color=color_exp,marker=marker_exp)
    # Update 230518: Plot Experiment Average - at 1 expeirment and 1 temperature
    [X_1_st,X_5_st,Y_1_st_avg,Y_2_st_avg,
        Y_3_st_avg,Y_4_st_avg,Y_5_st_avg]  = XY_pack
    axs[0].plot(
        X_1_st,Y_1_st_avg,color=color_exp_Avg,
        marker=marker_exp_Avg,label=f"Exp-Avg") 
    axs[1].plot(
        X_1_st,Y_2_st_avg,color=color_exp_Avg,
        marker=marker_exp_Avg,label=f"Exp-Avg")  
    axs[2].plot(
        X_1_st,Y_3_st_avg,color=color_exp_Avg,
        marker=marker_exp_Avg, )
    axs[3].plot(
        X_1_st,Y_4_st_avg,
        color=color_exp_Avg,marker=marker_exp_Avg,)
    axs[4].plot(
        X_5_st,Y_5_st_avg,
        color=color_exp_Avg,marker=marker_exp_Avg)
    axs[0].set_ylabel("SOH %")
    axs[1].set_ylabel("LLI %")
    axs[2].set_ylabel("LAM NE %")
    axs[3].set_ylabel("LAM PE %")
    axs[4].set_ylabel(r"Lump resistance [m$\Omega$]")
    axs[4].set_xlabel("Charge Throughput (kA.h)")
    for i in range(0,Num_subplot):
        labels = axs[i].get_xticklabels() + axs[i].get_yticklabels(); 
        [label.set_fontname('DejaVu Sans') for label in labels]
        axs[i].tick_params(labelcolor='k', labelsize=fs, width=1) ;  del labels;
    axs[4].ticklabel_format(style='sci', axis='x', scilimits=(-1e-2,1e-2))
    axs[0].legend(
        prop={'family':'DejaVu Sans','size':fs-6},
        loc='best',ncol=3,frameon=False)
    # axs[1].legend(prop={'family':'DejaVu Sans','size':fs-2},loc='best',frameon=False)
    fig.suptitle(
        f"{Str_1}_Exp-{index_exp}-{str(int(Temper_i- 273.15))}"
        +r"$^\circ$C", fontsize=fs+2)
    plt.savefig(
        BasicPath + f"Plots_collect/" +  
        f"{Str_1}_Exp-{index_exp}-{str(int(Temper_i- 273.15))}degC.png", dpi=dpi)
    # plt.close() 
    return All_Scans

Hit_10_25 = [17,175];
Hit_25_40 = [16,121,141,142,148];
Case_142_148 = [142,148]
for Temper_i in [10,25,40]:
    Temper_i = Temper_i + 273.15
    All_Scans = Plot_Selected_scans(
        Hit_25_40,Temper_i,Exp_Any_AllData,Str_1="Hit_25_40",dpi=400)
# Out:
# /tmp/ipykernel_9864/2306988824.py:6: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cm = mpl.cm.get_cmap("cool", len(Selected))

# %%
# Post-processing - using ML knowledge
# Read the Excel file into a DataFrame
df_40degC = pd.read_excel(BasicPath+"Summary of 200 cases-40oC.xlsx")
column_mapping = {
    "Inner SEI lithium interstitial diffusivity [m2.s-1]":"Dint",
    "Dead lithium decay constant [s-1]":"Decay",
    "Lithium plating kinetic rate constant [m.s-1]"	:"k_LiP",
    "Negative electrode LAM constant proportional term [s-1]"	:"pLAM_Ne",
    "Negative electrode cracking rate":"k_Ne_cr",
    "Outer SEI partial molar volume [m3.mol-1]":"V_SEI",	
}
# Rename the columns using the mapping   - Error_1~6;   Para_1~8
df_40degC = df_40degC.rename(columns=column_mapping)
df_40degC_s = df_40degC[df_40degC["Error Tot%"] != "Unknown"].copy()
df_40degC_f = df_40degC[df_40degC["Error Tot%"] == "Unknown"].copy()
df_40degC_f = df_40degC_f[~df_40degC_f["Scan No"].isin(df_40degC_s["Scan No"])].copy()

df_25degC = pd.read_excel(BasicPath+"Summary of 200 cases-25oC.xlsx")
df_25degC = df_25degC.rename(columns=column_mapping)
df_25degC_s = df_25degC[df_25degC["Error Tot%"] != "Unknown"].copy()
df_25degC_f = df_25degC[df_25degC["Error Tot%"] == "Unknown"].copy()
df_25degC_f = df_25degC_f[~df_25degC_f["Scan No"].isin(df_25degC_s["Scan No"])].copy()

df_10degC = pd.read_excel(BasicPath+"Summary of 200 cases-10oC.xlsx")
df_10degC = df_10degC.rename(columns=column_mapping)
df_10degC_s = df_10degC[df_10degC["Error Tot%"] != "Unknown"].copy()
df_10degC_f = df_10degC[df_10degC["Error Tot%"] == "Unknown"].copy()
df_10degC_f = df_10degC_f[~df_10degC_f["Scan No"].isin(df_10degC_s["Scan No"])].copy()

# %%
# Filter rows with "Error Tot%" less than 3.0
df_10degC_s["Error Tot%"] = pd.to_numeric(
    df_10degC_s["Error Tot%"], errors='coerce')
df_25degC_s["Error Tot%"] = pd.to_numeric(
    df_25degC_s["Error Tot%"], errors='coerce')
df_40degC_s["Error Tot%"] = pd.to_numeric(
    df_40degC_s["Error Tot%"], errors='coerce')
df_10degC_s_good = df_10degC_s[df_10degC_s["Error Tot%"] < 3.0].copy()
df_25degC_s_good = df_25degC_s[df_25degC_s["Error Tot%"] < 3.0].copy()
df_40degC_s_good = df_40degC_s[df_40degC_s["Error Tot%"] < 3.0].copy()
# Print the new dataframe
print(df_10degC_s_good["Scan No"]) # 
print(df_25degC_s_good["Scan No"]) # 
print(df_40degC_s_good["Scan No"]) # 
# hit 10,25: 17, 175 
# hit 25,40: 16,121,141,142,148 - all 40 cases can fit 25 as well!
# hit 10,40: none!
# Out:
# 26      17
# 95      61
# 211    155
# 241    175
# 258    190
# Name: Scan No, dtype: int64
# 22      13
# 23      14
# 24      15
# 25      16
# 26      17
# 27      19
# 122     84
# 135     91
# 172    121
# 198    141
# 199    142
# 201    148
# 202    150
# 243    174
# 244    175
# 246    179
# Name: Scan No, dtype: int64
# 25      16
# 178    121
# 206    141
# 207    142
# 210    148
# Name: Scan No, dtype: int64

# %%
# 1st thing to do: write these "good" values into the excel files for the next round run
str_list = [ 
    "Dint","Decay","k_LiP",
    "pLAM_Ne","k_Ne_cr","V_SEI",
]
df_10degC_s_good_filtered = df_10degC_s_good[str_list]
df_25degC_s_good_filtered = df_25degC_s_good[str_list]
df_40degC_s_good_filtered = df_40degC_s_good[str_list]
# Concatenate dataframes
df_combined = pd.concat([
    df_10degC_s_good_filtered, 
    df_25degC_s_good_filtered, 
    df_40degC_s_good_filtered])

# Remove duplicated rows based on "Scan No" column
df_combined_unique = df_combined.drop_duplicates(subset="Dint")

# Print the new dataframe
print(df_combined_unique,len(df_combined_unique))
column_mapping_rev = {
    "Dint":"Inner SEI lithium interstitial diffusivity [m2.s-1]",
    "Decay":"Dead lithium decay constant [s-1]",
    "k_LiP"	:"Lithium plating kinetic rate constant [m.s-1]",
    "pLAM_Ne"	:"Negative electrode LAM constant proportional term [s-1]",
    "k_Ne_cr":"Negative electrode cracking rate",
    "V_SEI":"Outer SEI partial molar volume [m3.mol-1]",	
}
df_combined_unique = df_combined_unique.rename(
    columns=column_mapping_rev)
# Save the dataframe to a CSV file
save_good =  os.path.expanduser("~/EnvPBGEM_Linux/SimSave/P2_R9_Dim")
tar  = '/Get_Random_sets/'
df_combined_unique.to_csv(
    save_good+tar+"GoodExp2_19cases.csv", index=False)
# Out:
#              Dint         Decay         k_LiP       pLAM_Ne       k_Ne_cr
# 26   1.058912e-18  5.478901e-13  1.846425e-14  2.327202e-15  6.442364e-24  \
# 95   9.432106e-19  3.180626e-11  7.401960e-14  3.001836e-15  1.742633e-25
# 211  1.034689e-18  1.398713e-12  2.582619e-15  7.575250e-15  9.221979e-25
# 241  9.652925e-19  1.534368e-11  4.102658e-15  8.603464e-16  3.217642e-24
# 258  1.365881e-18  2.494508e-11  5.542665e-15  1.189534e-15  8.504489e-24
# 22   6.218765e-19  1.011638e-11  3.331295e-15  3.529707e-15  1.366716e-22
# 23   2.246431e-19  1.783431e-12  3.217642e-14  6.985880e-16  1.289890e-23
# 24   2.521996e-19  2.736440e-13  2.523539e-15  1.867914e-16  4.605922e-25
# 25   4.006355e-19  8.703591e-11  7.575250e-14  6.080224e-16  2.582619e-23
# 27   1.414126e-19  1.245883e-11  1.059560e-14  6.747544e-15  9.011018e-23
# 122  1.464075e-18  2.409404e-11  3.107866e-15  1.011638e-15  1.320088e-25
# 135  4.394914e-19  2.121452e-12  2.494508e-14  1.607053e-15  3.612343e-22
# 172  1.866771e-19  2.552908e-13  1.722586e-14  1.448118e-16  1.804186e-22
# 198  3.652148e-19  4.500558e-11  4.937048e-15  1.071891e-16  1.663817e-21
# 199  3.825154e-19  1.189534e-13  4.500558e-15  2.768287e-16  5.291979e-25
# 201  2.464303e-19  5.170920e-11  1.663817e-15  2.899423e-16  4.247572e-24
# 202  1.121981e-19  2.800504e-12  7.488104e-15  2.300430e-16  1.846425e-24
# 243  9.541877e-20  7.316807e-11  6.593188e-14  2.221947e-15  7.663411e-21
# 246  6.821897e-19  4.768612e-13  9.547716e-14  1.956398e-16  6.080224e-25
#
#         V_SEI
# 26   0.000063
# 95   0.000066
# 211  0.000051
# 241  0.000059
# 258  0.000056
# 22   0.000078
# 23   0.000078
# 24   0.000061
# 25   0.000059
# 27   0.000071
# 122  0.000095
# 135  0.000103
# 172  0.000053
# 198  0.000058
# 199  0.000064
# 201  0.000055
# 202  0.000052
# 243  0.000085
# 246  0.000075   19

# %%
# Concatenate the "Scan No" columns from the three dataframes
combined_scan_no = pd.concat([
    df_10degC_s_good["Scan No"], 
    df_25degC_s_good["Scan No"], 
    df_40degC_s_good["Scan No"]])

# Get unique values and convert them to a list
unique_scan_no = combined_scan_no.unique().tolist()
print("Unique Scan No List:")
unique_scan_no = sorted(unique_scan_no)
print(unique_scan_no, len(unique_scan_no))
#
# Out:
# Unique Scan No List:
# [13, 14, 15, 16, 17, 19, 61, 84, 91, 121, 141, 142, 148, 150, 155, 174, 175, 179, 190] 19

# %%
# relevant input:
input_columns = [
    "Dint","Decay","k_LiP",
    "pLAM_Ne","k_Ne_cr","V_SEI"]
""" 
Error Tot%   Error SOH %   Error LLI % 
Error LAM NE %  Error LAM PE %	Error Res %
Cap Loss	
LLI to LiP	
LLI to SEI	
LLI to sei-on-cracks	
LAM to Neg	LAM to Pos	
Vol_Elely_Tot Final	
Vol_Elely_JR Final	
Width Final  """

def Plot_Single_Out(df, input_columns, output_column):
    fig, axes = plt.subplots(2, 3, figsize=(14, 6))
    axes = axes.flatten()
    # Plot input-output relationship in subplots
    for i, column in enumerate(input_columns):
        ax = axes[i]
        ax.scatter(df[column], df[output_column])
        ax.set_xlabel(column)
        ax.set_ylabel(output_column)
        if i < len(input_columns) - 1:
            ax.set_xscale('log')
    ax_last = axes[-1]
    ax_last.xaxis.set_major_formatter(mpl.ticker.ScalarFormatter(useMathText=True))
    ax_last.ticklabel_format(style='sci', axis='x', scilimits=(0, 0))
    plt.tight_layout()
    fig.suptitle(f"{output_column}", fontsize=fs+2)

#Plot_Single_Out(df,input_columns,output_column="Error Tot%")
Plot_Single_Out(df,input_columns,output_column="LLI to sei-on-cracks")
Plot_Single_Out(df,input_columns,output_column="LLI to SEI")
Plot_Single_Out(df,input_columns,output_column="LAM to Neg")
Plot_Single_Out(df,input_columns,output_column="LAM to Pos")

# %%
import seaborn as sns
def PlotPair(df, input_columns, output_column):
    # Create a DataFrame with only the input and output columns
    data_scale = df[input_columns + [output_column]]
    # Create the pair plot
    g = sns.pairplot(
        data_scale, vars=input_columns, hue=output_column,
        diag_kind='kde', plot_kws={'alpha': 0.6}, palette='cool')

    # Set x-axis and y-axis scales to log scale
    for ax in g.axes.flat:
        ax.set_xscale('log')
        ax.set_yscale('log')

    return

PlotPair(df, input_columns, output_column="LAM to Neg")

# %%
PlotPair(df, input_columns, output_column="Error Tot%")

# %%
import pandas as pd

# Assuming your DataFrame is named 'df'
df['Pass'] = df['Error Tot%'].apply(lambda x: 1.0 if x < 200 else 0.0)

# %%
PlotPair(df, ["Decay","k_LiP",], "Pass")
